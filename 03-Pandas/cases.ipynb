# %%
import pandas as pd
import matplotlib as plt

# %%
#d_parser = lambda x: pd.datetime.strptime(x, '%Y-%m-%d %I-%p')
#df = pd.read_excel('data/case.xlsx', parse_dates=['data nota fiscal'], date_parser=d_parser)
df = pd.read_excel('data/case.xlsx')

# %%
df.head()
# Out:
#    código nota fiscal data nota fiscal                        produto main  \
# 0            12345678       2021-02-03        MACARRÃO INSTANTÂNEO LEGUMES
# 1            91011123       2021-02-03        MACARRÃO INSTANTÂNEO LEGUMES
# 2           169676568       2021-02-03  MACARRÃO INSTANTÂNEO FRUTOS DO MAR
# 3           248342013       2021-02-03  MACARRÃO INSTANTÂNEO FRUTOS DO MAR
# 4           327007458       2021-02-03      MACARRÃO INSTANTÂNEO YAKISSOBA
#
#   cashback campanha  preço unitário  qtd. unidades vendidas  faturamento  \
# 0               40%            3.59                       1         3.59
# 1               40%            3.59                       1         3.59
# 2               40%            3.59                       1         3.59
# 3               40%            3.59                       1         3.59
# 4               40%            2.99                       3         8.97
#
#    cashback distribuído  comissão parceiro  cidade estado   tipo store
# 0                 1.436             1.5796   SALTO     SP  LOJA FÍSICA
# 1                 1.436             1.5796   SALTO     SP  LOJA FÍSICA
# 2                 1.436             1.5796   SALTO     SP  LOJA FÍSICA
# 3                 1.436             1.5796   SALTO     SP  LOJA FÍSICA
# 4                 1.196             1.3156  LAVRAS     MG  LOJA FÍSICA

# %%
df.shape
# Out:
# (1324, 12)

# %%
df.loc[0, 'data nota fiscal']
# Out:
# Timestamp('2021-02-03 00:00:00')

# %%
df.loc[0, 'data nota fiscal'].day_name()
# Out:
# 'Wednesday'

# %%
df['data nota fiscal'] = pd.to_datetime(df['data nota fiscal'], format='%Y-%m-%d %I-%p')

# %%
df['data nota fiscal']
# Out:
# 0      2021-02-03
# 1      2021-02-03
# 2      2021-02-03
# 3      2021-02-03
# 4      2021-02-03
#           ...
# 1319   2021-02-07
# 1320   2021-02-07
# 1321   2021-02-07
# 1322   2021-02-07
# 1323   2021-02-07
# Name: data nota fiscal, Length: 1324, dtype: datetime64[ns]

# %%
df['data nota fiscal'].dt.day_name()
# Out:
# 0       Wednesday
# 1       Wednesday
# 2       Wednesday
# 3       Wednesday
# 4       Wednesday
#           ...
# 1319       Sunday
# 1320       Sunday
# 1321       Sunday
# 1322       Sunday
# 1323       Sunday
# Name: data nota fiscal, Length: 1324, dtype: object

# %%
df['Day Of Week'] = df['data nota fiscal'].dt.day_name()
df
# Out:
#       código nota fiscal data nota fiscal                        produto main  \
# 0               12345678       2021-02-03        MACARRÃO INSTANTÂNEO LEGUMES
# 1               91011123       2021-02-03        MACARRÃO INSTANTÂNEO LEGUMES
# 2              169676568       2021-02-03  MACARRÃO INSTANTÂNEO FRUTOS DO MAR
# 3              248342013       2021-02-03  MACARRÃO INSTANTÂNEO FRUTOS DO MAR
# 4              327007458       2021-02-03      MACARRÃO INSTANTÂNEO YAKISSOBA
# ...                  ...              ...                                 ...
# 1319        103772067633       2021-02-07        MACARRÃO INSTANTÂNEO COSTELA
# 1320        103850733078       2021-02-07  MACARRÃO INSTANTÂNEO FRUTOS DO MAR
# 1321        103929398523       2021-02-07      MACARRÃO INSTANTÂNEO YAKISSOBA
# 1322        104008063968       2021-02-07      MACARRÃO INSTANTÂNEO YAKISSOBA
# 1323        104086729413       2021-02-07      MACARRÃO INSTANTÂNEO YAKISSOBA
#
#      cashback campanha  preço unitário  qtd. unidades vendidas  faturamento  \
# 0                  40%            3.59                       1         3.59
# 1                  40%            3.59                       1         3.59
# 2                  40%            3.59                       1         3.59
# 3                  40%            3.59                       1         3.59
# 4                  40%            2.99                       3         8.97
# ...                ...             ...                     ...          ...
# 1319               40%            3.99                       1         3.99
# 1320               40%            3.99                       1         3.99
# 1321               40%            3.99                       1         3.99
# 1322               40%            3.99                       1         3.99
# 1323               40%            3.99                       1         3.99
#
#       cashback distribuído  comissão parceiro          cidade estado  \
# 0                    1.436             1.5796           SALTO     SP
# 1                    1.436             1.5796           SALTO     SP
# 2                    1.436             1.5796           SALTO     SP
# 3                    1.436             1.5796           SALTO     SP
# 4                    1.196             1.3156          LAVRAS     MG
# ...                    ...                ...             ...    ...
# 1319                 1.596             1.7556  RIO DE JANEIRO     RJ
# 1320                 1.596             1.7556  RIO DE JANEIRO     RJ
# 1321                 1.596             1.7556  RIO DE JANEIRO     RJ
# 1322                 1.596             1.7556  RIO DE JANEIRO     RJ
# 1323                 1.596             1.7556  RIO DE JANEIRO     RJ
#
#        tipo store Day Of Week
# 0     LOJA FÍSICA   Wednesday
# 1     LOJA FÍSICA   Wednesday
# 2     LOJA FÍSICA   Wednesday
# 3     LOJA FÍSICA   Wednesday
# 4     LOJA FÍSICA   Wednesday
# ...           ...         ...
# 1319  LOJA FÍSICA      Sunday
# 1320  LOJA FÍSICA      Sunday
# 1321  LOJA FÍSICA      Sunday
# 1322  LOJA FÍSICA      Sunday
# 1323  LOJA FÍSICA      Sunday
#
# [1324 rows x 13 columns]

# %%
df['data nota fiscal'].min()
# Out:
# Timestamp('2021-02-03 00:00:00')

# %%
df['data nota fiscal'].max()
# Out:
# Timestamp('2021-02-07 00:00:00')

# %%
df['data nota fiscal'].max() - df['data nota fiscal'].min()
# Out:
# Timedelta('4 days 00:00:00')

# %%
filt = (df['data nota fiscal'] > '2021-02-03')
df.loc[filt]
# Out:
#       código nota fiscal data nota fiscal  \
# 208          16374758238       2021-02-04
# 209          16453423683       2021-02-04
# 210          16532089128       2021-02-04
# 211          16610754573       2021-02-04
# 212          16689420018       2021-02-04
# ...                  ...              ...
# 1319        103772067633       2021-02-07
# 1320        103850733078       2021-02-07
# 1321        103929398523       2021-02-07
# 1322        104008063968       2021-02-07
# 1323        104086729413       2021-02-07
#
#                                       produto main cashback campanha  \
# 208           MACARRÃO INSTANTÂNEO GALINHA CAIPIRA               40%
# 209                     MACARRÃO INSTANTÂNEO CURRY               40%
# 210           MACARRÃO INSTANTÂNEO GALINHA CAIPIRA               40%
# 211                   MACARRÃO INSTANTÂNEO LEGUMES               40%
# 212   MACARRÃO INSTANTÂNEO GALINHA CAIPIRA PICANTE               40%
# ...                                            ...               ...
# 1319                  MACARRÃO INSTANTÂNEO COSTELA               40%
# 1320            MACARRÃO INSTANTÂNEO FRUTOS DO MAR               40%
# 1321                MACARRÃO INSTANTÂNEO YAKISSOBA               40%
# 1322                MACARRÃO INSTANTÂNEO YAKISSOBA               40%
# 1323                MACARRÃO INSTANTÂNEO YAKISSOBA               40%
#
#       preço unitário  qtd. unidades vendidas  faturamento  \
# 208             2.99                       4        11.96
# 209             1.99                      12        23.88
# 210             1.99                      12        23.88
# 211             2.99                       2         5.98
# 212             2.99                       3         8.97
# ...              ...                     ...          ...
# 1319            3.99                       1         3.99
# 1320            3.99                       1         3.99
# 1321            3.99                       1         3.99
# 1322            3.99                       1         3.99
# 1323            3.99                       1         3.99
#
#       cashback distribuído  comissão parceiro          cidade estado  \
# 208                  1.196             1.3156            LEME     SP
# 209                  0.796             0.8756       SAO PAULO     SP
# 210                  0.796             0.8756       SÃO PAULO     SP
# 211                  1.196             1.3156     PASSO FUNDO     RS
# 212                  1.196             1.3156     PASSO FUNDO     RS
# ...                    ...                ...             ...    ...
# 1319                 1.596             1.7556  RIO DE JANEIRO     RJ
# 1320                 1.596             1.7556  RIO DE JANEIRO     RJ
# 1321                 1.596             1.7556  RIO DE JANEIRO     RJ
# 1322                 1.596             1.7556  RIO DE JANEIRO     RJ
# 1323                 1.596             1.7556  RIO DE JANEIRO     RJ
#
#        tipo store Day Of Week
# 208   LOJA FÍSICA    Thursday
# 209   LOJA FÍSICA    Thursday
# 210   LOJA FÍSICA    Thursday
# 211   LOJA FÍSICA    Thursday
# 212   LOJA FÍSICA    Thursday
# ...           ...         ...
# 1319  LOJA FÍSICA      Sunday
# 1320  LOJA FÍSICA      Sunday
# 1321  LOJA FÍSICA      Sunday
# 1322  LOJA FÍSICA      Sunday
# 1323  LOJA FÍSICA      Sunday
#
# [1116 rows x 13 columns]

# %%
filt = (df['data nota fiscal'] > pd.to_datetime('2021-02-03')) & (df['data nota fiscal'] < pd.to_datetime('2021-02-05'))
df.loc[filt]
# Out:
#      código nota fiscal data nota fiscal  \
# 208         16374758238       2021-02-04
# 209         16453423683       2021-02-04
# 210         16532089128       2021-02-04
# 211         16610754573       2021-02-04
# 212         16689420018       2021-02-04
# ..                  ...              ...
# 307         24162637293       2021-02-04
# 308         24241302738       2021-02-04
# 309         24319968183       2021-02-04
# 310         24398633628       2021-02-04
# 311         24477299073       2021-02-04
#
#                                      produto main cashback campanha  \
# 208          MACARRÃO INSTANTÂNEO GALINHA CAIPIRA               40%
# 209                    MACARRÃO INSTANTÂNEO CURRY               40%
# 210          MACARRÃO INSTANTÂNEO GALINHA CAIPIRA               40%
# 211                  MACARRÃO INSTANTÂNEO LEGUMES               40%
# 212  MACARRÃO INSTANTÂNEO GALINHA CAIPIRA PICANTE               40%
# ..                                            ...               ...
# 307                  MACARRÃO INSTANTÂNEO COSTELA               40%
# 308                MACARRÃO INSTANTÂNEO YAKISSOBA               40%
# 309                  MACARRÃO INSTANTÂNEO COSTELA               40%
# 310          MACARRÃO INSTANTÂNEO GALINHA CAIPIRA               40%
# 311                MACARRÃO INSTANTÂNEO YAKISSOBA               40%
#
#      preço unitário  qtd. unidades vendidas  faturamento  \
# 208            2.99                       4        11.96
# 209            1.99                      12        23.88
# 210            1.99                      12        23.88
# 211            2.99                       2         5.98
# 212            2.99                       3         8.97
# ..              ...                     ...          ...
# 307            3.99                       1         3.99
# 308            3.99                       1         3.99
# 309            3.99                       1         3.99
# 310            3.99                       1         3.99
# 311            2.99                       2         5.98
#
#      cashback distribuído  comissão parceiro       cidade estado   tipo store  \
# 208                 1.196             1.3156         LEME     SP  LOJA FÍSICA
# 209                 0.796             0.8756    SAO PAULO     SP  LOJA FÍSICA
# 210                 0.796             0.8756    SÃO PAULO     SP  LOJA FÍSICA
# 211                 1.196             1.3156  PASSO FUNDO     RS  LOJA FÍSICA
# 212                 1.196             1.3156  PASSO FUNDO     RS  LOJA FÍSICA
# ..                    ...                ...          ...    ...          ...
# 307                 1.596             1.7556      BARUERI     SP  LOJA FÍSICA
# 308                 1.596             1.7556      BARUERI     SP  LOJA FÍSICA
# 309                 1.596             1.7556      BARUERI     SP  LOJA FÍSICA
# 310                 1.596             1.7556      BARUERI     SP  LOJA FÍSICA
# 311                 1.196             1.3156  SANTA MARIA     RS  LOJA FÍSICA
#
#     Day Of Week
# 208    Thursday
# 209    Thursday
# 210    Thursday
# 211    Thursday
# 212    Thursday
# ..          ...
# 307    Thursday
# 308    Thursday
# 309    Thursday
# 310    Thursday
# 311    Thursday
#
# [104 rows x 13 columns]

# %%
df.set_index('data nota fiscal', inplace=True)

# %%
df['2021-02-02':'2021-02-05']['faturamento'].mean()
# Out:
# 4.8935431282051285

# %%
h = df['faturamento'].resample('D').max()
h['2021']
# Out:
# data nota fiscal
# 2021-02-03    47.88
# 2021-02-04    23.88
# 2021-02-05    31.90
# 2021-02-06    23.82
# 2021-02-07    51.00
# Freq: D, Name: faturamento, dtype: float64

# %%
# %matplotlib inline

# %%
h.plot()
# Out:
# <AxesSubplot:xlabel='data nota fiscal'>

# %%
df.resample('D').mean()
# Out:
#                   código nota fiscal  preço unitário  qtd. unidades vendidas  \
# data nota fiscal
# 2021-02-03              8.154219e+09        3.339622                1.600962
# 2021-02-04              2.042603e+10        3.102452                1.557692
# 2021-02-05              2.911856e+10        2.927906                1.615385
# 2021-02-06              3.824375e+10        3.020174                1.330435
# 2021-02-07              7.344654e+10        3.350010                1.593590
#
#                   faturamento  cashback distribuído  comissão parceiro
# data nota fiscal
# 2021-02-03           5.272019              1.335849           1.469434
# 2021-02-04           4.531346              1.240981           1.365079
# 2021-02-05           4.542650              1.171162           1.288279
# 2021-02-06           3.816522              1.208070           1.328877
# 2021-02-07           5.197026              1.340004           1.474004

# %%
fatMax = df['faturamento'].max()
fatmin = df['faturamento'].min()
df.resample('D').agg({'preço unitário':'mean', 'qtd. unidades vendidas':'sum', 'faturamento':'max', 'comissão parceiro':'sum'}).plot()
# Out:
# <AxesSubplot:xlabel='data nota fiscal'>
