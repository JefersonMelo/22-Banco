# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv')
schema_df = pd.read_csv('data/survey_results_schema.csv')

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
#      CurrencyDesc CurrencySymbol DatabaseDesireNextYear  \
# 0   European Euro            EUR   Microsoft SQL Server
# 1  Pound sterling            GBP                    NaN
# 2             NaN            NaN                    NaN
# 3    Albanian lek            ALL                    NaN
# 4             NaN            NaN       MySQL;PostgreSQL
#
#                           DatabaseWorkedWith  \
# 0  Elasticsearch;Microsoft SQL Server;Oracle
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4              MySQL;PostgreSQL;Redis;SQLite
#
#                                              DevType  \
# 0  Developer, desktop or enterprise applications;...
# 1            Developer, full-stack;Developer, mobile
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                            EdLevel  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                              NaN
# 3  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Employed full-time
# 2                                                NaN
# 3                                                NaN
# 4                                 Employed full-time
#
#                       Ethnicity Gender  \
# 0  White or of European descent    Man
# 1                           NaN    NaN
# 2                           NaN    NaN
# 3  White or of European descent    Man
# 4  White or of European descent    Man
#
#                                           JobFactors                 JobSat  \
# 0  Languages, frameworks, and other technologies ...     Slightly satisfied
# 1                                                NaN      Very dissatisfied
# 2                                                NaN                    NaN
# 3  Flex time or a flexible schedule;Office enviro...  Slightly dissatisfied
# 4                                                NaN                    NaN
#
#                                              JobSeek  \
# 0       I am not interested in new job opportunities
# 1       I am not interested in new job opportunities
# 2                                                NaN
# 3  I’m not actively looking, but I am open to new...
# 4                                                NaN
#
#      LanguageDesireNextYear        LanguageWorkedWith  \
# 0    C#;HTML/CSS;JavaScript    C#;HTML/CSS;JavaScript
# 1              Python;Swift          JavaScript;Swift
# 2  Objective-C;Python;Swift  Objective-C;Python;Swift
# 3                       NaN                       NaN
# 4           Java;Ruby;Scala         HTML/CSS;Ruby;SQL
#
#              MiscTechDesireNextYear MiscTechWorkedWith  \
# 0                 .NET Core;Xamarin     .NET;.NET Core
# 1  React Native;TensorFlow;Unity 3D       React Native
# 2                               NaN                NaN
# 3                               NaN                NaN
# 4                      Ansible;Chef            Ansible
#
#              NEWCollabToolsDesireNextYear  \
# 0  Microsoft Teams;Microsoft Azure;Trello
# 1                            Github;Slack
# 2                                     NaN
# 3                                     NaN
# 4   Github;Google Suite (Docs, Meet, etc)
#
#                             NEWCollabToolsWorkedWith NEWDevOps  \
# 0       Confluence;Jira;Slack;Microsoft Azure;Trello        No
# 1                Confluence;Jira;Github;Gitlab;Slack       NaN
# 2                                                NaN       NaN
# 3                                                NaN        No
# 4  Confluence;Jira;Github;Slack;Google Suite (Doc...       NaN
#
#         NEWDevOpsImpt                           NEWEdImpt  \
# 0  Somewhat important                    Fairly important
# 1                 NaN                    Fairly important
# 2                 NaN                                 NaN
# 3                 NaN  Not at all important/not necessary
# 4                 NaN                      Very important
#
#                                           NEWJobHunt NEWJobHuntResearch  \
# 0                                                NaN                NaN
# 1                                                NaN                NaN
# 2                                                NaN                NaN
# 3  Curious about other opportunities;Wanting to w...                NaN
# 4                                                NaN                NaN
#
#         NEWLearn NEWOffTopic NEWOnboardGood NEWOtherComms  \
# 0    Once a year    Not sure            NaN            No
# 1    Once a year    Not sure            NaN            No
# 2  Once a decade         NaN            NaN            No
# 3    Once a year    Not sure            Yes           Yes
# 4    Once a year          No            NaN           Yes
#
#                                          NEWOvertime  \
# 0                   Often: 1-2 days per week or more
# 1                                                NaN
# 2                                                NaN
# 3  Occasionally: 1-2 days per quarter but less th...
# 4                                                NaN
#
#                                  NEWPurchaseResearch      NEWPurpleLink  \
# 0  Start a free trial;Ask developers I know/work ...             Amused
# 1                                                NaN             Amused
# 2                                                NaN                NaN
# 3                                                NaN                NaN
# 4  Start a free trial;Ask developers I know/work ...  Hello, old friend
#
#                                           NEWSOSites  \
# 0   Stack Overflow (public Q&A for anyone who codes)
# 1  Stack Overflow (public Q&A for anyone who code...
# 2   Stack Overflow (public Q&A for anyone who codes)
# 3  Stack Overflow (public Q&A for anyone who code...
# 4  Stack Overflow (public Q&A for anyone who code...
#
#                                             NEWStuck        OpSys  \
# 0  Visit Stack Overflow;Go for a walk or other ph...      Windows
# 1  Visit Stack Overflow;Go for a walk or other ph...        MacOS
# 2                                                NaN  Linux-based
# 3                                                NaN  Linux-based
# 4  Call a coworker or friend;Visit Stack Overflow...      Windows
#
#                     OrgSize  \
# 0          2 to 9 employees
# 1  1,000 to 4,999 employees
# 2                       NaN
# 3        20 to 99 employees
# 4                       NaN
#
#                               PlatformDesireNextYear  \
# 0     Android;iOS;Kubernetes;Microsoft Azure;Windows
# 1                         iOS;Kubernetes;Linux;MacOS
# 2                                                NaN
# 3                                                NaN
# 4  Docker;Google Cloud Platform;Heroku;Linux;Windows
#
#                PlatformWorkedWith                      PurchaseWhat  \
# 0                         Windows                               NaN
# 1                             iOS     I have little or no influence
# 2                             NaN                               NaN
# 3                             NaN  I have a great deal of influence
# 4  AWS;Docker;Linux;MacOS;Windows                               NaN
#
#                  Sexuality SOAccount           SOComm  \
# 0  Straight / Heterosexual        No   No, not at all
# 1                      NaN       Yes  Yes, definitely
# 2                      NaN       Yes    Yes, somewhat
# 3  Straight / Heterosexual       Yes  Yes, definitely
# 4  Straight / Heterosexual       Yes    Yes, somewhat
#
#                             SOPartFreq                      SOVisitFreq  \
# 0                                  NaN           Multiple times per day
# 1  Less than once per month or monthly           Multiple times per day
# 2      A few times per month or weekly            Daily or almost daily
# 3      A few times per month or weekly           Multiple times per day
# 4  Less than once per month or monthly  A few times per month or weekly
#
#                    SurveyEase           SurveyLength Trans  \
# 0  Neither easy nor difficult  Appropriate in length    No
# 1                         NaN                    NaN   NaN
# 2  Neither easy nor difficult  Appropriate in length   NaN
# 3                         NaN                    NaN    No
# 4                        Easy              Too short    No
#
#                                       UndergradMajor WebframeDesireNextYear  \
# 0  Computer science, computer engineering, or sof...           ASP.NET Core
# 1  Computer science, computer engineering, or sof...                    NaN
# 2                                                NaN                    NaN
# 3  Computer science, computer engineering, or sof...                    NaN
# 4  Computer science, computer engineering, or sof...   Django;Ruby on Rails
#
#      WebframeWorkedWith                             WelcomeChange  \
# 0  ASP.NET;ASP.NET Core   Just as welcome now as I felt last year
# 1                   NaN  Somewhat more welcome now than last year
# 2                   NaN  Somewhat more welcome now than last year
# 3                   NaN  Somewhat less welcome now than last year
# 4         Ruby on Rails   Just as welcome now as I felt last year
#
#    WorkWeekHrs YearsCode YearsCodePro
# 0         50.0        36           27
# 1          NaN         7            4
# 2          NaN         4          NaN
# 3         40.0         7            4
# 4          NaN        15            8

# %%
df.shape
# Out:
# (64461, 61)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Respondent                    64461 non-null  int64
#  1   MainBranch                    64162 non-null  object
#  2   Hobbyist                      64416 non-null  object
#  3   Age                           45446 non-null  float64
#  4   Age1stCode                    57900 non-null  object
#  5   CompFreq                      40069 non-null  object
#  6   CompTotal                     34826 non-null  float64
#  7   ConvertedComp                 34756 non-null  float64
#  8   Country                       64072 non-null  object
#  9   CurrencyDesc                  45472 non-null  object
#  10  CurrencySymbol                45472 non-null  object
#  11  DatabaseDesireNextYear        44070 non-null  object
#  12  DatabaseWorkedWith            49537 non-null  object
#  13  DevType                       49370 non-null  object
#  14  EdLevel                       57431 non-null  object
#  15  Employment                    63854 non-null  object
#  16  Ethnicity                     45948 non-null  object
#  17  Gender                        50557 non-null  object
#  18  JobFactors                    49349 non-null  object
#  19  JobSat                        45194 non-null  object
#  20  JobSeek                       51727 non-null  object
#  21  LanguageDesireNextYear        54113 non-null  object
#  22  LanguageWorkedWith            57378 non-null  object
#  23  MiscTechDesireNextYear        42379 non-null  object
#  24  MiscTechWorkedWith            40314 non-null  object
#  25  NEWCollabToolsDesireNextYear  47287 non-null  object
#  26  NEWCollabToolsWorkedWith      52883 non-null  object
#  27  NEWDevOps                     42686 non-null  object
#  28  NEWDevOpsImpt                 41732 non-null  object
#  29  NEWEdImpt                     48465 non-null  object
#  30  NEWJobHunt                    42286 non-null  object
#  31  NEWJobHuntResearch            41022 non-null  object
#  32  NEWLearn                      56156 non-null  object
#  33  NEWOffTopic                   50804 non-null  object
#  34  NEWOnboardGood                42623 non-null  object
#  35  NEWOtherComms                 57205 non-null  object
#  36  NEWOvertime                   43231 non-null  object
#  37  NEWPurchaseResearch           37321 non-null  object
#  38  NEWPurpleLink                 54803 non-null  object
#  39  NEWSOSites                    58275 non-null  object
#  40  NEWStuck                      54983 non-null  object
#  41  OpSys                         56228 non-null  object
#  42  OrgSize                       44334 non-null  object
#  43  PlatformDesireNextYear        50605 non-null  object
#  44  PlatformWorkedWith            53843 non-null  object
#  45  PurchaseWhat                  39364 non-null  object
#  46  Sexuality                     43992 non-null  object
#  47  SOAccount                     56805 non-null  object
#  48  SOComm                        56476 non-null  object
#  49  SOPartFreq                    46792 non-null  object
#  50  SOVisitFreq                   56970 non-null  object
#  51  SurveyEase                    51802 non-null  object
#  52  SurveyLength                  51701 non-null  object
#  53  Trans                         49345 non-null  object
#  54  UndergradMajor                50995 non-null  object
#  55  WebframeDesireNextYear        40024 non-null  object
#  56  WebframeWorkedWith            42279 non-null  object
#  57  WelcomeChange                 52683 non-null  object
#  58  WorkWeekHrs                   41151 non-null  float64
#  59  YearsCode                     57684 non-null  object
#  60  YearsCodePro                  46349 non-null  object
# dtypes: float64(4), int64(1), object(56)
# memory usage: 30.0+ MB

# %%
pd.set_option('display.max_columns', 101)
pd.set_option('display.max_rows', 101)

# %%
schema_df = pd.read_csv('data/survey_results_schema.csv')

# %%
schema_df
# Out:
#                           Column  \
# 0                     Respondent
# 1                     MainBranch
# 2                       Hobbyist
# 3                            Age
# 4                     Age1stCode
# 5                       CompFreq
# 6                      CompTotal
# 7                  ConvertedComp
# 8                        Country
# 9                   CurrencyDesc
# 10                CurrencySymbol
# 11        DatabaseDesireNextYear
# 12            DatabaseWorkedWith
# 13                       DevType
# 14                       EdLevel
# 15                    Employment
# 16                     Ethnicity
# 17                        Gender
# 18                    JobFactors
# 19                        JobSat
# 20                       JobSeek
# 21        LanguageDesireNextYear
# 22            LanguageWorkedWith
# 23        MiscTechDesireNextYear
# 24            MiscTechWorkedWith
# 25  NEWCollabToolsDesireNextYear
# 26      NEWCollabToolsWorkedWith
# 27                     NEWDevOps
# 28                 NEWDevOpsImpt
# 29                     NEWEdImpt
# 30                    NEWJobHunt
# 31            NEWJobHuntResearch
# 32                      NEWLearn
# 33                   NEWOffTopic
# 34                NEWOnboardGood
# 35                 NEWOtherComms
# 36                   NEWOvertime
# 37           NEWPurchaseResearch
# 38                 NEWPurpleLink
# 39                    NEWSOSites
# 40                      NEWStuck
# 41                         OpSys
# 42                       OrgSize
# 43        PlatformDesireNextYear
# 44            PlatformWorkedWith
# 45                  PurchaseWhat
# 46                     Sexuality
# 47                     SOAccount
# 48                        SOComm
# 49                    SOPartFreq
# 50                   SOVisitFreq
# 51                    SurveyEase
# 52                  SurveyLength
# 53                         Trans
# 54                UndergradMajor
# 55        WebframeDesireNextYear
# 56            WebframeWorkedWith
# 57                 WelcomeChange
# 58                   WorkWeekHrs
# 59                     YearsCode
# 60                  YearsCodePro
#
#                                          QuestionText
# 0   Randomized respondent ID number (not in order ...
# 1   Which of the following options best describes ...
# 2                             Do you code as a hobby?
# 3   What is your age (in years)? If you prefer not...
# 4   At what age did you write your first line of c...
# 5    Is that compensation weekly, monthly, or yearly?
# 6   What is your current total compensation (salar...
# 7   Salary converted to annual USD salaries using ...
# 8                                  Where do you live?
# 9   Which currency do you use day-to-day? If your ...
# 10  Which currency do you use day-to-day? If your ...
# 11  Which database environments have you done exte...
# 12  Which database environments have you done exte...
# 13  Which of the following describe you? Please se...
# 14  Which of the following best describes the high...
# 15  Which of the following best describes your cur...
# 16  Which of the following describe you, if any? P...
# 17  Which of the following describe you, if any? P...
# 18  Imagine that you are deciding between two job ...
# 19  How satisfied are you with your current job? (...
# 20  Which of the following best describes your cur...
# 21  Which programming, scripting, and markup langu...
# 22  Which programming, scripting, and markup langu...
# 23  Which other frameworks, libraries, and tools h...
# 24  Which other frameworks, libraries, and tools h...
# 25  Which collaboration tools have you done extens...
# 26  Which collaboration tools have you done extens...
# 27  Does your company have a dedicated DevOps person?
# 28  How important is the practice of DevOps to sca...
# 29  How important is a formal education, such as a...
# 30  In general, what drives you to look for a new ...
# 31  When job searching, how do you learn more abou...
# 32  How frequently do you learn a new language or ...
# 33  Do you think Stack Overflow should relax restr...
# 34  Do you think your company has a good onboardin...
# 35  Are you a member of any other online developer...
# 36  How often do you work overtime or beyond the f...
# 37  When buying a new tool or software, how do you...
# 38  You search for a coding solution online and th...
# 39  Which of the following Stack Overflow sites ha...
# 40  What do you do when you get stuck on a problem...
# 41  What is the primary operating system in which ...
# 42  Approximately how many people are employed by ...
# 43  Which platforms have you done extensive develo...
# 44  Which platforms have you done extensive develo...
# 45  What level of influence do you, personally, ha...
# 46  Which of the following describe you, if any? P...
# 47              Do you have a Stack Overflow account?
# 48  Do you consider yourself a member of the Stack...
# 49  How frequently would you say you participate i...
# 50  How frequently would you say you visit Stack O...
# 51  How easy or difficult was this survey to compl...
# 52  How do you feel about the length of the survey...
# 53                               Are you transgender?
# 54              What was your primary field of study?
# 55  Which web frameworks have you done extensive d...
# 56  Which web frameworks have you done extensive d...
# 57  Compared to last year, how welcome do you feel...
# 58  On average, how many hours per week do you wor...
# 59  Including any education, how many years have y...
# 60  NOT including education, how many years have y...

# %%
df.shape
# Out:
# (64461, 61)

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
#        'Trans', 'UndergradMajor', 'WebframeDesireNextYear',
#        'WebframeWorkedWith', 'WelcomeChange', 'WorkWeekHrs', 'YearsCode',
#        'YearsCodePro'],
#       dtype='object')

# %%
df[['Hobbyist', 'Country']]
# Out:
#       Hobbyist             Country
# 0          Yes             Germany
# 1           No      United Kingdom
# 2          Yes  Russian Federation
# 3          Yes             Albania
# 4          Yes       United States
# ...        ...                 ...
# 64456      Yes       United States
# 64457      Yes             Morocco
# 64458      Yes            Viet Nam
# 64459      Yes              Poland
# 64460      Yes               Spain
#
# [64461 rows x 2 columns]

# %%
df[['Hobbyist']].value_counts()
# Out:
# Hobbyist
# Yes         50388
# No          14028
# dtype: int64

# %%
df[['PlatformWorkedWith']].value_counts()
# Out:
# PlatformWorkedWith
# Windows                                                                              4770
# Linux;Windows                                                                        2461
# Linux                                                                                2112
# Android                                                                              1201
# Microsoft Azure;Windows                                                               996
#                                                                                      ...
# Android;Docker;iOS;MacOS;Raspberry Pi;Slack Apps and Integrations                       1
# Android;AWS;Docker;iOS;Raspberry Pi;WordPress                                           1
# Android;Docker;iOS;MacOS;Raspberry Pi;Windows;WordPress                                 1
# Android;Docker;iOS;MacOS;Raspberry Pi;WordPress                                         1
# Arduino;AWS;Docker;Google Cloud Platform;Kubernetes;Linux;Microsoft Azure;Windows       1
# Length: 6287, dtype: int64

# %%
df.loc[0:38, 'Hobbyist':'Country']
# Out:
#    Hobbyist   Age Age1stCode CompFreq  CompTotal  ConvertedComp  \
# 0       Yes   NaN         13  Monthly        NaN            NaN
# 1        No   NaN         19      NaN        NaN            NaN
# 2       Yes   NaN         15      NaN        NaN            NaN
# 3       Yes  25.0         18      NaN        NaN            NaN
# 4       Yes  31.0         16      NaN        NaN            NaN
# 5        No   NaN         14      NaN        NaN            NaN
# 6       Yes   NaN         18  Monthly        NaN            NaN
# 7       Yes  36.0         12   Yearly   116000.0       116000.0
# 8        No  30.0         20      NaN        NaN            NaN
# 9       Yes  22.0         14   Yearly    25000.0        32315.0
# 10      Yes  23.0         13   Yearly    31000.0        40070.0
# 11       No  49.0         42  Monthly     1100.0        14268.0
# 12      Yes  53.0         14  Monthly     3000.0        38916.0
# 13      Yes  27.0         13   Yearly    66000.0        66000.0
# 14      Yes   NaN         13      NaN        NaN            NaN
# 15      Yes  45.0          8  Monthly     7000.0       108576.0
# 16      Yes  25.0         14   Yearly    79000.0        79000.0
# 17      Yes  32.0         12  Monthly   105000.0      1260000.0
# 18       No  24.0         15   Yearly    83400.0        83400.0
# 19      Yes  40.0         18      NaN        NaN            NaN
# 20      Yes  23.0         16      NaN        NaN            NaN
# 21      Yes   NaN         18  Monthly        NaN            NaN
# 22      Yes  27.0         14      NaN        NaN            NaN
# 23      Yes  45.0         14   Yearly    85000.0        91883.0
# 24       No   NaN         25  Monthly        NaN            NaN
# 25       No   NaN         12   Yearly    94000.0        71093.0
# 26      Yes   NaN         12      NaN        NaN            NaN
# 27      Yes   NaN         22      NaN        NaN            NaN
# 28      Yes  18.0         15      NaN        NaN            NaN
# 29      Yes   NaN         14   Yearly    30000.0        38778.0
# 30      Yes   NaN         20   Weekly        NaN            NaN
# 31      Yes  31.0         12  Monthly     3500.0        31764.0
# 32      Yes  39.0         14  Monthly     4900.0        63564.0
# 33      Yes  29.0         15      NaN        NaN            NaN
# 34      Yes  16.0         13      NaN        NaN            NaN
# 35      Yes  34.0         30   Yearly    60000.0        77556.0
# 36      Yes  19.0         16  Monthly        NaN            NaN
# 37       No  35.0         14   Yearly    90000.0        97288.0
# 38      Yes   NaN         17      NaN        NaN            NaN
#
#                Country
# 0              Germany
# 1       United Kingdom
# 2   Russian Federation
# 3              Albania
# 4        United States
# 5              Germany
# 6                India
# 7        United States
# 8              Tunisia
# 9       United Kingdom
# 10      United Kingdom
# 11               Spain
# 12         Netherlands
# 13       United States
# 14              France
# 15      United Kingdom
# 16       United States
# 17       United States
# 18       United States
# 19               Spain
# 20             Belgium
# 21               India
# 22             Germany
# 23             Germany
# 24            Portugal
# 25              Canada
# 26       United States
# 27               China
# 28             Ukraine
# 29      United Kingdom
# 30  Russian Federation
# 31              Canada
# 32             Belgium
# 33             Germany
# 34       United States
# 35      United Kingdom
# 36              France
# 37               Italy
# 38      United Kingdom

# %%
df['Country'] == 'Brazil'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 64456    False
# 64457    False
# 64458    False
# 64459    False
# 64460    False
# Name: Country, Length: 64461, dtype: bool

# %%
df.loc[0:38, ['Hobbyist', 'Country']]
# Out:
#    Hobbyist             Country
# 0       Yes             Germany
# 1        No      United Kingdom
# 2       Yes  Russian Federation
# 3       Yes             Albania
# 4       Yes       United States
# 5        No             Germany
# 6       Yes               India
# 7       Yes       United States
# 8        No             Tunisia
# 9       Yes      United Kingdom
# 10      Yes      United Kingdom
# 11       No               Spain
# 12      Yes         Netherlands
# 13      Yes       United States
# 14      Yes              France
# 15      Yes      United Kingdom
# 16      Yes       United States
# 17      Yes       United States
# 18       No       United States
# 19      Yes               Spain
# 20      Yes             Belgium
# 21      Yes               India
# 22      Yes             Germany
# 23      Yes             Germany
# 24       No            Portugal
# 25       No              Canada
# 26      Yes       United States
# 27      Yes               China
# 28      Yes             Ukraine
# 29      Yes      United Kingdom
# 30      Yes  Russian Federation
# 31      Yes              Canada
# 32      Yes             Belgium
# 33      Yes             Germany
# 34      Yes       United States
# 35      Yes      United Kingdom
# 36      Yes              France
# 37       No               Italy
# 38      Yes      United Kingdom

# %%
df.set_index('Country')
# Out:
#
# Germany                  Confluence;Jira;Slack;Microsoft Azure;Trello
# United Kingdom                    Confluence;Jira;Github;Gitlab;Slack
# Russian Federation                                                NaN
# Albania                                                           NaN
# United States       Confluence;Jira;Github;Slack;Google Suite (Doc...
# ...                                                               ...
# United States                                                     NaN
# Morocco                                                           NaN
# Viet Nam                                                          NaN
# Poland                          Confluence;Jira;Slack;Microsoft Teams
# Spain                                                          Github
#
#                    NEWDevOps       NEWDevOpsImpt  \
# Country
# Germany                   No  Somewhat important
# United Kingdom           NaN                 NaN
# Russian Federation       NaN                 NaN
# Albania                   No                 NaN
# United States            NaN                 NaN
# ...                      ...                 ...
# United States            NaN                 NaN
# Morocco                  NaN                 NaN
# Viet Nam                 NaN                 NaN
# Poland                   NaN                 NaN
# Spain                    NaN                 NaN
#
#                                              NEWEdImpt  \
# Country
# Germany                               Fairly important
# United Kingdom                        Fairly important
# Russian Federation                                 NaN
# Albania             Not at all important/not necessary
# United States                           Very important
# ...                                                ...
# United States                           Very important
# Morocco                                            NaN
# Viet Nam                                           NaN
# Poland                                             NaN
# Spain                             Critically important
#
#                                                            NEWJobHunt  \
# Country
# Germany                                                           NaN
# United Kingdom                                                    NaN
# Russian Federation                                                NaN
# Albania             Curious about other opportunities;Wanting to w...
# United States                                                     NaN
# ...                                                               ...
# United States                                                     NaN
# Morocco                                                           NaN
# Viet Nam                                                          NaN
# Poland                                                            NaN
# Spain                                                             NaN
#
#                    NEWJobHuntResearch       NEWLearn NEWOffTopic  \
# Country
# Germany                           NaN    Once a year    Not sure
# United Kingdom                    NaN    Once a year    Not sure
# Russian Federation                NaN  Once a decade         NaN
# Albania                           NaN    Once a year    Not sure
# United States                     NaN    Once a year          No
# ...                               ...            ...         ...
# United States                     NaN  Once a decade         NaN
# Morocco                           NaN            NaN         NaN
# Viet Nam                          NaN            NaN         NaN
# Poland                            NaN    Once a year         NaN
# Spain                             NaN    Once a year         NaN
#
#                    NEWOnboardGood NEWOtherComms  \
# Country
# Germany                       NaN            No
# United Kingdom                NaN            No
# Russian Federation            NaN            No
# Albania                       Yes           Yes
# United States                 NaN           Yes
# ...                           ...           ...
# United States                 NaN           NaN
# Morocco                       NaN           NaN
# Viet Nam                      NaN           NaN
# Poland                        NaN           NaN
# Spain                         NaN           NaN
#
#                                                           NEWOvertime  \
# Country
# Germany                              Often: 1-2 days per week or more
# United Kingdom                                                    NaN
# Russian Federation                                                NaN
# Albania             Occasionally: 1-2 days per quarter but less th...
# United States                                                     NaN
# ...                                                               ...
# United States                                                     NaN
# Morocco                                                           NaN
# Viet Nam                                                          NaN
# Poland                                                            NaN
# Spain                                                             NaN
#
#                                                   NEWPurchaseResearch  \
# Country
# Germany             Start a free trial;Ask developers I know/work ...
# United Kingdom                                                    NaN
# Russian Federation                                                NaN
# Albania                                                           NaN
# United States       Start a free trial;Ask developers I know/work ...
# ...                                                               ...
# United States                                      Start a free trial
# Morocco                                                           NaN
# Viet Nam                                                          NaN
# Poland                                             Start a free trial
# Spain               Start a free trial;Ask developers I know/work ...
#
#                         NEWPurpleLink  \
# Country
# Germany                        Amused
# United Kingdom                 Amused
# Russian Federation                NaN
# Albania                           NaN
# United States       Hello, old friend
# ...                               ...
# United States                  Amused
# Morocco                           NaN
# Viet Nam                          NaN
# Poland              Hello, old friend
# Spain                     Indifferent
#
#                                                            NEWSOSites  \
# Country
# Germany              Stack Overflow (public Q&A for anyone who codes)
# United Kingdom      Stack Overflow (public Q&A for anyone who code...
# Russian Federation   Stack Overflow (public Q&A for anyone who codes)
# Albania             Stack Overflow (public Q&A for anyone who code...
# United States       Stack Overflow (public Q&A for anyone who code...
# ...                                                               ...
# United States        Stack Overflow (public Q&A for anyone who codes)
# Morocco                                                           NaN
# Viet Nam                                                          NaN
# Poland               Stack Overflow (public Q&A for anyone who codes)
# Spain                                                             NaN
#
#                                                              NEWStuck  \
# Country
# Germany             Visit Stack Overflow;Go for a walk or other ph...
# United Kingdom      Visit Stack Overflow;Go for a walk or other ph...
# Russian Federation                                                NaN
# Albania                                                           NaN
# United States       Call a coworker or friend;Visit Stack Overflow...
# ...                                                               ...
# United States                               Call a coworker or friend
# Morocco                                                           NaN
# Viet Nam                                                          NaN
# Poland                 Call a coworker or friend;Visit Stack Overflow
# Spain               Meditate;Visit Stack Overflow;Go for a walk or...
#
#                           OpSys                   OrgSize  \
# Country
# Germany                 Windows          2 to 9 employees
# United Kingdom            MacOS  1,000 to 4,999 employees
# Russian Federation  Linux-based                       NaN
# Albania             Linux-based        20 to 99 employees
# United States           Windows                       NaN
# ...                         ...                       ...
# United States           Windows                       NaN
# Morocco                     NaN                       NaN
# Viet Nam                    NaN                       NaN
# Poland                  Windows                       NaN
# Spain                   Windows                       NaN
#
#                                                PlatformDesireNextYear  \
# Country
# Germany                Android;iOS;Kubernetes;Microsoft Azure;Windows
# United Kingdom                             iOS;Kubernetes;Linux;MacOS
# Russian Federation                                                NaN
# Albania                                                           NaN
# United States       Docker;Google Cloud Platform;Heroku;Linux;Windows
# ...                                                               ...
# United States                                                     NaN
# Morocco                                                           NaN
# Viet Nam                                                          NaN
# Poland                                                            NaN
# Spain                              Arduino;Linux;Raspberry Pi;Windows
#
#                                             PlatformWorkedWith  \
# Country
# Germany                                                Windows
# United Kingdom                                             iOS
# Russian Federation                                         NaN
# Albania                                                    NaN
# United States                   AWS;Docker;Linux;MacOS;Windows
# ...                                                        ...
# United States                                              NaN
# Morocco                                                    NaN
# Viet Nam                                                   NaN
# Poland                                           Linux;Windows
# Spain               Android;Arduino;Linux;Raspberry Pi;Windows
#
#                                         PurchaseWhat                Sexuality  \
# Country
# Germany                                          NaN  Straight / Heterosexual
# United Kingdom         I have little or no influence                      NaN
# Russian Federation                               NaN                      NaN
# Albania             I have a great deal of influence  Straight / Heterosexual
# United States                                    NaN  Straight / Heterosexual
# ...                                              ...                      ...
# United States                                    NaN                      NaN
# Morocco                                          NaN                      NaN
# Viet Nam                                         NaN                      NaN
# Poland                                           NaN                      NaN
# Spain                                            NaN                      NaN
#
#                    SOAccount           SOComm  \
# Country
# Germany                   No   No, not at all
# United Kingdom           Yes  Yes, definitely
# Russian Federation       Yes    Yes, somewhat
# Albania                  Yes  Yes, definitely
# United States            Yes    Yes, somewhat
# ...                      ...              ...
# United States            NaN              NaN
# Morocco                  NaN              NaN
# Viet Nam                 NaN              NaN
# Poland                   NaN              NaN
# Spain                    NaN              NaN
#
#                                              SOPartFreq  \
# Country
# Germany                                             NaN
# United Kingdom      Less than once per month or monthly
# Russian Federation      A few times per month or weekly
# Albania                 A few times per month or weekly
# United States       Less than once per month or monthly
# ...                                                 ...
# United States                                       NaN
# Morocco                                             NaN
# Viet Nam                                            NaN
# Poland                                              NaN
# Spain                                               NaN
#
#                                         SOVisitFreq  \
# Country
# Germany                      Multiple times per day
# United Kingdom               Multiple times per day
# Russian Federation            Daily or almost daily
# Albania                      Multiple times per day
# United States       A few times per month or weekly
# ...                                             ...
# United States                                   NaN
# Morocco                                         NaN
# Viet Nam                                        NaN
# Poland                                          NaN
# Spain                                           NaN
#
#                                     SurveyEase           SurveyLength Trans  \
# Country
# Germany             Neither easy nor difficult  Appropriate in length    No
# United Kingdom                             NaN                    NaN   NaN
# Russian Federation  Neither easy nor difficult  Appropriate in length   NaN
# Albania                                    NaN                    NaN    No
# United States                             Easy              Too short    No
# ...                                        ...                    ...   ...
# United States                              NaN                    NaN   NaN
# Morocco                                    NaN                    NaN   NaN
# Viet Nam                                   NaN                    NaN   NaN
# Poland                                     NaN                    NaN   NaN
# Spain                                      NaN                    NaN   NaN
#
#                                                        UndergradMajor  \
# Country
# Germany             Computer science, computer engineering, or sof...
# United Kingdom      Computer science, computer engineering, or sof...
# Russian Federation                                                NaN
# Albania             Computer science, computer engineering, or sof...
# United States       Computer science, computer engineering, or sof...
# ...                                                               ...
# United States       Computer science, computer engineering, or sof...
# Morocco                                                           NaN
# Viet Nam                                                          NaN
# Poland                                                            NaN
# Spain               Computer science, computer engineering, or sof...
#
#                          WebframeDesireNextYear  \
# Country
# Germany                            ASP.NET Core
# United Kingdom                              NaN
# Russian Federation                          NaN
# Albania                                     NaN
# United States              Django;Ruby on Rails
# ...                                         ...
# United States                               NaN
# Morocco                                     NaN
# Viet Nam                                    NaN
# Poland              Angular;Angular.js;React.js
# Spain                       ASP.NET Core;jQuery
#
#                                         WebframeWorkedWith  \
# Country
# Germany                               ASP.NET;ASP.NET Core
# United Kingdom                                         NaN
# Russian Federation                                     NaN
# Albania                                                NaN
# United States                                Ruby on Rails
# ...                                                    ...
# United States                                          NaN
# Morocco                                                NaN
# Viet Nam                                               NaN
# Poland                                                 NaN
# Spain               Angular;Angular.js;ASP.NET Core;jQuery
#
#                                                WelcomeChange  WorkWeekHrs  \
# Country
# Germany              Just as welcome now as I felt last year         50.0
# United Kingdom      Somewhat more welcome now than last year          NaN
# Russian Federation  Somewhat more welcome now than last year          NaN
# Albania             Somewhat less welcome now than last year         40.0
# United States        Just as welcome now as I felt last year          NaN
# ...                                                      ...          ...
# United States                                            NaN          NaN
# Morocco                                                  NaN          NaN
# Viet Nam                                                 NaN          NaN
# Poland                                                   NaN          NaN
# Spain                                                    NaN          NaN
#
#                    YearsCode      YearsCodePro
# Country
# Germany                   36                27
# United Kingdom             7                 4
# Russian Federation         4               NaN
# Albania                    7                 4
# United States             15                 8
# ...                      ...               ...
# United States             10  Less than 1 year
# Morocco                  NaN               NaN
# Viet Nam                 NaN               NaN
# Poland                   NaN               NaN
# Spain                    NaN               NaN
#
# [64461 rows x 60 columns]

# %%
df
# Out:
#      Employed full-time
# 2                                                    NaN
# 3                                                    NaN
# 4                                     Employed full-time
# ...                                                  ...
# 64456                                 Employed full-time
# 64457                                 Employed full-time
# 64458                                                NaN
# 64459                                 Employed full-time
# 64460                                 Employed full-time
#
#                           Ethnicity Gender  \
# 0      White or of European descent    Man
# 1                               NaN    NaN
# 2                               NaN    NaN
# 3      White or of European descent    Man
# 4      White or of European descent    Man
# ...                             ...    ...
# 64456                           NaN    NaN
# 64457                           NaN    NaN
# 64458                           NaN    NaN
# 64459                           NaN    NaN
# 64460                           NaN    NaN
#
#                                               JobFactors  \
# 0      Languages, frameworks, and other technologies ...
# 1                                                    NaN
# 2                                                    NaN
# 3      Flex time or a flexible schedule;Office enviro...
# 4                                                    NaN
# ...                                                  ...
# 64456                                                NaN
# 64457                                                NaN
# 64458                                                NaN
# 64459                                                NaN
# 64460                                                NaN
#
#                       JobSat  \
# 0         Slightly satisfied
# 1          Very dissatisfied
# 2                        NaN
# 3      Slightly dissatisfied
# 4                        NaN
# ...                      ...
# 64456                    NaN
# 64457                    NaN
# 64458                    NaN
# 64459                    NaN
# 64460                    NaN
#
#                                                  JobSeek  \
# 0           I am not interested in new job opportunities
# 1           I am not interested in new job opportunities
# 2                                                    NaN
# 3      I’m not actively looking, but I am open to new...
# 4                                                    NaN
# ...                                                  ...
# 64456                                                NaN
# 64457                                                NaN
# 64458                                                NaN
# 64459                                                NaN
# 64460                                                NaN
#
#                                   LanguageDesireNextYear  \
# 0                                 C#;HTML/CSS;JavaScript
# 1                                           Python;Swift
# 2                               Objective-C;Python;Swift
# 3                                                    NaN
# 4                                        Java;Ruby;Scala
# ...                                                  ...
# 64456                                                NaN
# 64457  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64458                                                NaN
# 64459                           HTML/CSS;Java;JavaScript
# 64460                    C#;HTML/CSS;Java;JavaScript;SQL
#
#                                       LanguageWorkedWith  \
# 0                                 C#;HTML/CSS;JavaScript
# 1                                       JavaScript;Swift
# 2                               Objective-C;Python;Swift
# 3                                                    NaN
# 4                                      HTML/CSS;Ruby;SQL
# ...                                                  ...
# 64456                                                NaN
# 64457  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64458                                                NaN
# 64459                                           HTML/CSS
# 64460                    C#;HTML/CSS;Java;JavaScript;SQL
#
#                  MiscTechDesireNextYear MiscTechWorkedWith  \
# 0                     .NET Core;Xamarin     .NET;.NET Core
# 1      React Native;TensorFlow;Unity 3D       React Native
# 2                                   NaN                NaN
# 3                                   NaN                NaN
# 4                          Ansible;Chef            Ansible
# ...                                 ...                ...
# 64456                               NaN                NaN
# 64457                               NaN                NaN
# 64458                               NaN                NaN
# 64459                           Node.js                NaN
# 64460                 .NET Core;Xamarin     .NET;.NET Core
#
#                  NEWCollabToolsDesireNextYear  \
# 0      Microsoft Teams;Microsoft Azure;Trello
# 1                                Github;Slack
# 2                                         NaN
# 3                                         NaN
# 4       Github;Google Suite (Docs, Meet, etc)
# ...                                       ...
# 64456                                     NaN
# 64457                                     NaN
# 64458                                     NaN
# 64459                           Github;Gitlab
# 64460                  Github;Microsoft Teams
#
#                                 NEWCollabToolsWorkedWith NEWDevOps  \
# 0           Confluence;Jira;Slack;Microsoft Azure;Trello        No
# 1                    Confluence;Jira;Github;Gitlab;Slack       NaN
# 2                                                    NaN       NaN
# 3                                                    NaN        No
# 4      Confluence;Jira;Github;Slack;Google Suite (Doc...       NaN
# ...                                                  ...       ...
# 64456                                                NaN       NaN
# 64457                                                NaN       NaN
# 64458                                                NaN       NaN
# 64459              Confluence;Jira;Slack;Microsoft Teams       NaN
# 64460                                             Github       NaN
#
#             NEWDevOpsImpt                           NEWEdImpt  \
# 0      Somewhat important                    Fairly important
# 1                     NaN                    Fairly important
# 2                     NaN                                 NaN
# 3                     NaN  Not at all important/not necessary
# 4                     NaN                      Very important
# ...                   ...                                 ...
# 64456                 NaN                      Very important
# 64457                 NaN                                 NaN
# 64458                 NaN                                 NaN
# 64459                 NaN                                 NaN
# 64460                 NaN                Critically important
#
#                                               NEWJobHunt NEWJobHuntResearch  \
# 0                                                    NaN                NaN
# 1                                                    NaN                NaN
# 2                                                    NaN                NaN
# 3      Curious about other opportunities;Wanting to w...                NaN
# 4                                                    NaN                NaN
# ...                                                  ...                ...
# 64456                                                NaN                NaN
# 64457                                                NaN                NaN
# 64458                                                NaN                NaN
# 64459                                                NaN                NaN
# 64460                                                NaN                NaN
#
#             NEWLearn NEWOffTopic NEWOnboardGood NEWOtherComms  \
# 0        Once a year    Not sure            NaN            No
# 1        Once a year    Not sure            NaN            No
# 2      Once a decade         NaN            NaN            No
# 3        Once a year    Not sure            Yes           Yes
# 4        Once a year          No            NaN           Yes
# ...              ...         ...            ...           ...
# 64456  Once a decade         NaN            NaN           NaN
# 64457            NaN         NaN            NaN           NaN
# 64458            NaN         NaN            NaN           NaN
# 64459    Once a year         NaN            NaN           NaN
# 64460    Once a year         NaN            NaN           NaN
#
#                                              NEWOvertime  \
# 0                       Often: 1-2 days per week or more
# 1                                                    NaN
# 2                                                    NaN
# 3      Occasionally: 1-2 days per quarter but less th...
# 4                                                    NaN
# ...                                                  ...
# 64456                                                NaN
# 64457                                                NaN
# 64458                                                NaN
# 64459                                                NaN
# 64460                                                NaN
#
#                                      NEWPurchaseResearch      NEWPurpleLink  \
# 0      Start a free trial;Ask developers I know/work ...             Amused
# 1                                                    NaN             Amused
# 2                                                    NaN                NaN
# 3                                                    NaN                NaN
# 4      Start a free trial;Ask developers I know/work ...  Hello, old friend
# ...                                                  ...                ...
# 64456                                 Start a free trial             Amused
# 64457                                                NaN                NaN
# 64458                                                NaN                NaN
# 64459                                 Start a free trial  Hello, old friend
# 64460  Start a free trial;Ask developers I know/work ...        Indifferent
#
#                                               NEWSOSites  \
# 0       Stack Overflow (public Q&A for anyone who codes)
# 1      Stack Overflow (public Q&A for anyone who code...
# 2       Stack Overflow (public Q&A for anyone who codes)
# 3      Stack Overflow (public Q&A for anyone who code...
# 4      Stack Overflow (public Q&A for anyone who code...
# ...                                                  ...
# 64456   Stack Overflow (public Q&A for anyone who codes)
# 64457                                                NaN
# 64458                                                NaN
# 64459   Stack Overflow (public Q&A for anyone who codes)
# 64460                                                NaN
#
#                                                 NEWStuck        OpSys  \
# 0      Visit Stack Overflow;Go for a walk or other ph...      Windows
# 1      Visit Stack Overflow;Go for a walk or other ph...        MacOS
# 2                                                    NaN  Linux-based
# 3                                                    NaN  Linux-based
# 4      Call a coworker or friend;Visit Stack Overflow...      Windows
# ...                                                  ...          ...
# 64456                          Call a coworker or friend      Windows
# 64457                                                NaN          NaN
# 64458                                                NaN          NaN
# 64459     Call a coworker or friend;Visit Stack Overflow      Windows
# 64460  Meditate;Visit Stack Overflow;Go for a walk or...      Windows
#
#                         OrgSize  \
# 0              2 to 9 employees
# 1      1,000 to 4,999 employees
# 2                           NaN
# 3            20 to 99 employees
# 4                           NaN
# ...                         ...
# 64456                       NaN
# 64457                       NaN
# 64458                       NaN
# 64459                       NaN
# 64460                       NaN
#
#                                   PlatformDesireNextYear  \
# 0         Android;iOS;Kubernetes;Microsoft Azure;Windows
# 1                             iOS;Kubernetes;Linux;MacOS
# 2                                                    NaN
# 3                                                    NaN
# 4      Docker;Google Cloud Platform;Heroku;Linux;Windows
# ...                                                  ...
# 64456                                                NaN
# 64457                                                NaN
# 64458                                                NaN
# 64459                                                NaN
# 64460                 Arduino;Linux;Raspberry Pi;Windows
#
#                                PlatformWorkedWith  \
# 0                                         Windows
# 1                                             iOS
# 2                                             NaN
# 3                                             NaN
# 4                  AWS;Docker;Linux;MacOS;Windows
# ...                                           ...
# 64456                                         NaN
# 64457                                         NaN
# 64458                                         NaN
# 64459                               Linux;Windows
# 64460  Android;Arduino;Linux;Raspberry Pi;Windows
#
#                            PurchaseWhat                Sexuality SOAccount  \
# 0                                   NaN  Straight / Heterosexual        No
# 1         I have little or no influence                      NaN       Yes
# 2                                   NaN                      NaN       Yes
# 3      I have a great deal of influence  Straight / Heterosexual       Yes
# 4                                   NaN  Straight / Heterosexual       Yes
# ...                                 ...                      ...       ...
# 64456                               NaN                      NaN       NaN
# 64457                               NaN                      NaN       NaN
# 64458                               NaN                      NaN       NaN
# 64459                               NaN                      NaN       NaN
# 64460                               NaN                      NaN       NaN
#
#                 SOComm                           SOPartFreq  \
# 0       No, not at all                                  NaN
# 1      Yes, definitely  Less than once per month or monthly
# 2        Yes, somewhat      A few times per month or weekly
# 3      Yes, definitely      A few times per month or weekly
# 4        Yes, somewhat  Less than once per month or monthly
# ...                ...                                  ...
# 64456              NaN                                  NaN
# 64457              NaN                                  NaN
# 64458              NaN                                  NaN
# 64459              NaN                                  NaN
# 64460              NaN                                  NaN
#
#                            SOVisitFreq                  SurveyEase  \
# 0               Multiple times per day  Neither easy nor difficult
# 1               Multiple times per day                         NaN
# 2                Daily or almost daily  Neither easy nor difficult
# 3               Multiple times per day                         NaN
# 4      A few times per month or weekly                        Easy
# ...                                ...                         ...
# 64456                              NaN                         NaN
# 64457                              NaN                         NaN
# 64458                              NaN                         NaN
# 64459                              NaN                         NaN
# 64460                              NaN                         NaN
#
#                 SurveyLength Trans  \
# 0      Appropriate in length    No
# 1                        NaN   NaN
# 2      Appropriate in length   NaN
# 3                        NaN    No
# 4                  Too short    No
# ...                      ...   ...
# 64456                    NaN   NaN
# 64457                    NaN   NaN
# 64458                    NaN   NaN
# 64459                    NaN   NaN
# 64460                    NaN   NaN
#
#                                           UndergradMajor  \
# 0      Computer science, computer engineering, or sof...
# 1      Computer science, computer engineering, or sof...
# 2                                                    NaN
# 3      Computer science, computer engineering, or sof...
# 4      Computer science, computer engineering, or sof...
# ...                                                  ...
# 64456  Computer science, computer engineering, or sof...
# 64457                                                NaN
# 64458                                                NaN
# 64459                                                NaN
# 64460  Computer science, computer engineering, or sof...
#
#             WebframeDesireNextYear                      WebframeWorkedWith  \
# 0                     ASP.NET Core                    ASP.NET;ASP.NET Core
# 1                              NaN                                     NaN
# 2                              NaN                                     NaN
# 3                              NaN                                     NaN
# 4             Django;Ruby on Rails                           Ruby on Rails
# ...                            ...                                     ...
# 64456                          NaN                                     NaN
# 64457                          NaN                                     NaN
# 64458                          NaN                                     NaN
# 64459  Angular;Angular.js;React.js                                     NaN
# 64460          ASP.NET Core;jQuery  Angular;Angular.js;ASP.NET Core;jQuery
#
#                                   WelcomeChange  WorkWeekHrs YearsCode  \
# 0       Just as welcome now as I felt last year         50.0        36
# 1      Somewhat more welcome now than last year          NaN         7
# 2      Somewhat more welcome now than last year          NaN         4
# 3      Somewhat less welcome now than last year         40.0         7
# 4       Just as welcome now as I felt last year          NaN        15
# ...                                         ...          ...       ...
# 64456                                       NaN          NaN        10
# 64457                                       NaN          NaN       NaN
# 64458                                       NaN          NaN       NaN
# 64459                                       NaN          NaN       NaN
# 64460                                       NaN          NaN       NaN
#
#            YearsCodePro
# 0                    27
# 1                     4
# 2                   NaN
# 3                     4
# 4                     8
# ...                 ...
# 64456  Less than 1 year
# 64457               NaN
# 64458               NaN
# 64459               NaN
# 64460               NaN
#
# [64461 rows x 61 columns]

# %%
df.loc[0:38, ['Hobbyist', 'Country']]
# Out:
#    Hobbyist             Country
# 0       Yes             Germany
# 1        No      United Kingdom
# 2       Yes  Russian Federation
# 3       Yes             Albania
# 4       Yes       United States
# 5        No             Germany
# 6       Yes               India
# 7       Yes       United States
# 8        No             Tunisia
# 9       Yes      United Kingdom
# 10      Yes      United Kingdom
# 11       No               Spain
# 12      Yes         Netherlands
# 13      Yes       United States
# 14      Yes              France
# 15      Yes      United Kingdom
# 16      Yes       United States
# 17      Yes       United States
# 18       No       United States
# 19      Yes               Spain
# 20      Yes             Belgium
# 21      Yes               India
# 22      Yes             Germany
# 23      Yes             Germany
# 24       No            Portugal
# 25       No              Canada
# 26      Yes       United States
# 27      Yes               China
# 28      Yes             Ukraine
# 29      Yes      United Kingdom
# 30      Yes  Russian Federation
# 31      Yes              Canada
# 32      Yes             Belgium
# 33      Yes             Germany
# 34      Yes       United States
# 35      Yes      United Kingdom
# 36      Yes              France
# 37       No               Italy
# 38      Yes      United Kingdom

# %%
schema_df
# Out:
#                           Column  \
# 0                     Respondent
# 1                     MainBranch
# 2                       Hobbyist
# 3                            Age
# 4                     Age1stCode
# 5                       CompFreq
# 6                      CompTotal
# 7                  ConvertedComp
# 8                        Country
# 9                   CurrencyDesc
# 10                CurrencySymbol
# 11        DatabaseDesireNextYear
# 12            DatabaseWorkedWith
# 13                       DevType
# 14                       EdLevel
# 15                    Employment
# 16                     Ethnicity
# 17                        Gender
# 18                    JobFactors
# 19                        JobSat
# 20                       JobSeek
# 21        LanguageDesireNextYear
# 22            LanguageWorkedWith
# 23        MiscTechDesireNextYear
# 24            MiscTechWorkedWith
# 25  NEWCollabToolsDesireNextYear
# 26      NEWCollabToolsWorkedWith
# 27                     NEWDevOps
# 28                 NEWDevOpsImpt
# 29                     NEWEdImpt
# 30                    NEWJobHunt
# 31            NEWJobHuntResearch
# 32                      NEWLearn
# 33                   NEWOffTopic
# 34                NEWOnboardGood
# 35                 NEWOtherComms
# 36                   NEWOvertime
# 37           NEWPurchaseResearch
# 38                 NEWPurpleLink
# 39                    NEWSOSites
# 40                      NEWStuck
# 41                         OpSys
# 42                       OrgSize
# 43        PlatformDesireNextYear
# 44            PlatformWorkedWith
# 45                  PurchaseWhat
# 46                     Sexuality
# 47                     SOAccount
# 48                        SOComm
# 49                    SOPartFreq
# 50                   SOVisitFreq
# 51                    SurveyEase
# 52                  SurveyLength
# 53                         Trans
# 54                UndergradMajor
# 55        WebframeDesireNextYear
# 56            WebframeWorkedWith
# 57                 WelcomeChange
# 58                   WorkWeekHrs
# 59                     YearsCode
# 60                  YearsCodePro
#
#                                          QuestionText
# 0   Randomized respondent ID number (not in order ...
# 1   Which of the following options best describes ...
# 2                             Do you code as a hobby?
# 3   What is your age (in years)? If you prefer not...
# 4   At what age did you write your first line of c...
# 5    Is that compensation weekly, monthly, or yearly?
# 6   What is your current total compensation (salar...
# 7   Salary converted to annual USD salaries using ...
# 8                                  Where do you live?
# 9   Which currency do you use day-to-day? If your ...
# 10  Which currency do you use day-to-day? If your ...
# 11  Which database environments have you done exte...
# 12  Which database environments have you done exte...
# 13  Which of the following describe you? Please se...
# 14  Which of the following best describes the high...
# 15  Which of the following best describes your cur...
# 16  Which of the following describe you, if any? P...
# 17  Which of the following describe you, if any? P...
# 18  Imagine that you are deciding between two job ...
# 19  How satisfied are you with your current job? (...
# 20  Which of the following best describes your cur...
# 21  Which programming, scripting, and markup langu...
# 22  Which programming, scripting, and markup langu...
# 23  Which other frameworks, libraries, and tools h...
# 24  Which other frameworks, libraries, and tools h...
# 25  Which collaboration tools have you done extens...
# 26  Which collaboration tools have you done extens...
# 27  Does your company have a dedicated DevOps person?
# 28  How important is the practice of DevOps to sca...
# 29  How important is a formal education, such as a...
# 30  In general, what drives you to look for a new ...
# 31  When job searching, how do you learn more abou...
# 32  How frequently do you learn a new language or ...
# 33  Do you think Stack Overflow should relax restr...
# 34  Do you think your company has a good onboardin...
# 35  Are you a member of any other online developer...
# 36  How often do you work overtime or beyond the f...
# 37  When buying a new tool or software, how do you...
# 38  You search for a coding solution online and th...
# 39  Which of the following Stack Overflow sites ha...
# 40  What do you do when you get stuck on a problem...
# 41  What is the primary operating system in which ...
# 42  Approximately how many people are employed by ...
# 43  Which platforms have you done extensive develo...
# 44  Which platforms have you done extensive develo...
# 45  What level of influence do you, personally, ha...
# 46  Which of the following describe you, if any? P...
# 47              Do you have a Stack Overflow account?
# 48  Do you consider yourself a member of the Stack...
# 49  How frequently would you say you participate i...
# 50  How frequently would you say you visit Stack O...
# 51  How easy or difficult was this survey to compl...
# 52  How do you feel about the length of the survey...
# 53                               Are you transgender?
# 54              What was your primary field of study?
# 55  Which web frameworks have you done extensive d...
# 56  Which web frameworks have you done extensive d...
# 57  Compared to last year, how welcome do you feel...
# 58  On average, how many hours per week do you wor...
# 59  Including any education, how many years have y...
# 60  NOT including education, how many years have y...

# %%
schema_df.columns
# Out:
# Index(['Column', 'QuestionText'], dtype='object')

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')

# %%
schema_df.sort_index()
# Out:
#                                                                    QuestionText
# Column
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# DatabaseDesireNextYear        Which database environments have you done exte...
# DatabaseWorkedWith            Which database environments have you done exte...
# DevType                       Which of the following describe you? Please se...
# EdLevel                       Which of the following best describes the high...
# Employment                    Which of the following best describes your cur...
# Ethnicity                     Which of the following describe you, if any? P...
# Gender                        Which of the following describe you, if any? P...
# Hobbyist                                                Do you code as a hobby?
# JobFactors                    Imagine that you are deciding between two job ...
# JobSat                        How satisfied are you with your current job? (...
# JobSeek                       Which of the following best describes your cur...
# LanguageDesireNextYear        Which programming, scripting, and markup langu...
# LanguageWorkedWith            Which programming, scripting, and markup langu...
# MainBranch                    Which of the following options best describes ...
# MiscTechDesireNextYear        Which other frameworks, libraries, and tools h...
# MiscTechWorkedWith            Which other frameworks, libraries, and tools h...
# NEWCollabToolsDesireNextYear  Which collaboration tools have you done extens...
# NEWCollabToolsWorkedWith      Which collaboration tools have you done extens...
# NEWDevOps                     Does your company have a dedicated DevOps person?
# NEWDevOpsImpt                 How important is the practice of DevOps to sca...
# NEWEdImpt                     How important is a formal education, such as a...
# NEWJobHunt                    In general, what drives you to look for a new ...
# NEWJobHuntResearch            When job searching, how do you learn more abou...
# NEWLearn                      How frequently do you learn a new language or ...
# NEWOffTopic                   Do you think Stack Overflow should relax restr...
# NEWOnboardGood                Do you think your company has a good onboardin...
# NEWOtherComms                 Are you a member of any other online developer...
# NEWOvertime                   How often do you work overtime or beyond the f...
# NEWPurchaseResearch           When buying a new tool or software, how do you...
# NEWPurpleLink                 You search for a coding solution online and th...
# NEWSOSites                    Which of the following Stack Overflow sites ha...
# NEWStuck                      What do you do when you get stuck on a problem...
# OpSys                         What is the primary operating system in which ...
# OrgSize                       Approximately how many people are employed by ...
# PlatformDesireNextYear        Which platforms have you done extensive develo...
# PlatformWorkedWith            Which platforms have you done extensive develo...
# PurchaseWhat                  What level of influence do you, personally, ha...
# Respondent                    Randomized respondent ID number (not in order ...
# SOAccount                                 Do you have a Stack Overflow account?
# SOComm                        Do you consider yourself a member of the Stack...
# SOPartFreq                    How frequently would you say you participate i...
# SOVisitFreq                   How frequently would you say you visit Stack O...
# Sexuality                     Which of the following describe you, if any? P...
# SurveyEase                    How easy or difficult was this survey to compl...
# SurveyLength                  How do you feel about the length of the survey...
# Trans                                                      Are you transgender?
# UndergradMajor                            What was your primary field of study?
# WebframeDesireNextYear        Which web frameworks have you done extensive d...
# WebframeWorkedWith            Which web frameworks have you done extensive d...
# WelcomeChange                 Compared to last year, how welcome do you feel...
# WorkWeekHrs                   On average, how many hours per week do you wor...
# YearsCode                     Including any education, how many years have y...
# YearsCodePro                  NOT including education, how many years have y...

# %%
schema_df.loc['Age']
# Out:
# QuestionText    What is your age (in years)? If you prefer not...
# Name: Age, dtype: object

# %%
schema_df.loc['Age', 'QuestionText']
# Out:
# 'What is your age (in years)? If you prefer not to answer, you may leave this question blank.'

# %%
schema_df.sort_index()
# Out:
#                                                                    QuestionText
# Column
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# DatabaseDesireNextYear        Which database environments have you done exte...
# DatabaseWorkedWith            Which database environments have you done exte...
# DevType                       Which of the following describe you? Please se...
# EdLevel                       Which of the following best describes the high...
# Employment                    Which of the following best describes your cur...
# Ethnicity                     Which of the following describe you, if any? P...
# Gender                        Which of the following describe you, if any? P...
# Hobbyist                                                Do you code as a hobby?
# JobFactors                    Imagine that you are deciding between two job ...
# JobSat                        How satisfied are you with your current job? (...
# JobSeek                       Which of the following best describes your cur...
# LanguageDesireNextYear        Which programming, scripting, and markup langu...
# LanguageWorkedWith            Which programming, scripting, and markup langu...
# MainBranch                    Which of the following options best describes ...
# MiscTechDesireNextYear        Which other frameworks, libraries, and tools h...
# MiscTechWorkedWith            Which other frameworks, libraries, and tools h...
# NEWCollabToolsDesireNextYear  Which collaboration tools have you done extens...
# NEWCollabToolsWorkedWith      Which collaboration tools have you done extens...
# NEWDevOps                     Does your company have a dedicated DevOps person?
# NEWDevOpsImpt                 How important is the practice of DevOps to sca...
# NEWEdImpt                     How important is a formal education, such as a...
# NEWJobHunt                    In general, what drives you to look for a new ...
# NEWJobHuntResearch            When job searching, how do you learn more abou...
# NEWLearn                      How frequently do you learn a new language or ...
# NEWOffTopic                   Do you think Stack Overflow should relax restr...
# NEWOnboardGood                Do you think your company has a good onboardin...
# NEWOtherComms                 Are you a member of any other online developer...
# NEWOvertime                   How often do you work overtime or beyond the f...
# NEWPurchaseResearch           When buying a new tool or software, how do you...
# NEWPurpleLink                 You search for a coding solution online and th...
# NEWSOSites                    Which of the following Stack Overflow sites ha...
# NEWStuck                      What do you do when you get stuck on a problem...
# OpSys                         What is the primary operating system in which ...
# OrgSize                       Approximately how many people are employed by ...
# PlatformDesireNextYear        Which platforms have you done extensive develo...
# PlatformWorkedWith            Which platforms have you done extensive develo...
# PurchaseWhat                  What level of influence do you, personally, ha...
# Respondent                    Randomized respondent ID number (not in order ...
# SOAccount                                 Do you have a Stack Overflow account?
# SOComm                        Do you consider yourself a member of the Stack...
# SOPartFreq                    How frequently would you say you participate i...
# SOVisitFreq                   How frequently would you say you visit Stack O...
# Sexuality                     Which of the following describe you, if any? P...
# SurveyEase                    How easy or difficult was this survey to compl...
# SurveyLength                  How do you feel about the length of the survey...
# Trans                                                      Are you transgender?
# UndergradMajor                            What was your primary field of study?
# WebframeDesireNextYear        Which web frameworks have you done extensive d...
# WebframeWorkedWith            Which web frameworks have you done extensive d...
# WelcomeChange                 Compared to last year, how welcome do you feel...
# WorkWeekHrs                   On average, how many hours per week do you wor...
# YearsCode                     Including any education, how many years have y...
# YearsCodePro                  NOT including education, how many years have y...

# %%
schema_df.sort_index(ascending=False)
# Out:
#                                                                    QuestionText
# Column
# YearsCodePro                  NOT including education, how many years have y...
# YearsCode                     Including any education, how many years have y...
# WorkWeekHrs                   On average, how many hours per week do you wor...
# WelcomeChange                 Compared to last year, how welcome do you feel...
# WebframeWorkedWith            Which web frameworks have you done extensive d...
# WebframeDesireNextYear        Which web frameworks have you done extensive d...
# UndergradMajor                            What was your primary field of study?
# Trans                                                      Are you transgender?
# SurveyLength                  How do you feel about the length of the survey...
# SurveyEase                    How easy or difficult was this survey to compl...
# Sexuality                     Which of the following describe you, if any? P...
# SOVisitFreq                   How frequently would you say you visit Stack O...
# SOPartFreq                    How frequently would you say you participate i...
# SOComm                        Do you consider yourself a member of the Stack...
# SOAccount                                 Do you have a Stack Overflow account?
# Respondent                    Randomized respondent ID number (not in order ...
# PurchaseWhat                  What level of influence do you, personally, ha...
# PlatformWorkedWith            Which platforms have you done extensive develo...
# PlatformDesireNextYear        Which platforms have you done extensive develo...
# OrgSize                       Approximately how many people are employed by ...
# OpSys                         What is the primary operating system in which ...
# NEWStuck                      What do you do when you get stuck on a problem...
# NEWSOSites                    Which of the following Stack Overflow sites ha...
# NEWPurpleLink                 You search for a coding solution online and th...
# NEWPurchaseResearch           When buying a new tool or software, how do you...
# NEWOvertime                   How often do you work overtime or beyond the f...
# NEWOtherComms                 Are you a member of any other online developer...
# NEWOnboardGood                Do you think your company has a good onboardin...
# NEWOffTopic                   Do you think Stack Overflow should relax restr...
# NEWLearn                      How frequently do you learn a new language or ...
# NEWJobHuntResearch            When job searching, how do you learn more abou...
# NEWJobHunt                    In general, what drives you to look for a new ...
# NEWEdImpt                     How important is a formal education, such as a...
# NEWDevOpsImpt                 How important is the practice of DevOps to sca...
# NEWDevOps                     Does your company have a dedicated DevOps person?
# NEWCollabToolsWorkedWith      Which collaboration tools have you done extens...
# NEWCollabToolsDesireNextYear  Which collaboration tools have you done extens...
# MiscTechWorkedWith            Which other frameworks, libraries, and tools h...
# MiscTechDesireNextYear        Which other frameworks, libraries, and tools h...
# MainBranch                    Which of the following options best describes ...
# LanguageWorkedWith            Which programming, scripting, and markup langu...
# LanguageDesireNextYear        Which programming, scripting, and markup langu...
# JobSeek                       Which of the following best describes your cur...
# JobSat                        How satisfied are you with your current job? (...
# JobFactors                    Imagine that you are deciding between two job ...
# Hobbyist                                                Do you code as a hobby?
# Gender                        Which of the following describe you, if any? P...
# Ethnicity                     Which of the following describe you, if any? P...
# Employment                    Which of the following best describes your cur...
# EdLevel                       Which of the following best describes the high...
# DevType                       Which of the following describe you? Please se...
# DatabaseWorkedWith            Which database environments have you done exte...
# DatabaseDesireNextYear        Which database environments have you done exte...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# Country                                                      Where do you live?
# ConvertedComp                 Salary converted to annual USD salaries using ...
# CompTotal                     What is your current total compensation (salar...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# Age1stCode                    At what age did you write your first line of c...
# Age                           What is your age (in years)? If you prefer not...

# %%
schema_df.sort_index(inplace=True)

# %%
schema_df
# Out:
#                                                                    QuestionText
# Column
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# DatabaseDesireNextYear        Which database environments have you done exte...
# DatabaseWorkedWith            Which database environments have you done exte...
# DevType                       Which of the following describe you? Please se...
# EdLevel                       Which of the following best describes the high...
# Employment                    Which of the following best describes your cur...
# Ethnicity                     Which of the following describe you, if any? P...
# Gender                        Which of the following describe you, if any? P...
# Hobbyist                                                Do you code as a hobby?
# JobFactors                    Imagine that you are deciding between two job ...
# JobSat                        How satisfied are you with your current job? (...
# JobSeek                       Which of the following best describes your cur...
# LanguageDesireNextYear        Which programming, scripting, and markup langu...
# LanguageWorkedWith            Which programming, scripting, and markup langu...
# MainBranch                    Which of the following options best describes ...
# MiscTechDesireNextYear        Which other frameworks, libraries, and tools h...
# MiscTechWorkedWith            Which other frameworks, libraries, and tools h...
# NEWCollabToolsDesireNextYear  Which collaboration tools have you done extens...
# NEWCollabToolsWorkedWith      Which collaboration tools have you done extens...
# NEWDevOps                     Does your company have a dedicated DevOps person?
# NEWDevOpsImpt                 How important is the practice of DevOps to sca...
# NEWEdImpt                     How important is a formal education, such as a...
# NEWJobHunt                    In general, what drives you to look for a new ...
# NEWJobHuntResearch            When job searching, how do you learn more abou...
# NEWLearn                      How frequently do you learn a new language or ...
# NEWOffTopic                   Do you think Stack Overflow should relax restr...
# NEWOnboardGood                Do you think your company has a good onboardin...
# NEWOtherComms                 Are you a member of any other online developer...
# NEWOvertime                   How often do you work overtime or beyond the f...
# NEWPurchaseResearch           When buying a new tool or software, how do you...
# NEWPurpleLink                 You search for a coding solution online and th...
# NEWSOSites                    Which of the following Stack Overflow sites ha...
# NEWStuck                      What do you do when you get stuck on a problem...
# OpSys                         What is the primary operating system in which ...
# OrgSize                       Approximately how many people are employed by ...
# PlatformDesireNextYear        Which platforms have you done extensive develo...
# PlatformWorkedWith            Which platforms have you done extensive develo...
# PurchaseWhat                  What level of influence do you, personally, ha...
# Respondent                    Randomized respondent ID number (not in order ...
# SOAccount                                 Do you have a Stack Overflow account?
# SOComm                        Do you consider yourself a member of the Stack...
# SOPartFreq                    How frequently would you say you participate i...
# SOVisitFreq                   How frequently would you say you visit Stack O...
# Sexuality                     Which of the following describe you, if any? P...
# SurveyEase                    How easy or difficult was this survey to compl...
# SurveyLength                  How do you feel about the length of the survey...
# Trans                                                      Are you transgender?
# UndergradMajor                            What was your primary field of study?
# WebframeDesireNextYear        Which web frameworks have you done extensive d...
# WebframeWorkedWith            Which web frameworks have you done extensive d...
# WelcomeChange                 Compared to last year, how welcome do you feel...
# WorkWeekHrs                   On average, how many hours per week do you wor...
# YearsCode                     Including any education, how many years have y...
# YearsCodePro                  NOT including education, how many years have y...
