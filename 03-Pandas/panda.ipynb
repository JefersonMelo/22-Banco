# %%
import pandas as pd
import numpy as np

# %%
na_vals = ['NA', 'Missing']

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent', na_values=na_vals)
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')

# %%
df
# Out:
#                                                      NaN
# 5                                             Java;Ruby;Scala
# ...                                                       ...
# 64858                                                     NaN
# 64867       Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64898                                                     NaN
# 64925                                HTML/CSS;Java;JavaScript
# 65112                         C#;HTML/CSS;Java;JavaScript;SQL
#
#                                            LanguageWorkedWith  \
# Respondent
# 1                                      C#;HTML/CSS;JavaScript
# 2                                            JavaScript;Swift
# 3                                    Objective-C;Python;Swift
# 4                                                         NaN
# 5                                           HTML/CSS;Ruby;SQL
# ...                                                       ...
# 64858                                                     NaN
# 64867       Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64898                                                     NaN
# 64925                                                HTML/CSS
# 65112                         C#;HTML/CSS;Java;JavaScript;SQL
#
#                       MiscTechDesireNextYear MiscTechWorkedWith  \
# Respondent
# 1                          .NET Core;Xamarin     .NET;.NET Core
# 2           React Native;TensorFlow;Unity 3D       React Native
# 3                                        NaN                NaN
# 4                                        NaN                NaN
# 5                               Ansible;Chef            Ansible
# ...                                      ...                ...
# 64858                                    NaN                NaN
# 64867                                    NaN                NaN
# 64898                                    NaN                NaN
# 64925                                Node.js                NaN
# 65112                      .NET Core;Xamarin     .NET;.NET Core
#
#                       NEWCollabToolsDesireNextYear  \
# Respondent
# 1           Microsoft Teams;Microsoft Azure;Trello
# 2                                     Github;Slack
# 3                                              NaN
# 4                                              NaN
# 5            Github;Google Suite (Docs, Meet, etc)
# ...                                            ...
# 64858                                          NaN
# 64867                                          NaN
# 64898                                          NaN
# 64925                                Github;Gitlab
# 65112                       Github;Microsoft Teams
#
#                                      NEWCollabToolsWorkedWith NEWDevOps  \
# Respondent
# 1                Confluence;Jira;Slack;Microsoft Azure;Trello        No
# 2                         Confluence;Jira;Github;Gitlab;Slack       NaN
# 3                                                         NaN       NaN
# 4                                                         NaN        No
# 5           Confluence;Jira;Github;Slack;Google Suite (Doc...       NaN
# ...                                                       ...       ...
# 64858                                                     NaN       NaN
# 64867                                                     NaN       NaN
# 64898                                                     NaN       NaN
# 64925                   Confluence;Jira;Slack;Microsoft Teams       NaN
# 65112                                                  Github       NaN
#
#                  NEWDevOpsImpt                           NEWEdImpt  \
# Respondent
# 1           Somewhat important                    Fairly important
# 2                          NaN                    Fairly important
# 3                          NaN                                 NaN
# 4                          NaN  Not at all important/not necessary
# 5                          NaN                      Very important
# ...                        ...                                 ...
# 64858                      NaN                      Very important
# 64867                      NaN                                 NaN
# 64898                      NaN                                 NaN
# 64925                      NaN                                 NaN
# 65112                      NaN                Critically important
#
#                                                    NEWJobHunt  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4           Curious about other opportunities;Wanting to w...
# 5                                                         NaN
# ...                                                       ...
# 64858                                                     NaN
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                                     NaN
# 65112                                                     NaN
#
#            NEWJobHuntResearch       NEWLearn NEWOffTopic NEWOnboardGood  \
# Respondent
# 1                         NaN    Once a year    Not sure            NaN
# 2                         NaN    Once a year    Not sure            NaN
# 3                         NaN  Once a decade         NaN            NaN
# 4                         NaN    Once a year    Not sure            Yes
# 5                         NaN    Once a year          No            NaN
# ...                       ...            ...         ...            ...
# 64858                     NaN  Once a decade         NaN            NaN
# 64867                     NaN            NaN         NaN            NaN
# 64898                     NaN            NaN         NaN            NaN
# 64925                     NaN    Once a year         NaN            NaN
# 65112                     NaN    Once a year         NaN            NaN
#
#            NEWOtherComms                                        NEWOvertime  \
# Respondent
# 1                     No                   Often: 1-2 days per week or more
# 2                     No                                                NaN
# 3                     No                                                NaN
# 4                    Yes  Occasionally: 1-2 days per quarter but less th...
# 5                    Yes                                                NaN
# ...                  ...                                                ...
# 64858                NaN                                                NaN
# 64867                NaN                                                NaN
# 64898                NaN                                                NaN
# 64925                NaN                                                NaN
# 65112                NaN                                                NaN
#
#                                           NEWPurchaseResearch  \
# Respondent
# 1           Start a free trial;Ask developers I know/work ...
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
# 5           Start a free trial;Ask developers I know/work ...
# ...                                                       ...
# 64858                                      Start a free trial
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                      Start a free trial
# 65112       Start a free trial;Ask developers I know/work ...
#
#                 NEWPurpleLink  \
# Respondent
# 1                      Amused
# 2                      Amused
# 3                         NaN
# 4                         NaN
# 5           Hello, old friend
# ...                       ...
# 64858                  Amused
# 64867                     NaN
# 64898                     NaN
# 64925       Hello, old friend
# 65112             Indifferent
#
#                                                    NEWSOSites  \
# Respondent
# 1            Stack Overflow (public Q&A for anyone who codes)
# 2           Stack Overflow (public Q&A for anyone who code...
# 3            Stack Overflow (public Q&A for anyone who codes)
# 4           Stack Overflow (public Q&A for anyone who code...
# 5           Stack Overflow (public Q&A for anyone who code...
# ...                                                       ...
# 64858        Stack Overflow (public Q&A for anyone who codes)
# 64867                                                     NaN
# 64898                                                     NaN
# 64925        Stack Overflow (public Q&A for anyone who codes)
# 65112                                                     NaN
#
#                                                      NEWStuck        OpSys  \
# Respondent
# 1           Visit Stack Overflow;Go for a walk or other ph...      Windows
# 2           Visit Stack Overflow;Go for a walk or other ph...        MacOS
# 3                                                         NaN  Linux-based
# 4                                                         NaN  Linux-based
# 5           Call a coworker or friend;Visit Stack Overflow...      Windows
# ...                                                       ...          ...
# 64858                               Call a coworker or friend      Windows
# 64867                                                     NaN          NaN
# 64898                                                     NaN          NaN
# 64925          Call a coworker or friend;Visit Stack Overflow      Windows
# 65112       Meditate;Visit Stack Overflow;Go for a walk or...      Windows
#
#                              OrgSize  \
# Respondent
# 1                   2 to 9 employees
# 2           1,000 to 4,999 employees
# 3                                NaN
# 4                 20 to 99 employees
# 5                                NaN
# ...                              ...
# 64858                            NaN
# 64867                            NaN
# 64898                            NaN
# 64925                            NaN
# 65112                            NaN
#
#                                        PlatformDesireNextYear  \
# Respondent
# 1              Android;iOS;Kubernetes;Microsoft Azure;Windows
# 2                                  iOS;Kubernetes;Linux;MacOS
# 3                                                         NaN
# 4                                                         NaN
# 5           Docker;Google Cloud Platform;Heroku;Linux;Windows
# ...                                                       ...
# 64858                                                     NaN
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                                     NaN
# 65112                      Arduino;Linux;Raspberry Pi;Windows
#
#                                     PlatformWorkedWith  \
# Respondent
# 1                                              Windows
# 2                                                  iOS
# 3                                                  NaN
# 4                                                  NaN
# 5                       AWS;Docker;Linux;MacOS;Windows
# ...                                                ...
# 64858                                              NaN
# 64867                                              NaN
# 64898                                              NaN
# 64925                                    Linux;Windows
# 65112       Android;Arduino;Linux;Raspberry Pi;Windows
#
#                                 PurchaseWhat                Sexuality  \
# Respondent
# 1                                        NaN  Straight / Heterosexual
# 2              I have little or no influence                      NaN
# 3                                        NaN                      NaN
# 4           I have a great deal of influence  Straight / Heterosexual
# 5                                        NaN  Straight / Heterosexual
# ...                                      ...                      ...
# 64858                                    NaN                      NaN
# 64867                                    NaN                      NaN
# 64898                                    NaN                      NaN
# 64925                                    NaN                      NaN
# 65112                                    NaN                      NaN
#
#            SOAccount           SOComm                           SOPartFreq  \
# Respondent
# 1                 No   No, not at all                                  NaN
# 2                Yes  Yes, definitely  Less than once per month or monthly
# 3                Yes    Yes, somewhat      A few times per month or weekly
# 4                Yes  Yes, definitely      A few times per month or weekly
# 5                Yes    Yes, somewhat  Less than once per month or monthly
# ...              ...              ...                                  ...
# 64858            NaN              NaN                                  NaN
# 64867            NaN              NaN                                  NaN
# 64898            NaN              NaN                                  NaN
# 64925            NaN              NaN                                  NaN
# 65112            NaN              NaN                                  NaN
#
#                                 SOVisitFreq                  SurveyEase  \
# Respondent
# 1                    Multiple times per day  Neither easy nor difficult
# 2                    Multiple times per day                         NaN
# 3                     Daily or almost daily  Neither easy nor difficult
# 4                    Multiple times per day                         NaN
# 5           A few times per month or weekly                        Easy
# ...                                     ...                         ...
# 64858                                   NaN                         NaN
# 64867                                   NaN                         NaN
# 64898                                   NaN                         NaN
# 64925                                   NaN                         NaN
# 65112                                   NaN                         NaN
#
#                      SurveyLength Trans  \
# Respondent
# 1           Appropriate in length    No
# 2                             NaN   NaN
# 3           Appropriate in length   NaN
# 4                             NaN    No
# 5                       Too short    No
# ...                           ...   ...
# 64858                         NaN   NaN
# 64867                         NaN   NaN
# 64898                         NaN   NaN
# 64925                         NaN   NaN
# 65112                         NaN   NaN
#
#                                                UndergradMajor  \
# Respondent
# 1           Computer science, computer engineering, or sof...
# 2           Computer science, computer engineering, or sof...
# 3                                                         NaN
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
# ...                                                       ...
# 64858       Computer science, computer engineering, or sof...
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                                     NaN
# 65112       Computer science, computer engineering, or sof...
#
#                  WebframeDesireNextYear  \
# Respondent
# 1                          ASP.NET Core
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                  Django;Ruby on Rails
# ...                                 ...
# 64858                               NaN
# 64867                               NaN
# 64898                               NaN
# 64925       Angular;Angular.js;React.js
# 65112               ASP.NET Core;jQuery
#
#                                 WebframeWorkedWith  \
# Respondent
# 1                             ASP.NET;ASP.NET Core
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# 5                                    Ruby on Rails
# ...                                            ...
# 64858                                          NaN
# 64867                                          NaN
# 64898                                          NaN
# 64925                                          NaN
# 65112       Angular;Angular.js;ASP.NET Core;jQuery
#
#                                        WelcomeChange  WorkWeekHrs YearsCode  \
# Respondent
# 1            Just as welcome now as I felt last year         50.0        36
# 2           Somewhat more welcome now than last year          NaN         7
# 3           Somewhat more welcome now than last year          NaN         4
# 4           Somewhat less welcome now than last year         40.0         7
# 5            Just as welcome now as I felt last year          NaN        15
# ...                                              ...          ...       ...
# 64858                                            NaN          NaN        10
# 64867                                            NaN          NaN       NaN
# 64898                                            NaN          NaN       NaN
# 64925                                            NaN          NaN       NaN
# 65112                                            NaN          NaN       NaN
#
#                 YearsCodePro
# Respondent
# 1                         27
# 2                          4
# 3                        NaN
# 4                          4
# 5                          8
# ...                      ...
# 64858       Less than 1 year
# 64867                    NaN
# 64898                    NaN
# 64925                    NaN
# 65112                    NaN
#
# [64461 rows x 60 columns]

# %%
df['YearsCode'] = df['YearsCode'].astype(str)

# %%
df['YearsCode'].head(10)
# Out:
# Respondent
# 1     36
# 2      7
# 3      4
# 4      7
# 5     15
# 6      6
# 7      6
# 8     17
# 9      6
# 10     8
# Name: YearsCode, dtype: object

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
#               CurrencyDesc CurrencySymbol DatabaseDesireNextYear  \
# Respondent
# 1            European Euro            EUR   Microsoft SQL Server
# 2           Pound sterling            GBP                    NaN
# 3                      NaN            NaN                    NaN
# 4             Albanian lek            ALL                    NaN
# 5                      NaN            NaN       MySQL;PostgreSQL
#
#                                    DatabaseWorkedWith  \
# Respondent
# 1           Elasticsearch;Microsoft SQL Server;Oracle
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                       MySQL;PostgreSQL;Redis;SQLite
#
#                                                       DevType  \
# Respondent
# 1           Developer, desktop or enterprise applications;...
# 2                     Developer, full-stack;Developer, mobile
# 3                                                         NaN
# 4                                                         NaN
# 5                                                         NaN
#
#                                                     EdLevel  \
# Respondent
# 1           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3                                                       NaN
# 4           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 5              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                    Employment  \
# Respondent
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Employed full-time
# 3                                                         NaN
# 4                                                         NaN
# 5                                          Employed full-time
#
#                                Ethnicity Gender  \
# Respondent
# 1           White or of European descent    Man
# 2                                    NaN    NaN
# 3                                    NaN    NaN
# 4           White or of European descent    Man
# 5           White or of European descent    Man
#
#                                                    JobFactors  \
# Respondent
# 1           Languages, frameworks, and other technologies ...
# 2                                                         NaN
# 3                                                         NaN
# 4           Flex time or a flexible schedule;Office enviro...
# 5                                                         NaN
#
#                            JobSat  \
# Respondent
# 1              Slightly satisfied
# 2               Very dissatisfied
# 3                             NaN
# 4           Slightly dissatisfied
# 5                             NaN
#
#                                                       JobSeek  \
# Respondent
# 1                I am not interested in new job opportunities
# 2                I am not interested in new job opportunities
# 3                                                         NaN
# 4           I’m not actively looking, but I am open to new...
# 5                                                         NaN
#
#               LanguageDesireNextYear        LanguageWorkedWith  \
# Respondent
# 1             C#;HTML/CSS;JavaScript    C#;HTML/CSS;JavaScript
# 2                       Python;Swift          JavaScript;Swift
# 3           Objective-C;Python;Swift  Objective-C;Python;Swift
# 4                                NaN                       NaN
# 5                    Java;Ruby;Scala         HTML/CSS;Ruby;SQL
#
#                       MiscTechDesireNextYear MiscTechWorkedWith  \
# Respondent
# 1                          .NET Core;Xamarin     .NET;.NET Core
# 2           React Native;TensorFlow;Unity 3D       React Native
# 3                                        NaN                NaN
# 4                                        NaN                NaN
# 5                               Ansible;Chef            Ansible
#
#                       NEWCollabToolsDesireNextYear  \
# Respondent
# 1           Microsoft Teams;Microsoft Azure;Trello
# 2                                     Github;Slack
# 3                                              NaN
# 4                                              NaN
# 5            Github;Google Suite (Docs, Meet, etc)
#
#                                      NEWCollabToolsWorkedWith NEWDevOps  \
# Respondent
# 1                Confluence;Jira;Slack;Microsoft Azure;Trello        No
# 2                         Confluence;Jira;Github;Gitlab;Slack       NaN
# 3                                                         NaN       NaN
# 4                                                         NaN        No
# 5           Confluence;Jira;Github;Slack;Google Suite (Doc...       NaN
#
#                  NEWDevOpsImpt                           NEWEdImpt  \
# Respondent
# 1           Somewhat important                    Fairly important
# 2                          NaN                    Fairly important
# 3                          NaN                                 NaN
# 4                          NaN  Not at all important/not necessary
# 5                          NaN                      Very important
#
#                                                    NEWJobHunt  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4           Curious about other opportunities;Wanting to w...
# 5                                                         NaN
#
#            NEWJobHuntResearch       NEWLearn NEWOffTopic NEWOnboardGood  \
# Respondent
# 1                         NaN    Once a year    Not sure            NaN
# 2                         NaN    Once a year    Not sure            NaN
# 3                         NaN  Once a decade         NaN            NaN
# 4                         NaN    Once a year    Not sure            Yes
# 5                         NaN    Once a year          No            NaN
#
#            NEWOtherComms                                        NEWOvertime  \
# Respondent
# 1                     No                   Often: 1-2 days per week or more
# 2                     No                                                NaN
# 3                     No                                                NaN
# 4                    Yes  Occasionally: 1-2 days per quarter but less th...
# 5                    Yes                                                NaN
#
#                                           NEWPurchaseResearch  \
# Respondent
# 1           Start a free trial;Ask developers I know/work ...
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
# 5           Start a free trial;Ask developers I know/work ...
#
#                 NEWPurpleLink  \
# Respondent
# 1                      Amused
# 2                      Amused
# 3                         NaN
# 4                         NaN
# 5           Hello, old friend
#
#                                                    NEWSOSites  \
# Respondent
# 1            Stack Overflow (public Q&A for anyone who codes)
# 2           Stack Overflow (public Q&A for anyone who code...
# 3            Stack Overflow (public Q&A for anyone who codes)
# 4           Stack Overflow (public Q&A for anyone who code...
# 5           Stack Overflow (public Q&A for anyone who code...
#
#                                                      NEWStuck        OpSys  \
# Respondent
# 1           Visit Stack Overflow;Go for a walk or other ph...      Windows
# 2           Visit Stack Overflow;Go for a walk or other ph...        MacOS
# 3                                                         NaN  Linux-based
# 4                                                         NaN  Linux-based
# 5           Call a coworker or friend;Visit Stack Overflow...      Windows
#
#                              OrgSize  \
# Respondent
# 1                   2 to 9 employees
# 2           1,000 to 4,999 employees
# 3                                NaN
# 4                 20 to 99 employees
# 5                                NaN
#
#                                        PlatformDesireNextYear  \
# Respondent
# 1              Android;iOS;Kubernetes;Microsoft Azure;Windows
# 2                                  iOS;Kubernetes;Linux;MacOS
# 3                                                         NaN
# 4                                                         NaN
# 5           Docker;Google Cloud Platform;Heroku;Linux;Windows
#
#                         PlatformWorkedWith                      PurchaseWhat  \
# Respondent
# 1                                  Windows                               NaN
# 2                                      iOS     I have little or no influence
# 3                                      NaN                               NaN
# 4                                      NaN  I have a great deal of influence
# 5           AWS;Docker;Linux;MacOS;Windows                               NaN
#
#                           Sexuality SOAccount           SOComm  \
# Respondent
# 1           Straight / Heterosexual        No   No, not at all
# 2                               NaN       Yes  Yes, definitely
# 3                               NaN       Yes    Yes, somewhat
# 4           Straight / Heterosexual       Yes  Yes, definitely
# 5           Straight / Heterosexual       Yes    Yes, somewhat
#
#                                      SOPartFreq  \
# Respondent
# 1                                           NaN
# 2           Less than once per month or monthly
# 3               A few times per month or weekly
# 4               A few times per month or weekly
# 5           Less than once per month or monthly
#
#                                 SOVisitFreq                  SurveyEase  \
# Respondent
# 1                    Multiple times per day  Neither easy nor difficult
# 2                    Multiple times per day                         NaN
# 3                     Daily or almost daily  Neither easy nor difficult
# 4                    Multiple times per day                         NaN
# 5           A few times per month or weekly                        Easy
#
#                      SurveyLength Trans  \
# Respondent
# 1           Appropriate in length    No
# 2                             NaN   NaN
# 3           Appropriate in length   NaN
# 4                             NaN    No
# 5                       Too short    No
#
#                                                UndergradMajor  \
# Respondent
# 1           Computer science, computer engineering, or sof...
# 2           Computer science, computer engineering, or sof...
# 3                                                         NaN
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
#
#            WebframeDesireNextYear    WebframeWorkedWith  \
# Respondent
# 1                    ASP.NET Core  ASP.NET;ASP.NET Core
# 2                             NaN                   NaN
# 3                             NaN                   NaN
# 4                             NaN                   NaN
# 5            Django;Ruby on Rails         Ruby on Rails
#
#                                        WelcomeChange  WorkWeekHrs YearsCode  \
# Respondent
# 1            Just as welcome now as I felt last year         50.0        36
# 2           Somewhat more welcome now than last year          NaN         7
# 3           Somewhat more welcome now than last year          NaN         4
# 4           Somewhat less welcome now than last year         40.0         7
# 5            Just as welcome now as I felt last year          NaN        15
#
#            YearsCodePro
# Respondent
# 1                    27
# 2                     4
# 3                   NaN
# 4                     4
# 5                     8

# %%
df.shape
# Out:
# (64461, 60)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64461 entries, 1 to 65112
# Data columns (total 60 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   MainBranch                    64162 non-null  object
#  1   Hobbyist                      64416 non-null  object
#  2   Age                           45446 non-null  float64
#  3   Age1stCode                    57900 non-null  object
#  4   CompFreq                      40069 non-null  object
#  5   CompTotal                     34826 non-null  float64
#  6   ConvertedComp                 34756 non-null  float64
#  7   Country                       64072 non-null  object
#  8   CurrencyDesc                  45472 non-null  object
#  9   CurrencySymbol                45472 non-null  object
#  10  DatabaseDesireNextYear        44070 non-null  object
#  11  DatabaseWorkedWith            49537 non-null  object
#  12  DevType                       49370 non-null  object
#  13  EdLevel                       57431 non-null  object
#  14  Employment                    63854 non-null  object
#  15  Ethnicity                     45948 non-null  object
#  16  Gender                        50557 non-null  object
#  17  JobFactors                    49349 non-null  object
#  18  JobSat                        45194 non-null  object
#  19  JobSeek                       51727 non-null  object
#  20  LanguageDesireNextYear        54113 non-null  object
#  21  LanguageWorkedWith            57378 non-null  object
#  22  MiscTechDesireNextYear        42379 non-null  object
#  23  MiscTechWorkedWith            40314 non-null  object
#  24  NEWCollabToolsDesireNextYear  47287 non-null  object
#  25  NEWCollabToolsWorkedWith      52883 non-null  object
#  26  NEWDevOps                     42686 non-null  object
#  27  NEWDevOpsImpt                 41732 non-null  object
#  28  NEWEdImpt                     48465 non-null  object
#  29  NEWJobHunt                    42286 non-null  object
#  30  NEWJobHuntResearch            41022 non-null  object
#  31  NEWLearn                      56156 non-null  object
#  32  NEWOffTopic                   50804 non-null  object
#  33  NEWOnboardGood                42623 non-null  object
#  34  NEWOtherComms                 57205 non-null  object
#  35  NEWOvertime                   43231 non-null  object
#  36  NEWPurchaseResearch           37321 non-null  object
#  37  NEWPurpleLink                 54803 non-null  object
#  38  NEWSOSites                    58275 non-null  object
#  39  NEWStuck                      54983 non-null  object
#  40  OpSys                         56228 non-null  object
#  41  OrgSize                       44334 non-null  object
#  42  PlatformDesireNextYear        50605 non-null  object
#  43  PlatformWorkedWith            53843 non-null  object
#  44  PurchaseWhat                  39364 non-null  object
#  45  Sexuality                     43992 non-null  object
#  46  SOAccount                     56805 non-null  object
#  47  SOComm                        56476 non-null  object
#  48  SOPartFreq                    46792 non-null  object
#  49  SOVisitFreq                   56970 non-null  object
#  50  SurveyEase                    51802 non-null  object
#  51  SurveyLength                  51701 non-null  object
#  52  Trans                         49345 non-null  object
#  53  UndergradMajor                50995 non-null  object
#  54  WebframeDesireNextYear        40024 non-null  object
#  55  WebframeWorkedWith            42279 non-null  object
#  56  WelcomeChange                 52683 non-null  object
#  57  WorkWeekHrs                   41151 non-null  float64
#  58  YearsCode                     64461 non-null  object
#  59  YearsCodePro                  46349 non-null  object
# dtypes: float64(4), object(56)
# memory usage: 30.0+ MB

# %%
pd.set_option('display.max_columns', 101)
pd.set_option('display.max_rows', 101)

# %%
schema_df = pd.read_csv('data/survey_results_schema.csv')

# %%
schema_df
# Out:
#                           Column  \
# 0                     Respondent
# 1                     MainBranch
# 2                       Hobbyist
# 3                            Age
# 4                     Age1stCode
# 5                       CompFreq
# 6                      CompTotal
# 7                  ConvertedComp
# 8                        Country
# 9                   CurrencyDesc
# 10                CurrencySymbol
# 11        DatabaseDesireNextYear
# 12            DatabaseWorkedWith
# 13                       DevType
# 14                       EdLevel
# 15                    Employment
# 16                     Ethnicity
# 17                        Gender
# 18                    JobFactors
# 19                        JobSat
# 20                       JobSeek
# 21        LanguageDesireNextYear
# 22            LanguageWorkedWith
# 23        MiscTechDesireNextYear
# 24            MiscTechWorkedWith
# 25  NEWCollabToolsDesireNextYear
# 26      NEWCollabToolsWorkedWith
# 27                     NEWDevOps
# 28                 NEWDevOpsImpt
# 29                     NEWEdImpt
# 30                    NEWJobHunt
# 31            NEWJobHuntResearch
# 32                      NEWLearn
# 33                   NEWOffTopic
# 34                NEWOnboardGood
# 35                 NEWOtherComms
# 36                   NEWOvertime
# 37           NEWPurchaseResearch
# 38                 NEWPurpleLink
# 39                    NEWSOSites
# 40                      NEWStuck
# 41                         OpSys
# 42                       OrgSize
# 43        PlatformDesireNextYear
# 44            PlatformWorkedWith
# 45                  PurchaseWhat
# 46                     Sexuality
# 47                     SOAccount
# 48                        SOComm
# 49                    SOPartFreq
# 50                   SOVisitFreq
# 51                    SurveyEase
# 52                  SurveyLength
# 53                         Trans
# 54                UndergradMajor
# 55        WebframeDesireNextYear
# 56            WebframeWorkedWith
# 57                 WelcomeChange
# 58                   WorkWeekHrs
# 59                     YearsCode
# 60                  YearsCodePro
#
#                                          QuestionText
# 0   Randomized respondent ID number (not in order ...
# 1   Which of the following options best describes ...
# 2                             Do you code as a hobby?
# 3   What is your age (in years)? If you prefer not...
# 4   At what age did you write your first line of c...
# 5    Is that compensation weekly, monthly, or yearly?
# 6   What is your current total compensation (salar...
# 7   Salary converted to annual USD salaries using ...
# 8                                  Where do you live?
# 9   Which currency do you use day-to-day? If your ...
# 10  Which currency do you use day-to-day? If your ...
# 11  Which database environments have you done exte...
# 12  Which database environments have you done exte...
# 13  Which of the following describe you? Please se...
# 14  Which of the following best describes the high...
# 15  Which of the following best describes your cur...
# 16  Which of the following describe you, if any? P...
# 17  Which of the following describe you, if any? P...
# 18  Imagine that you are deciding between two job ...
# 19  How satisfied are you with your current job? (...
# 20  Which of the following best describes your cur...
# 21  Which programming, scripting, and markup langu...
# 22  Which programming, scripting, and markup langu...
# 23  Which other frameworks, libraries, and tools h...
# 24  Which other frameworks, libraries, and tools h...
# 25  Which collaboration tools have you done extens...
# 26  Which collaboration tools have you done extens...
# 27  Does your company have a dedicated DevOps person?
# 28  How important is the practice of DevOps to sca...
# 29  How important is a formal education, such as a...
# 30  In general, what drives you to look for a new ...
# 31  When job searching, how do you learn more abou...
# 32  How frequently do you learn a new language or ...
# 33  Do you think Stack Overflow should relax restr...
# 34  Do you think your company has a good onboardin...
# 35  Are you a member of any other online developer...
# 36  How often do you work overtime or beyond the f...
# 37  When buying a new tool or software, how do you...
# 38  You search for a coding solution online and th...
# 39  Which of the following Stack Overflow sites ha...
# 40  What do you do when you get stuck on a problem...
# 41  What is the primary operating system in which ...
# 42  Approximately how many people are employed by ...
# 43  Which platforms have you done extensive develo...
# 44  Which platforms have you done extensive develo...
# 45  What level of influence do you, personally, ha...
# 46  Which of the following describe you, if any? P...
# 47              Do you have a Stack Overflow account?
# 48  Do you consider yourself a member of the Stack...
# 49  How frequently would you say you participate i...
# 50  How frequently would you say you visit Stack O...
# 51  How easy or difficult was this survey to compl...
# 52  How do you feel about the length of the survey...
# 53                               Are you transgender?
# 54              What was your primary field of study?
# 55  Which web frameworks have you done extensive d...
# 56  Which web frameworks have you done extensive d...
# 57  Compared to last year, how welcome do you feel...
# 58  On average, how many hours per week do you wor...
# 59  Including any education, how many years have y...
# 60  NOT including education, how many years have y...

# %%
df.shape
# Out:
# (64461, 60)

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq', 'CompTotal',
#        'ConvertedComp', 'Country', 'CurrencyDesc', 'CurrencySymbol',
#        'DatabaseDesireNextYear', 'DatabaseWorkedWith', 'DevType', 'EdLevel',
#        'Employment', 'Ethnicity', 'Gender', 'JobFactors', 'JobSat', 'JobSeek',
#        'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
#        'Trans', 'UndergradMajor', 'WebframeDesireNextYear',
#        'WebframeWorkedWith', 'WelcomeChange', 'WorkWeekHrs', 'YearsCode',
#        'YearsCodePro'],
#       dtype='object')

# %%
df[['Hobbyist', 'Country']]
# Out:
#            Hobbyist             Country
# Respondent
# 1               Yes             Germany
# 2                No      United Kingdom
# 3               Yes  Russian Federation
# 4               Yes             Albania
# 5               Yes       United States
# ...             ...                 ...
# 64858           Yes       United States
# 64867           Yes             Morocco
# 64898           Yes            Viet Nam
# 64925           Yes              Poland
# 65112           Yes               Spain
#
# [64461 rows x 2 columns]

# %%
df[['Hobbyist']].value_counts()
# Out:
# Hobbyist
# Yes         50388
# No          14028
# dtype: int64

# %%
df[['PlatformWorkedWith']].value_counts()
# Out:
# PlatformWorkedWith
# Windows                                                                              4770
# Linux;Windows                                                                        2461
# Linux                                                                                2112
# Android                                                                              1201
# Microsoft Azure;Windows                                                               996
#                                                                                      ...
# Android;Docker;iOS;MacOS;Raspberry Pi;Slack Apps and Integrations                       1
# Android;AWS;Docker;iOS;Raspberry Pi;WordPress                                           1
# Android;Docker;iOS;MacOS;Raspberry Pi;Windows;WordPress                                 1
# Android;Docker;iOS;MacOS;Raspberry Pi;WordPress                                         1
# Arduino;AWS;Docker;Google Cloud Platform;Kubernetes;Linux;Microsoft Azure;Windows       1
# Length: 6287, dtype: int64

# %%
#df.loc[0:38, 'Hobbyist':'Country']

# %%
df['Country'] == 'Brazil'
# Out:
# Respondent
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 64858    False
# 64867    False
# 64898    False
# 64925    False
# 65112    False
# Name: Country, Length: 64461, dtype: bool

# %%
#df.loc[0:38, ['Hobbyist', 'Country']]

# %%
df.set_index('Country')
# Out:
#
# Germany                  Confluence;Jira;Slack;Microsoft Azure;Trello
# United Kingdom                    Confluence;Jira;Github;Gitlab;Slack
# Russian Federation                                                NaN
# Albania                                                           NaN
# United States       Confluence;Jira;Github;Slack;Google Suite (Doc...
# ...                                                               ...
# United States                                                     NaN
# Morocco                                                           NaN
# Viet Nam                                                          NaN
# Poland                          Confluence;Jira;Slack;Microsoft Teams
# Spain                                                          Github
#
#                    NEWDevOps       NEWDevOpsImpt  \
# Country
# Germany                   No  Somewhat important
# United Kingdom           NaN                 NaN
# Russian Federation       NaN                 NaN
# Albania                   No                 NaN
# United States            NaN                 NaN
# ...                      ...                 ...
# United States            NaN                 NaN
# Morocco                  NaN                 NaN
# Viet Nam                 NaN                 NaN
# Poland                   NaN                 NaN
# Spain                    NaN                 NaN
#
#                                              NEWEdImpt  \
# Country
# Germany                               Fairly important
# United Kingdom                        Fairly important
# Russian Federation                                 NaN
# Albania             Not at all important/not necessary
# United States                           Very important
# ...                                                ...
# United States                           Very important
# Morocco                                            NaN
# Viet Nam                                           NaN
# Poland                                             NaN
# Spain                             Critically important
#
#                                                            NEWJobHunt  \
# Country
# Germany                                                           NaN
# United Kingdom                                                    NaN
# Russian Federation                                                NaN
# Albania             Curious about other opportunities;Wanting to w...
# United States                                                     NaN
# ...                                                               ...
# United States                                                     NaN
# Morocco                                                           NaN
# Viet Nam                                                          NaN
# Poland                                                            NaN
# Spain                                                             NaN
#
#                    NEWJobHuntResearch       NEWLearn NEWOffTopic  \
# Country
# Germany                           NaN    Once a year    Not sure
# United Kingdom                    NaN    Once a year    Not sure
# Russian Federation                NaN  Once a decade         NaN
# Albania                           NaN    Once a year    Not sure
# United States                     NaN    Once a year          No
# ...                               ...            ...         ...
# United States                     NaN  Once a decade         NaN
# Morocco                           NaN            NaN         NaN
# Viet Nam                          NaN            NaN         NaN
# Poland                            NaN    Once a year         NaN
# Spain                             NaN    Once a year         NaN
#
#                    NEWOnboardGood NEWOtherComms  \
# Country
# Germany                       NaN            No
# United Kingdom                NaN            No
# Russian Federation            NaN            No
# Albania                       Yes           Yes
# United States                 NaN           Yes
# ...                           ...           ...
# United States                 NaN           NaN
# Morocco                       NaN           NaN
# Viet Nam                      NaN           NaN
# Poland                        NaN           NaN
# Spain                         NaN           NaN
#
#                                                           NEWOvertime  \
# Country
# Germany                              Often: 1-2 days per week or more
# United Kingdom                                                    NaN
# Russian Federation                                                NaN
# Albania             Occasionally: 1-2 days per quarter but less th...
# United States                                                     NaN
# ...                                                               ...
# United States                                                     NaN
# Morocco                                                           NaN
# Viet Nam                                                          NaN
# Poland                                                            NaN
# Spain                                                             NaN
#
#                                                   NEWPurchaseResearch  \
# Country
# Germany             Start a free trial;Ask developers I know/work ...
# United Kingdom                                                    NaN
# Russian Federation                                                NaN
# Albania                                                           NaN
# United States       Start a free trial;Ask developers I know/work ...
# ...                                                               ...
# United States                                      Start a free trial
# Morocco                                                           NaN
# Viet Nam                                                          NaN
# Poland                                             Start a free trial
# Spain               Start a free trial;Ask developers I know/work ...
#
#                         NEWPurpleLink  \
# Country
# Germany                        Amused
# United Kingdom                 Amused
# Russian Federation                NaN
# Albania                           NaN
# United States       Hello, old friend
# ...                               ...
# United States                  Amused
# Morocco                           NaN
# Viet Nam                          NaN
# Poland              Hello, old friend
# Spain                     Indifferent
#
#                                                            NEWSOSites  \
# Country
# Germany              Stack Overflow (public Q&A for anyone who codes)
# United Kingdom      Stack Overflow (public Q&A for anyone who code...
# Russian Federation   Stack Overflow (public Q&A for anyone who codes)
# Albania             Stack Overflow (public Q&A for anyone who code...
# United States       Stack Overflow (public Q&A for anyone who code...
# ...                                                               ...
# United States        Stack Overflow (public Q&A for anyone who codes)
# Morocco                                                           NaN
# Viet Nam                                                          NaN
# Poland               Stack Overflow (public Q&A for anyone who codes)
# Spain                                                             NaN
#
#                                                              NEWStuck  \
# Country
# Germany             Visit Stack Overflow;Go for a walk or other ph...
# United Kingdom      Visit Stack Overflow;Go for a walk or other ph...
# Russian Federation                                                NaN
# Albania                                                           NaN
# United States       Call a coworker or friend;Visit Stack Overflow...
# ...                                                               ...
# United States                               Call a coworker or friend
# Morocco                                                           NaN
# Viet Nam                                                          NaN
# Poland                 Call a coworker or friend;Visit Stack Overflow
# Spain               Meditate;Visit Stack Overflow;Go for a walk or...
#
#                           OpSys                   OrgSize  \
# Country
# Germany                 Windows          2 to 9 employees
# United Kingdom            MacOS  1,000 to 4,999 employees
# Russian Federation  Linux-based                       NaN
# Albania             Linux-based        20 to 99 employees
# United States           Windows                       NaN
# ...                         ...                       ...
# United States           Windows                       NaN
# Morocco                     NaN                       NaN
# Viet Nam                    NaN                       NaN
# Poland                  Windows                       NaN
# Spain                   Windows                       NaN
#
#                                                PlatformDesireNextYear  \
# Country
# Germany                Android;iOS;Kubernetes;Microsoft Azure;Windows
# United Kingdom                             iOS;Kubernetes;Linux;MacOS
# Russian Federation                                                NaN
# Albania                                                           NaN
# United States       Docker;Google Cloud Platform;Heroku;Linux;Windows
# ...                                                               ...
# United States                                                     NaN
# Morocco                                                           NaN
# Viet Nam                                                          NaN
# Poland                                                            NaN
# Spain                              Arduino;Linux;Raspberry Pi;Windows
#
#                                             PlatformWorkedWith  \
# Country
# Germany                                                Windows
# United Kingdom                                             iOS
# Russian Federation                                         NaN
# Albania                                                    NaN
# United States                   AWS;Docker;Linux;MacOS;Windows
# ...                                                        ...
# United States                                              NaN
# Morocco                                                    NaN
# Viet Nam                                                   NaN
# Poland                                           Linux;Windows
# Spain               Android;Arduino;Linux;Raspberry Pi;Windows
#
#                                         PurchaseWhat                Sexuality  \
# Country
# Germany                                          NaN  Straight / Heterosexual
# United Kingdom         I have little or no influence                      NaN
# Russian Federation                               NaN                      NaN
# Albania             I have a great deal of influence  Straight / Heterosexual
# United States                                    NaN  Straight / Heterosexual
# ...                                              ...                      ...
# United States                                    NaN                      NaN
# Morocco                                          NaN                      NaN
# Viet Nam                                         NaN                      NaN
# Poland                                           NaN                      NaN
# Spain                                            NaN                      NaN
#
#                    SOAccount           SOComm  \
# Country
# Germany                   No   No, not at all
# United Kingdom           Yes  Yes, definitely
# Russian Federation       Yes    Yes, somewhat
# Albania                  Yes  Yes, definitely
# United States            Yes    Yes, somewhat
# ...                      ...              ...
# United States            NaN              NaN
# Morocco                  NaN              NaN
# Viet Nam                 NaN              NaN
# Poland                   NaN              NaN
# Spain                    NaN              NaN
#
#                                              SOPartFreq  \
# Country
# Germany                                             NaN
# United Kingdom      Less than once per month or monthly
# Russian Federation      A few times per month or weekly
# Albania                 A few times per month or weekly
# United States       Less than once per month or monthly
# ...                                                 ...
# United States                                       NaN
# Morocco                                             NaN
# Viet Nam                                            NaN
# Poland                                              NaN
# Spain                                               NaN
#
#                                         SOVisitFreq  \
# Country
# Germany                      Multiple times per day
# United Kingdom               Multiple times per day
# Russian Federation            Daily or almost daily
# Albania                      Multiple times per day
# United States       A few times per month or weekly
# ...                                             ...
# United States                                   NaN
# Morocco                                         NaN
# Viet Nam                                        NaN
# Poland                                          NaN
# Spain                                           NaN
#
#                                     SurveyEase           SurveyLength Trans  \
# Country
# Germany             Neither easy nor difficult  Appropriate in length    No
# United Kingdom                             NaN                    NaN   NaN
# Russian Federation  Neither easy nor difficult  Appropriate in length   NaN
# Albania                                    NaN                    NaN    No
# United States                             Easy              Too short    No
# ...                                        ...                    ...   ...
# United States                              NaN                    NaN   NaN
# Morocco                                    NaN                    NaN   NaN
# Viet Nam                                   NaN                    NaN   NaN
# Poland                                     NaN                    NaN   NaN
# Spain                                      NaN                    NaN   NaN
#
#                                                        UndergradMajor  \
# Country
# Germany             Computer science, computer engineering, or sof...
# United Kingdom      Computer science, computer engineering, or sof...
# Russian Federation                                                NaN
# Albania             Computer science, computer engineering, or sof...
# United States       Computer science, computer engineering, or sof...
# ...                                                               ...
# United States       Computer science, computer engineering, or sof...
# Morocco                                                           NaN
# Viet Nam                                                          NaN
# Poland                                                            NaN
# Spain               Computer science, computer engineering, or sof...
#
#                          WebframeDesireNextYear  \
# Country
# Germany                            ASP.NET Core
# United Kingdom                              NaN
# Russian Federation                          NaN
# Albania                                     NaN
# United States              Django;Ruby on Rails
# ...                                         ...
# United States                               NaN
# Morocco                                     NaN
# Viet Nam                                    NaN
# Poland              Angular;Angular.js;React.js
# Spain                       ASP.NET Core;jQuery
#
#                                         WebframeWorkedWith  \
# Country
# Germany                               ASP.NET;ASP.NET Core
# United Kingdom                                         NaN
# Russian Federation                                     NaN
# Albania                                                NaN
# United States                                Ruby on Rails
# ...                                                    ...
# United States                                          NaN
# Morocco                                                NaN
# Viet Nam                                               NaN
# Poland                                                 NaN
# Spain               Angular;Angular.js;ASP.NET Core;jQuery
#
#                                                WelcomeChange  WorkWeekHrs  \
# Country
# Germany              Just as welcome now as I felt last year         50.0
# United Kingdom      Somewhat more welcome now than last year          NaN
# Russian Federation  Somewhat more welcome now than last year          NaN
# Albania             Somewhat less welcome now than last year         40.0
# United States        Just as welcome now as I felt last year          NaN
# ...                                                      ...          ...
# United States                                            NaN          NaN
# Morocco                                                  NaN          NaN
# Viet Nam                                                 NaN          NaN
# Poland                                                   NaN          NaN
# Spain                                                    NaN          NaN
#
#                    YearsCode      YearsCodePro
# Country
# Germany                   36                27
# United Kingdom             7                 4
# Russian Federation         4               NaN
# Albania                    7                 4
# United States             15                 8
# ...                      ...               ...
# United States             10  Less than 1 year
# Morocco                  nan               NaN
# Viet Nam                 nan               NaN
# Poland                   nan               NaN
# Spain                    nan               NaN
#
# [64461 rows x 59 columns]

# %%
df
# Out:
#                                                      NaN
# 5                                             Java;Ruby;Scala
# ...                                                       ...
# 64858                                                     NaN
# 64867       Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64898                                                     NaN
# 64925                                HTML/CSS;Java;JavaScript
# 65112                         C#;HTML/CSS;Java;JavaScript;SQL
#
#                                            LanguageWorkedWith  \
# Respondent
# 1                                      C#;HTML/CSS;JavaScript
# 2                                            JavaScript;Swift
# 3                                    Objective-C;Python;Swift
# 4                                                         NaN
# 5                                           HTML/CSS;Ruby;SQL
# ...                                                       ...
# 64858                                                     NaN
# 64867       Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64898                                                     NaN
# 64925                                                HTML/CSS
# 65112                         C#;HTML/CSS;Java;JavaScript;SQL
#
#                       MiscTechDesireNextYear MiscTechWorkedWith  \
# Respondent
# 1                          .NET Core;Xamarin     .NET;.NET Core
# 2           React Native;TensorFlow;Unity 3D       React Native
# 3                                        NaN                NaN
# 4                                        NaN                NaN
# 5                               Ansible;Chef            Ansible
# ...                                      ...                ...
# 64858                                    NaN                NaN
# 64867                                    NaN                NaN
# 64898                                    NaN                NaN
# 64925                                Node.js                NaN
# 65112                      .NET Core;Xamarin     .NET;.NET Core
#
#                       NEWCollabToolsDesireNextYear  \
# Respondent
# 1           Microsoft Teams;Microsoft Azure;Trello
# 2                                     Github;Slack
# 3                                              NaN
# 4                                              NaN
# 5            Github;Google Suite (Docs, Meet, etc)
# ...                                            ...
# 64858                                          NaN
# 64867                                          NaN
# 64898                                          NaN
# 64925                                Github;Gitlab
# 65112                       Github;Microsoft Teams
#
#                                      NEWCollabToolsWorkedWith NEWDevOps  \
# Respondent
# 1                Confluence;Jira;Slack;Microsoft Azure;Trello        No
# 2                         Confluence;Jira;Github;Gitlab;Slack       NaN
# 3                                                         NaN       NaN
# 4                                                         NaN        No
# 5           Confluence;Jira;Github;Slack;Google Suite (Doc...       NaN
# ...                                                       ...       ...
# 64858                                                     NaN       NaN
# 64867                                                     NaN       NaN
# 64898                                                     NaN       NaN
# 64925                   Confluence;Jira;Slack;Microsoft Teams       NaN
# 65112                                                  Github       NaN
#
#                  NEWDevOpsImpt                           NEWEdImpt  \
# Respondent
# 1           Somewhat important                    Fairly important
# 2                          NaN                    Fairly important
# 3                          NaN                                 NaN
# 4                          NaN  Not at all important/not necessary
# 5                          NaN                      Very important
# ...                        ...                                 ...
# 64858                      NaN                      Very important
# 64867                      NaN                                 NaN
# 64898                      NaN                                 NaN
# 64925                      NaN                                 NaN
# 65112                      NaN                Critically important
#
#                                                    NEWJobHunt  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4           Curious about other opportunities;Wanting to w...
# 5                                                         NaN
# ...                                                       ...
# 64858                                                     NaN
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                                     NaN
# 65112                                                     NaN
#
#            NEWJobHuntResearch       NEWLearn NEWOffTopic NEWOnboardGood  \
# Respondent
# 1                         NaN    Once a year    Not sure            NaN
# 2                         NaN    Once a year    Not sure            NaN
# 3                         NaN  Once a decade         NaN            NaN
# 4                         NaN    Once a year    Not sure            Yes
# 5                         NaN    Once a year          No            NaN
# ...                       ...            ...         ...            ...
# 64858                     NaN  Once a decade         NaN            NaN
# 64867                     NaN            NaN         NaN            NaN
# 64898                     NaN            NaN         NaN            NaN
# 64925                     NaN    Once a year         NaN            NaN
# 65112                     NaN    Once a year         NaN            NaN
#
#            NEWOtherComms                                        NEWOvertime  \
# Respondent
# 1                     No                   Often: 1-2 days per week or more
# 2                     No                                                NaN
# 3                     No                                                NaN
# 4                    Yes  Occasionally: 1-2 days per quarter but less th...
# 5                    Yes                                                NaN
# ...                  ...                                                ...
# 64858                NaN                                                NaN
# 64867                NaN                                                NaN
# 64898                NaN                                                NaN
# 64925                NaN                                                NaN
# 65112                NaN                                                NaN
#
#                                           NEWPurchaseResearch  \
# Respondent
# 1           Start a free trial;Ask developers I know/work ...
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
# 5           Start a free trial;Ask developers I know/work ...
# ...                                                       ...
# 64858                                      Start a free trial
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                      Start a free trial
# 65112       Start a free trial;Ask developers I know/work ...
#
#                 NEWPurpleLink  \
# Respondent
# 1                      Amused
# 2                      Amused
# 3                         NaN
# 4                         NaN
# 5           Hello, old friend
# ...                       ...
# 64858                  Amused
# 64867                     NaN
# 64898                     NaN
# 64925       Hello, old friend
# 65112             Indifferent
#
#                                                    NEWSOSites  \
# Respondent
# 1            Stack Overflow (public Q&A for anyone who codes)
# 2           Stack Overflow (public Q&A for anyone who code...
# 3            Stack Overflow (public Q&A for anyone who codes)
# 4           Stack Overflow (public Q&A for anyone who code...
# 5           Stack Overflow (public Q&A for anyone who code...
# ...                                                       ...
# 64858        Stack Overflow (public Q&A for anyone who codes)
# 64867                                                     NaN
# 64898                                                     NaN
# 64925        Stack Overflow (public Q&A for anyone who codes)
# 65112                                                     NaN
#
#                                                      NEWStuck        OpSys  \
# Respondent
# 1           Visit Stack Overflow;Go for a walk or other ph...      Windows
# 2           Visit Stack Overflow;Go for a walk or other ph...        MacOS
# 3                                                         NaN  Linux-based
# 4                                                         NaN  Linux-based
# 5           Call a coworker or friend;Visit Stack Overflow...      Windows
# ...                                                       ...          ...
# 64858                               Call a coworker or friend      Windows
# 64867                                                     NaN          NaN
# 64898                                                     NaN          NaN
# 64925          Call a coworker or friend;Visit Stack Overflow      Windows
# 65112       Meditate;Visit Stack Overflow;Go for a walk or...      Windows
#
#                              OrgSize  \
# Respondent
# 1                   2 to 9 employees
# 2           1,000 to 4,999 employees
# 3                                NaN
# 4                 20 to 99 employees
# 5                                NaN
# ...                              ...
# 64858                            NaN
# 64867                            NaN
# 64898                            NaN
# 64925                            NaN
# 65112                            NaN
#
#                                        PlatformDesireNextYear  \
# Respondent
# 1              Android;iOS;Kubernetes;Microsoft Azure;Windows
# 2                                  iOS;Kubernetes;Linux;MacOS
# 3                                                         NaN
# 4                                                         NaN
# 5           Docker;Google Cloud Platform;Heroku;Linux;Windows
# ...                                                       ...
# 64858                                                     NaN
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                                     NaN
# 65112                      Arduino;Linux;Raspberry Pi;Windows
#
#                                     PlatformWorkedWith  \
# Respondent
# 1                                              Windows
# 2                                                  iOS
# 3                                                  NaN
# 4                                                  NaN
# 5                       AWS;Docker;Linux;MacOS;Windows
# ...                                                ...
# 64858                                              NaN
# 64867                                              NaN
# 64898                                              NaN
# 64925                                    Linux;Windows
# 65112       Android;Arduino;Linux;Raspberry Pi;Windows
#
#                                 PurchaseWhat                Sexuality  \
# Respondent
# 1                                        NaN  Straight / Heterosexual
# 2              I have little or no influence                      NaN
# 3                                        NaN                      NaN
# 4           I have a great deal of influence  Straight / Heterosexual
# 5                                        NaN  Straight / Heterosexual
# ...                                      ...                      ...
# 64858                                    NaN                      NaN
# 64867                                    NaN                      NaN
# 64898                                    NaN                      NaN
# 64925                                    NaN                      NaN
# 65112                                    NaN                      NaN
#
#            SOAccount           SOComm                           SOPartFreq  \
# Respondent
# 1                 No   No, not at all                                  NaN
# 2                Yes  Yes, definitely  Less than once per month or monthly
# 3                Yes    Yes, somewhat      A few times per month or weekly
# 4                Yes  Yes, definitely      A few times per month or weekly
# 5                Yes    Yes, somewhat  Less than once per month or monthly
# ...              ...              ...                                  ...
# 64858            NaN              NaN                                  NaN
# 64867            NaN              NaN                                  NaN
# 64898            NaN              NaN                                  NaN
# 64925            NaN              NaN                                  NaN
# 65112            NaN              NaN                                  NaN
#
#                                 SOVisitFreq                  SurveyEase  \
# Respondent
# 1                    Multiple times per day  Neither easy nor difficult
# 2                    Multiple times per day                         NaN
# 3                     Daily or almost daily  Neither easy nor difficult
# 4                    Multiple times per day                         NaN
# 5           A few times per month or weekly                        Easy
# ...                                     ...                         ...
# 64858                                   NaN                         NaN
# 64867                                   NaN                         NaN
# 64898                                   NaN                         NaN
# 64925                                   NaN                         NaN
# 65112                                   NaN                         NaN
#
#                      SurveyLength Trans  \
# Respondent
# 1           Appropriate in length    No
# 2                             NaN   NaN
# 3           Appropriate in length   NaN
# 4                             NaN    No
# 5                       Too short    No
# ...                           ...   ...
# 64858                         NaN   NaN
# 64867                         NaN   NaN
# 64898                         NaN   NaN
# 64925                         NaN   NaN
# 65112                         NaN   NaN
#
#                                                UndergradMajor  \
# Respondent
# 1           Computer science, computer engineering, or sof...
# 2           Computer science, computer engineering, or sof...
# 3                                                         NaN
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
# ...                                                       ...
# 64858       Computer science, computer engineering, or sof...
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                                     NaN
# 65112       Computer science, computer engineering, or sof...
#
#                  WebframeDesireNextYear  \
# Respondent
# 1                          ASP.NET Core
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                  Django;Ruby on Rails
# ...                                 ...
# 64858                               NaN
# 64867                               NaN
# 64898                               NaN
# 64925       Angular;Angular.js;React.js
# 65112               ASP.NET Core;jQuery
#
#                                 WebframeWorkedWith  \
# Respondent
# 1                             ASP.NET;ASP.NET Core
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# 5                                    Ruby on Rails
# ...                                            ...
# 64858                                          NaN
# 64867                                          NaN
# 64898                                          NaN
# 64925                                          NaN
# 65112       Angular;Angular.js;ASP.NET Core;jQuery
#
#                                        WelcomeChange  WorkWeekHrs YearsCode  \
# Respondent
# 1            Just as welcome now as I felt last year         50.0        36
# 2           Somewhat more welcome now than last year          NaN         7
# 3           Somewhat more welcome now than last year          NaN         4
# 4           Somewhat less welcome now than last year         40.0         7
# 5            Just as welcome now as I felt last year          NaN        15
# ...                                              ...          ...       ...
# 64858                                            NaN          NaN        10
# 64867                                            NaN          NaN       nan
# 64898                                            NaN          NaN       nan
# 64925                                            NaN          NaN       nan
# 65112                                            NaN          NaN       nan
#
#                 YearsCodePro
# Respondent
# 1                         27
# 2                          4
# 3                        NaN
# 4                          4
# 5                          8
# ...                      ...
# 64858       Less than 1 year
# 64867                    NaN
# 64898                    NaN
# 64925                    NaN
# 65112                    NaN
#
# [64461 rows x 60 columns]

# %%
#df.loc[0:38, ['Hobbyist', 'Country']]

# %%
schema_df
# Out:
#                           Column  \
# 0                     Respondent
# 1                     MainBranch
# 2                       Hobbyist
# 3                            Age
# 4                     Age1stCode
# 5                       CompFreq
# 6                      CompTotal
# 7                  ConvertedComp
# 8                        Country
# 9                   CurrencyDesc
# 10                CurrencySymbol
# 11        DatabaseDesireNextYear
# 12            DatabaseWorkedWith
# 13                       DevType
# 14                       EdLevel
# 15                    Employment
# 16                     Ethnicity
# 17                        Gender
# 18                    JobFactors
# 19                        JobSat
# 20                       JobSeek
# 21        LanguageDesireNextYear
# 22            LanguageWorkedWith
# 23        MiscTechDesireNextYear
# 24            MiscTechWorkedWith
# 25  NEWCollabToolsDesireNextYear
# 26      NEWCollabToolsWorkedWith
# 27                     NEWDevOps
# 28                 NEWDevOpsImpt
# 29                     NEWEdImpt
# 30                    NEWJobHunt
# 31            NEWJobHuntResearch
# 32                      NEWLearn
# 33                   NEWOffTopic
# 34                NEWOnboardGood
# 35                 NEWOtherComms
# 36                   NEWOvertime
# 37           NEWPurchaseResearch
# 38                 NEWPurpleLink
# 39                    NEWSOSites
# 40                      NEWStuck
# 41                         OpSys
# 42                       OrgSize
# 43        PlatformDesireNextYear
# 44            PlatformWorkedWith
# 45                  PurchaseWhat
# 46                     Sexuality
# 47                     SOAccount
# 48                        SOComm
# 49                    SOPartFreq
# 50                   SOVisitFreq
# 51                    SurveyEase
# 52                  SurveyLength
# 53                         Trans
# 54                UndergradMajor
# 55        WebframeDesireNextYear
# 56            WebframeWorkedWith
# 57                 WelcomeChange
# 58                   WorkWeekHrs
# 59                     YearsCode
# 60                  YearsCodePro
#
#                                          QuestionText
# 0   Randomized respondent ID number (not in order ...
# 1   Which of the following options best describes ...
# 2                             Do you code as a hobby?
# 3   What is your age (in years)? If you prefer not...
# 4   At what age did you write your first line of c...
# 5    Is that compensation weekly, monthly, or yearly?
# 6   What is your current total compensation (salar...
# 7   Salary converted to annual USD salaries using ...
# 8                                  Where do you live?
# 9   Which currency do you use day-to-day? If your ...
# 10  Which currency do you use day-to-day? If your ...
# 11  Which database environments have you done exte...
# 12  Which database environments have you done exte...
# 13  Which of the following describe you? Please se...
# 14  Which of the following best describes the high...
# 15  Which of the following best describes your cur...
# 16  Which of the following describe you, if any? P...
# 17  Which of the following describe you, if any? P...
# 18  Imagine that you are deciding between two job ...
# 19  How satisfied are you with your current job? (...
# 20  Which of the following best describes your cur...
# 21  Which programming, scripting, and markup langu...
# 22  Which programming, scripting, and markup langu...
# 23  Which other frameworks, libraries, and tools h...
# 24  Which other frameworks, libraries, and tools h...
# 25  Which collaboration tools have you done extens...
# 26  Which collaboration tools have you done extens...
# 27  Does your company have a dedicated DevOps person?
# 28  How important is the practice of DevOps to sca...
# 29  How important is a formal education, such as a...
# 30  In general, what drives you to look for a new ...
# 31  When job searching, how do you learn more abou...
# 32  How frequently do you learn a new language or ...
# 33  Do you think Stack Overflow should relax restr...
# 34  Do you think your company has a good onboardin...
# 35  Are you a member of any other online developer...
# 36  How often do you work overtime or beyond the f...
# 37  When buying a new tool or software, how do you...
# 38  You search for a coding solution online and th...
# 39  Which of the following Stack Overflow sites ha...
# 40  What do you do when you get stuck on a problem...
# 41  What is the primary operating system in which ...
# 42  Approximately how many people are employed by ...
# 43  Which platforms have you done extensive develo...
# 44  Which platforms have you done extensive develo...
# 45  What level of influence do you, personally, ha...
# 46  Which of the following describe you, if any? P...
# 47              Do you have a Stack Overflow account?
# 48  Do you consider yourself a member of the Stack...
# 49  How frequently would you say you participate i...
# 50  How frequently would you say you visit Stack O...
# 51  How easy or difficult was this survey to compl...
# 52  How do you feel about the length of the survey...
# 53                               Are you transgender?
# 54              What was your primary field of study?
# 55  Which web frameworks have you done extensive d...
# 56  Which web frameworks have you done extensive d...
# 57  Compared to last year, how welcome do you feel...
# 58  On average, how many hours per week do you wor...
# 59  Including any education, how many years have y...
# 60  NOT including education, how many years have y...

# %%
schema_df.columns
# Out:
# Index(['Column', 'QuestionText'], dtype='object')

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')

# %%
schema_df.sort_index()
# Out:
#                                                                    QuestionText
# Column
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# DatabaseDesireNextYear        Which database environments have you done exte...
# DatabaseWorkedWith            Which database environments have you done exte...
# DevType                       Which of the following describe you? Please se...
# EdLevel                       Which of the following best describes the high...
# Employment                    Which of the following best describes your cur...
# Ethnicity                     Which of the following describe you, if any? P...
# Gender                        Which of the following describe you, if any? P...
# Hobbyist                                                Do you code as a hobby?
# JobFactors                    Imagine that you are deciding between two job ...
# JobSat                        How satisfied are you with your current job? (...
# JobSeek                       Which of the following best describes your cur...
# LanguageDesireNextYear        Which programming, scripting, and markup langu...
# LanguageWorkedWith            Which programming, scripting, and markup langu...
# MainBranch                    Which of the following options best describes ...
# MiscTechDesireNextYear        Which other frameworks, libraries, and tools h...
# MiscTechWorkedWith            Which other frameworks, libraries, and tools h...
# NEWCollabToolsDesireNextYear  Which collaboration tools have you done extens...
# NEWCollabToolsWorkedWith      Which collaboration tools have you done extens...
# NEWDevOps                     Does your company have a dedicated DevOps person?
# NEWDevOpsImpt                 How important is the practice of DevOps to sca...
# NEWEdImpt                     How important is a formal education, such as a...
# NEWJobHunt                    In general, what drives you to look for a new ...
# NEWJobHuntResearch            When job searching, how do you learn more abou...
# NEWLearn                      How frequently do you learn a new language or ...
# NEWOffTopic                   Do you think Stack Overflow should relax restr...
# NEWOnboardGood                Do you think your company has a good onboardin...
# NEWOtherComms                 Are you a member of any other online developer...
# NEWOvertime                   How often do you work overtime or beyond the f...
# NEWPurchaseResearch           When buying a new tool or software, how do you...
# NEWPurpleLink                 You search for a coding solution online and th...
# NEWSOSites                    Which of the following Stack Overflow sites ha...
# NEWStuck                      What do you do when you get stuck on a problem...
# OpSys                         What is the primary operating system in which ...
# OrgSize                       Approximately how many people are employed by ...
# PlatformDesireNextYear        Which platforms have you done extensive develo...
# PlatformWorkedWith            Which platforms have you done extensive develo...
# PurchaseWhat                  What level of influence do you, personally, ha...
# Respondent                    Randomized respondent ID number (not in order ...
# SOAccount                                 Do you have a Stack Overflow account?
# SOComm                        Do you consider yourself a member of the Stack...
# SOPartFreq                    How frequently would you say you participate i...
# SOVisitFreq                   How frequently would you say you visit Stack O...
# Sexuality                     Which of the following describe you, if any? P...
# SurveyEase                    How easy or difficult was this survey to compl...
# SurveyLength                  How do you feel about the length of the survey...
# Trans                                                      Are you transgender?
# UndergradMajor                            What was your primary field of study?
# WebframeDesireNextYear        Which web frameworks have you done extensive d...
# WebframeWorkedWith            Which web frameworks have you done extensive d...
# WelcomeChange                 Compared to last year, how welcome do you feel...
# WorkWeekHrs                   On average, how many hours per week do you wor...
# YearsCode                     Including any education, how many years have y...
# YearsCodePro                  NOT including education, how many years have y...

# %%
schema_df.loc['Age']
# Out:
# QuestionText    What is your age (in years)? If you prefer not...
# Name: Age, dtype: object

# %%
schema_df.loc['Age', 'QuestionText']
# Out:
# 'What is your age (in years)? If you prefer not to answer, you may leave this question blank.'

# %%
schema_df.sort_index()
# Out:
#                                                                    QuestionText
# Column
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# DatabaseDesireNextYear        Which database environments have you done exte...
# DatabaseWorkedWith            Which database environments have you done exte...
# DevType                       Which of the following describe you? Please se...
# EdLevel                       Which of the following best describes the high...
# Employment                    Which of the following best describes your cur...
# Ethnicity                     Which of the following describe you, if any? P...
# Gender                        Which of the following describe you, if any? P...
# Hobbyist                                                Do you code as a hobby?
# JobFactors                    Imagine that you are deciding between two job ...
# JobSat                        How satisfied are you with your current job? (...
# JobSeek                       Which of the following best describes your cur...
# LanguageDesireNextYear        Which programming, scripting, and markup langu...
# LanguageWorkedWith            Which programming, scripting, and markup langu...
# MainBranch                    Which of the following options best describes ...
# MiscTechDesireNextYear        Which other frameworks, libraries, and tools h...
# MiscTechWorkedWith            Which other frameworks, libraries, and tools h...
# NEWCollabToolsDesireNextYear  Which collaboration tools have you done extens...
# NEWCollabToolsWorkedWith      Which collaboration tools have you done extens...
# NEWDevOps                     Does your company have a dedicated DevOps person?
# NEWDevOpsImpt                 How important is the practice of DevOps to sca...
# NEWEdImpt                     How important is a formal education, such as a...
# NEWJobHunt                    In general, what drives you to look for a new ...
# NEWJobHuntResearch            When job searching, how do you learn more abou...
# NEWLearn                      How frequently do you learn a new language or ...
# NEWOffTopic                   Do you think Stack Overflow should relax restr...
# NEWOnboardGood                Do you think your company has a good onboardin...
# NEWOtherComms                 Are you a member of any other online developer...
# NEWOvertime                   How often do you work overtime or beyond the f...
# NEWPurchaseResearch           When buying a new tool or software, how do you...
# NEWPurpleLink                 You search for a coding solution online and th...
# NEWSOSites                    Which of the following Stack Overflow sites ha...
# NEWStuck                      What do you do when you get stuck on a problem...
# OpSys                         What is the primary operating system in which ...
# OrgSize                       Approximately how many people are employed by ...
# PlatformDesireNextYear        Which platforms have you done extensive develo...
# PlatformWorkedWith            Which platforms have you done extensive develo...
# PurchaseWhat                  What level of influence do you, personally, ha...
# Respondent                    Randomized respondent ID number (not in order ...
# SOAccount                                 Do you have a Stack Overflow account?
# SOComm                        Do you consider yourself a member of the Stack...
# SOPartFreq                    How frequently would you say you participate i...
# SOVisitFreq                   How frequently would you say you visit Stack O...
# Sexuality                     Which of the following describe you, if any? P...
# SurveyEase                    How easy or difficult was this survey to compl...
# SurveyLength                  How do you feel about the length of the survey...
# Trans                                                      Are you transgender?
# UndergradMajor                            What was your primary field of study?
# WebframeDesireNextYear        Which web frameworks have you done extensive d...
# WebframeWorkedWith            Which web frameworks have you done extensive d...
# WelcomeChange                 Compared to last year, how welcome do you feel...
# WorkWeekHrs                   On average, how many hours per week do you wor...
# YearsCode                     Including any education, how many years have y...
# YearsCodePro                  NOT including education, how many years have y...

# %%
schema_df.sort_index(ascending=False)
# Out:
#                                                                    QuestionText
# Column
# YearsCodePro                  NOT including education, how many years have y...
# YearsCode                     Including any education, how many years have y...
# WorkWeekHrs                   On average, how many hours per week do you wor...
# WelcomeChange                 Compared to last year, how welcome do you feel...
# WebframeWorkedWith            Which web frameworks have you done extensive d...
# WebframeDesireNextYear        Which web frameworks have you done extensive d...
# UndergradMajor                            What was your primary field of study?
# Trans                                                      Are you transgender?
# SurveyLength                  How do you feel about the length of the survey...
# SurveyEase                    How easy or difficult was this survey to compl...
# Sexuality                     Which of the following describe you, if any? P...
# SOVisitFreq                   How frequently would you say you visit Stack O...
# SOPartFreq                    How frequently would you say you participate i...
# SOComm                        Do you consider yourself a member of the Stack...
# SOAccount                                 Do you have a Stack Overflow account?
# Respondent                    Randomized respondent ID number (not in order ...
# PurchaseWhat                  What level of influence do you, personally, ha...
# PlatformWorkedWith            Which platforms have you done extensive develo...
# PlatformDesireNextYear        Which platforms have you done extensive develo...
# OrgSize                       Approximately how many people are employed by ...
# OpSys                         What is the primary operating system in which ...
# NEWStuck                      What do you do when you get stuck on a problem...
# NEWSOSites                    Which of the following Stack Overflow sites ha...
# NEWPurpleLink                 You search for a coding solution online and th...
# NEWPurchaseResearch           When buying a new tool or software, how do you...
# NEWOvertime                   How often do you work overtime or beyond the f...
# NEWOtherComms                 Are you a member of any other online developer...
# NEWOnboardGood                Do you think your company has a good onboardin...
# NEWOffTopic                   Do you think Stack Overflow should relax restr...
# NEWLearn                      How frequently do you learn a new language or ...
# NEWJobHuntResearch            When job searching, how do you learn more abou...
# NEWJobHunt                    In general, what drives you to look for a new ...
# NEWEdImpt                     How important is a formal education, such as a...
# NEWDevOpsImpt                 How important is the practice of DevOps to sca...
# NEWDevOps                     Does your company have a dedicated DevOps person?
# NEWCollabToolsWorkedWith      Which collaboration tools have you done extens...
# NEWCollabToolsDesireNextYear  Which collaboration tools have you done extens...
# MiscTechWorkedWith            Which other frameworks, libraries, and tools h...
# MiscTechDesireNextYear        Which other frameworks, libraries, and tools h...
# MainBranch                    Which of the following options best describes ...
# LanguageWorkedWith            Which programming, scripting, and markup langu...
# LanguageDesireNextYear        Which programming, scripting, and markup langu...
# JobSeek                       Which of the following best describes your cur...
# JobSat                        How satisfied are you with your current job? (...
# JobFactors                    Imagine that you are deciding between two job ...
# Hobbyist                                                Do you code as a hobby?
# Gender                        Which of the following describe you, if any? P...
# Ethnicity                     Which of the following describe you, if any? P...
# Employment                    Which of the following best describes your cur...
# EdLevel                       Which of the following best describes the high...
# DevType                       Which of the following describe you? Please se...
# DatabaseWorkedWith            Which database environments have you done exte...
# DatabaseDesireNextYear        Which database environments have you done exte...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# Country                                                      Where do you live?
# ConvertedComp                 Salary converted to annual USD salaries using ...
# CompTotal                     What is your current total compensation (salar...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# Age1stCode                    At what age did you write your first line of c...
# Age                           What is your age (in years)? If you prefer not...

# %%
schema_df.sort_index(inplace=True)

# %%
schema_df
# Out:
#                                                                    QuestionText
# Column
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# DatabaseDesireNextYear        Which database environments have you done exte...
# DatabaseWorkedWith            Which database environments have you done exte...
# DevType                       Which of the following describe you? Please se...
# EdLevel                       Which of the following best describes the high...
# Employment                    Which of the following best describes your cur...
# Ethnicity                     Which of the following describe you, if any? P...
# Gender                        Which of the following describe you, if any? P...
# Hobbyist                                                Do you code as a hobby?
# JobFactors                    Imagine that you are deciding between two job ...
# JobSat                        How satisfied are you with your current job? (...
# JobSeek                       Which of the following best describes your cur...
# LanguageDesireNextYear        Which programming, scripting, and markup langu...
# LanguageWorkedWith            Which programming, scripting, and markup langu...
# MainBranch                    Which of the following options best describes ...
# MiscTechDesireNextYear        Which other frameworks, libraries, and tools h...
# MiscTechWorkedWith            Which other frameworks, libraries, and tools h...
# NEWCollabToolsDesireNextYear  Which collaboration tools have you done extens...
# NEWCollabToolsWorkedWith      Which collaboration tools have you done extens...
# NEWDevOps                     Does your company have a dedicated DevOps person?
# NEWDevOpsImpt                 How important is the practice of DevOps to sca...
# NEWEdImpt                     How important is a formal education, such as a...
# NEWJobHunt                    In general, what drives you to look for a new ...
# NEWJobHuntResearch            When job searching, how do you learn more abou...
# NEWLearn                      How frequently do you learn a new language or ...
# NEWOffTopic                   Do you think Stack Overflow should relax restr...
# NEWOnboardGood                Do you think your company has a good onboardin...
# NEWOtherComms                 Are you a member of any other online developer...
# NEWOvertime                   How often do you work overtime or beyond the f...
# NEWPurchaseResearch           When buying a new tool or software, how do you...
# NEWPurpleLink                 You search for a coding solution online and th...
# NEWSOSites                    Which of the following Stack Overflow sites ha...
# NEWStuck                      What do you do when you get stuck on a problem...
# OpSys                         What is the primary operating system in which ...
# OrgSize                       Approximately how many people are employed by ...
# PlatformDesireNextYear        Which platforms have you done extensive develo...
# PlatformWorkedWith            Which platforms have you done extensive develo...
# PurchaseWhat                  What level of influence do you, personally, ha...
# Respondent                    Randomized respondent ID number (not in order ...
# SOAccount                                 Do you have a Stack Overflow account?
# SOComm                        Do you consider yourself a member of the Stack...
# SOPartFreq                    How frequently would you say you participate i...
# SOVisitFreq                   How frequently would you say you visit Stack O...
# Sexuality                     Which of the following describe you, if any? P...
# SurveyEase                    How easy or difficult was this survey to compl...
# SurveyLength                  How do you feel about the length of the survey...
# Trans                                                      Are you transgender?
# UndergradMajor                            What was your primary field of study?
# WebframeDesireNextYear        Which web frameworks have you done extensive d...
# WebframeWorkedWith            Which web frameworks have you done extensive d...
# WelcomeChange                 Compared to last year, how welcome do you feel...
# WorkWeekHrs                   On average, how many hours per week do you wor...
# YearsCode                     Including any education, how many years have y...
# YearsCodePro                  NOT including education, how many years have y...

# %%
filtered = (df['Country'] == 'Brazil')

# %%
df[filtered]
# Out:
#                                                       ...
# 65621                                                     NaN
# 4995                                                     .NET
# 17229                                                 Node.js
# 57188                                                     NaN
# 60149                            Apache Spark;Pandas;Teraform
#
#                                  NEWCollabToolsDesireNextYear  \
# Respondent
# 44                                        Github;Slack;Trello
# 59               Github;Slack;Microsoft Teams;Microsoft Azure
# 241                                                    Github
# 310              Confluence;Jira;Github;Slack;Microsoft Azure
# 328             Github;Gitlab;Trello;Stack Overflow for Teams
# ...                                                       ...
# 65621                                                     NaN
# 4995                                               Confluence
# 17229                                                  Github
# 57188                                                     NaN
# 60149       Confluence;Jira;Github;Slack;Google Suite (Doc...
#
#                                      NEWCollabToolsWorkedWith NEWDevOps  \
# Respondent
# 44                                        Github;Slack;Trello        No
# 59                                        Github;Slack;Trello        No
# 241                                                    Github        No
# 310                              Github;Slack;Microsoft Azure        No
# 328         Github;Gitlab;Trello;Google Suite (Docs, Meet,...        No
# ...                                                       ...       ...
# 65621                                                     NaN       NaN
# 4995                                               Confluence       NaN
# 17229                   Github;Google Suite (Docs, Meet, etc)       NaN
# 57188                                                     NaN       NaN
# 60149       Confluence;Jira;Github;Slack;Google Suite (Doc...       NaN
#
#                   NEWDevOpsImpt             NEWEdImpt  \
# Respondent
# 44           Somewhat important        Very important
# 59           Somewhat important      Fairly important
# 241          Somewhat important      Fairly important
# 310         Extremely important    Somewhat important
# 328         Extremely important  Critically important
# ...                         ...                   ...
# 65621                       NaN        Very important
# 4995                        NaN                   NaN
# 17229                       NaN      Fairly important
# 57188                       NaN                   NaN
# 60149                       NaN        Very important
#
#                                                    NEWJobHunt  \
# Respondent
# 44          Having a bad day (or week or month) at work;Cu...
# 59          Curious about other opportunities;Better compe...
# 241         Better compensation;Better work/life balance;G...
# 310         Wanting to share accomplishments with a wider ...
# 328              Better work/life balance;Looking to relocate
# ...                                                       ...
# 65621                                                     NaN
# 4995                                                      NaN
# 17229                                                     NaN
# 57188                                                     NaN
# 60149                                                     NaN
#
#                                            NEWJobHuntResearch  \
# Respondent
# 44          Company reviews from third party sites (e.g. G...
# 59          Read company media, such as employee blogs or ...
# 241         Read company media, such as employee blogs or ...
# 310         Company reviews from third party sites (e.g. G...
# 328         Read company media, such as employee blogs or ...
# ...                                                       ...
# 65621                                                     NaN
# 4995                                                      NaN
# 17229                                                     NaN
# 57188                                                     NaN
# 60149                                                     NaN
#
#                         NEWLearn NEWOffTopic                NEWOnboardGood  \
# Respondent
# 44          Once every few years          No                            No
# 59              Every few months          No                            No
# 241                  Once a year          No  Onboarding? What onboarding?
# 310             Every few months    Not sure                            No
# 328             Every few months    Not sure                           Yes
# ...                          ...         ...                           ...
# 65621                        NaN         NaN                           NaN
# 4995                         NaN         NaN                           NaN
# 17229           Every few months    Not sure                           NaN
# 57188                        NaN         NaN                           NaN
# 60149                Once a year          No                           NaN
#
#            NEWOtherComms                        NEWOvertime  \
# Respondent
# 44                    No   Often: 1-2 days per week or more
# 59                    No                              Never
# 241                   No  Rarely: 1-2 days per year or less
# 310                  Yes                              Never
# 328                  Yes  Rarely: 1-2 days per year or less
# ...                  ...                                ...
# 65621                NaN                                NaN
# 4995                 NaN                                NaN
# 17229                NaN                                NaN
# 57188                NaN                                NaN
# 60149                NaN                                NaN
#
#                                           NEWPurchaseResearch  \
# Respondent
# 44          Start a free trial;Ask developers I know/work ...
# 59                                                        NaN
# 241                                                       NaN
# 310         Start a free trial;Ask developers I know/work ...
# 328                                                       NaN
# ...                                                       ...
# 65621                                                     NaN
# 4995                                                      NaN
# 17229       Visit developer communities like Stack Overflo...
# 57188                                                     NaN
# 60149       Start a free trial;Visit developer communities...
#
#                 NEWPurpleLink  \
# Respondent
# 44          Hello, old friend
# 59                Indifferent
# 241                   Annoyed
# 310         Hello, old friend
# 328         Hello, old friend
# ...                       ...
# 65621                     NaN
# 4995                   Amused
# 17229             Indifferent
# 57188                     NaN
# 60149                  Amused
#
#                                                    NEWSOSites  \
# Respondent
# 44          Stack Overflow (public Q&A for anyone who code...
# 59           Stack Overflow (public Q&A for anyone who codes)
# 241         Stack Overflow (public Q&A for anyone who code...
# 310         Stack Overflow (public Q&A for anyone who code...
# 328         Stack Overflow (public Q&A for anyone who code...
# ...                                                       ...
# 65621                                                     NaN
# 4995                  I have never visited any of these sites
# 17229       Stack Overflow (public Q&A for anyone who code...
# 57188                                                     NaN
# 60149        Stack Overflow (public Q&A for anyone who codes)
#
#                                                      NEWStuck        OpSys  \
# Respondent
# 44          Call a coworker or friend;Visit Stack Overflow...      Windows
# 59          Call a coworker or friend;Visit Stack Overflow...      Windows
# 241            Call a coworker or friend;Visit Stack Overflow      Windows
# 310         Meditate;Call a coworker or friend;Visit Stack...      Windows
# 328            Call a coworker or friend;Visit Stack Overflow  Linux-based
# ...                                                       ...          ...
# 65621                                                     NaN          NaN
# 4995                                                      NaN      Windows
# 17229       Visit Stack Overflow;Go for a walk or other ph...  Linux-based
# 57188                                                     NaN          NaN
# 60149       Call a coworker or friend;Visit Stack Overflow...        MacOS
#
#                                                       OrgSize  \
# Respondent
# 44                                         10 to 19 employees
# 59                                       500 to 999 employees
# 241                                        10 to 19 employees
# 310         Just me - I am a freelancer, sole proprietor, ...
# 328                                  1,000 to 4,999 employees
# ...                                                       ...
# 65621                                    500 to 999 employees
# 4995                                                      NaN
# 17229                                                     NaN
# 57188                                                     NaN
# 60149                                                     NaN
#
#                                        PlatformDesireNextYear  \
# Respondent
# 44                                              Linux;Windows
# 59                                    Microsoft Azure;Windows
# 241                                           Android;Windows
# 310         Android;Docker;Heroku;IBM Cloud or Watson;iOS;...
# 328                                   Docker;Kubernetes;Linux
# ...                                                       ...
# 65621                                                     NaN
# 4995                                                  Android
# 17229                                Android;Heroku;iOS;Linux
# 57188                                                     NaN
# 60149                    AWS;Google Cloud Platform;Kubernetes
#
#                                            PlatformWorkedWith  \
# Respondent
# 44                                                    Windows
# 59                                               Docker;MacOS
# 241                                           Android;Windows
# 310         Android;Linux;Microsoft Azure;Raspberry Pi;Win...
# 328                                       Docker;Heroku;Linux
# ...                                                       ...
# 65621                                                     NaN
# 4995                                                  Android
# 17229                                    Heroku;Linux;Windows
# 57188                                                     NaN
# 60149                                                     AWS
#
#                                 PurchaseWhat                Sexuality  \
# Respondent
# 44                     I have some influence  Straight / Heterosexual
# 59             I have little or no influence  Straight / Heterosexual
# 241            I have little or no influence  Straight / Heterosexual
# 310         I have a great deal of influence  Straight / Heterosexual
# 328            I have little or no influence  Straight / Heterosexual
# ...                                      ...                      ...
# 65621                                    NaN                      NaN
# 4995                                     NaN                      NaN
# 17229                                    NaN  Straight / Heterosexual
# 57188                                    NaN                      NaN
# 60149                                    NaN  Straight / Heterosexual
#
#                           SOAccount           SOComm  \
# Respondent
# 44                              Yes    Yes, somewhat
# 59                              Yes    Yes, somewhat
# 241                             Yes  Yes, definitely
# 310                             Yes          Neutral
# 328                             Yes    Yes, somewhat
# ...                             ...              ...
# 65621                           NaN              NaN
# 4995                            NaN              NaN
# 17229                           Yes   No, not at all
# 57188                           NaN              NaN
# 60149       Not sure/can't remember   No, not really
#
#                                                    SOPartFreq  \
# Respondent
# 44                            A few times per month or weekly
# 59                                       A few times per week
# 241                                    Multiple times per day
# 310                       Less than once per month or monthly
# 328                                      A few times per week
# ...                                                       ...
# 65621                                                     NaN
# 4995                                                      NaN
# 17229       I have never participated in Q&A on Stack Over...
# 57188                                                     NaN
# 60149                                                     NaN
#
#                                 SOVisitFreq                  SurveyEase  \
# Respondent
# 44                   Multiple times per day  Neither easy nor difficult
# 59                     A few times per week                        Easy
# 241                   Daily or almost daily                        Easy
# 310         A few times per month or weekly                        Easy
# 328                   Daily or almost daily                        Easy
# ...                                     ...                         ...
# 65621                                   NaN                         NaN
# 4995                                    NaN                        Easy
# 17229                  A few times per week                        Easy
# 57188                                   NaN                         NaN
# 60149       A few times per month or weekly                        Easy
#
#                      SurveyLength Trans  \
# Respondent
# 44          Appropriate in length    No
# 59          Appropriate in length    No
# 241                     Too short    No
# 310         Appropriate in length    No
# 328         Appropriate in length    No
# ...                           ...   ...
# 65621                         NaN   NaN
# 4995                          NaN    No
# 17229       Appropriate in length    No
# 57188                         NaN   NaN
# 60149       Appropriate in length    No
#
#                                                UndergradMajor  \
# Respondent
# 44          Another engineering discipline (such as civil,...
# 59          Computer science, computer engineering, or sof...
# 241         Information systems, information technology, o...
# 310         Computer science, computer engineering, or sof...
# 328         Computer science, computer engineering, or sof...
# ...                                                       ...
# 65621                                                     NaN
# 4995                                                      NaN
# 17229       Computer science, computer engineering, or sof...
# 57188                                                     NaN
# 60149       Computer science, computer engineering, or sof...
#
#                                 WebframeDesireNextYear  \
# Respondent
# 44                                                 NaN
# 59                              Angular;ASP.NET;jQuery
# 241                                             jQuery
# 310         Angular;ASP.NET Core;Django;Express;Vue.js
# 328                                     Express;Vue.js
# ...                                                ...
# 65621                                              NaN
# 4995                                           ASP.NET
# 17229                   Django;Express;React.js;Vue.js
# 57188                                              NaN
# 60149                                     Django;Flask
#
#                               WebframeWorkedWith  \
# Respondent
# 44                                           NaN
# 59          ASP.NET;jQuery;Laravel;Ruby on Rails
# 241                                       jQuery
# 310                         ASP.NET Core;Express
# 328                Angular;Express;jQuery;Vue.js
# ...                                          ...
# 65621                                        NaN
# 4995                                     ASP.NET
# 17229                    Express;jQuery;React.js
# 57188                                        NaN
# 60149                                     Django
#
#                                                 WelcomeChange  WorkWeekHrs  \
# Respondent
# 44                    Just as welcome now as I felt last year         45.0
# 59                    Just as welcome now as I felt last year         40.0
# 241                   Just as welcome now as I felt last year         44.0
# 310                   Just as welcome now as I felt last year         40.0
# 328                   Just as welcome now as I felt last year         40.0
# ...                                                       ...          ...
# 65621                                                     NaN          NaN
# 4995                                                      NaN          NaN
# 17229       Not applicable - I did not use Stack Overflow ...          NaN
# 57188                                                     NaN          NaN
# 60149                 Just as welcome now as I felt last year          NaN
#
#            YearsCode YearsCodePro
# Respondent
# 44                10            6
# 59                24           15
# 241                5            3
# 310               10           10
# 328               13            9
# ...              ...          ...
# 65621              4          NaN
# 4995             NaN          NaN
# 17229              4          NaN
# 57188            NaN          NaN
# 60149             16           14
#
# [1818 rows x 60 columns]

# %%
df.loc[filtered]
# Out:
#                                                       ...
# 65621                                                     NaN
# 4995                                                     .NET
# 17229                                                 Node.js
# 57188                                                     NaN
# 60149                            Apache Spark;Pandas;Teraform
#
#                                  NEWCollabToolsDesireNextYear  \
# Respondent
# 44                                        Github;Slack;Trello
# 59               Github;Slack;Microsoft Teams;Microsoft Azure
# 241                                                    Github
# 310              Confluence;Jira;Github;Slack;Microsoft Azure
# 328             Github;Gitlab;Trello;Stack Overflow for Teams
# ...                                                       ...
# 65621                                                     NaN
# 4995                                               Confluence
# 17229                                                  Github
# 57188                                                     NaN
# 60149       Confluence;Jira;Github;Slack;Google Suite (Doc...
#
#                                      NEWCollabToolsWorkedWith NEWDevOps  \
# Respondent
# 44                                        Github;Slack;Trello        No
# 59                                        Github;Slack;Trello        No
# 241                                                    Github        No
# 310                              Github;Slack;Microsoft Azure        No
# 328         Github;Gitlab;Trello;Google Suite (Docs, Meet,...        No
# ...                                                       ...       ...
# 65621                                                     NaN       NaN
# 4995                                               Confluence       NaN
# 17229                   Github;Google Suite (Docs, Meet, etc)       NaN
# 57188                                                     NaN       NaN
# 60149       Confluence;Jira;Github;Slack;Google Suite (Doc...       NaN
#
#                   NEWDevOpsImpt             NEWEdImpt  \
# Respondent
# 44           Somewhat important        Very important
# 59           Somewhat important      Fairly important
# 241          Somewhat important      Fairly important
# 310         Extremely important    Somewhat important
# 328         Extremely important  Critically important
# ...                         ...                   ...
# 65621                       NaN        Very important
# 4995                        NaN                   NaN
# 17229                       NaN      Fairly important
# 57188                       NaN                   NaN
# 60149                       NaN        Very important
#
#                                                    NEWJobHunt  \
# Respondent
# 44          Having a bad day (or week or month) at work;Cu...
# 59          Curious about other opportunities;Better compe...
# 241         Better compensation;Better work/life balance;G...
# 310         Wanting to share accomplishments with a wider ...
# 328              Better work/life balance;Looking to relocate
# ...                                                       ...
# 65621                                                     NaN
# 4995                                                      NaN
# 17229                                                     NaN
# 57188                                                     NaN
# 60149                                                     NaN
#
#                                            NEWJobHuntResearch  \
# Respondent
# 44          Company reviews from third party sites (e.g. G...
# 59          Read company media, such as employee blogs or ...
# 241         Read company media, such as employee blogs or ...
# 310         Company reviews from third party sites (e.g. G...
# 328         Read company media, such as employee blogs or ...
# ...                                                       ...
# 65621                                                     NaN
# 4995                                                      NaN
# 17229                                                     NaN
# 57188                                                     NaN
# 60149                                                     NaN
#
#                         NEWLearn NEWOffTopic                NEWOnboardGood  \
# Respondent
# 44          Once every few years          No                            No
# 59              Every few months          No                            No
# 241                  Once a year          No  Onboarding? What onboarding?
# 310             Every few months    Not sure                            No
# 328             Every few months    Not sure                           Yes
# ...                          ...         ...                           ...
# 65621                        NaN         NaN                           NaN
# 4995                         NaN         NaN                           NaN
# 17229           Every few months    Not sure                           NaN
# 57188                        NaN         NaN                           NaN
# 60149                Once a year          No                           NaN
#
#            NEWOtherComms                        NEWOvertime  \
# Respondent
# 44                    No   Often: 1-2 days per week or more
# 59                    No                              Never
# 241                   No  Rarely: 1-2 days per year or less
# 310                  Yes                              Never
# 328                  Yes  Rarely: 1-2 days per year or less
# ...                  ...                                ...
# 65621                NaN                                NaN
# 4995                 NaN                                NaN
# 17229                NaN                                NaN
# 57188                NaN                                NaN
# 60149                NaN                                NaN
#
#                                           NEWPurchaseResearch  \
# Respondent
# 44          Start a free trial;Ask developers I know/work ...
# 59                                                        NaN
# 241                                                       NaN
# 310         Start a free trial;Ask developers I know/work ...
# 328                                                       NaN
# ...                                                       ...
# 65621                                                     NaN
# 4995                                                      NaN
# 17229       Visit developer communities like Stack Overflo...
# 57188                                                     NaN
# 60149       Start a free trial;Visit developer communities...
#
#                 NEWPurpleLink  \
# Respondent
# 44          Hello, old friend
# 59                Indifferent
# 241                   Annoyed
# 310         Hello, old friend
# 328         Hello, old friend
# ...                       ...
# 65621                     NaN
# 4995                   Amused
# 17229             Indifferent
# 57188                     NaN
# 60149                  Amused
#
#                                                    NEWSOSites  \
# Respondent
# 44          Stack Overflow (public Q&A for anyone who code...
# 59           Stack Overflow (public Q&A for anyone who codes)
# 241         Stack Overflow (public Q&A for anyone who code...
# 310         Stack Overflow (public Q&A for anyone who code...
# 328         Stack Overflow (public Q&A for anyone who code...
# ...                                                       ...
# 65621                                                     NaN
# 4995                  I have never visited any of these sites
# 17229       Stack Overflow (public Q&A for anyone who code...
# 57188                                                     NaN
# 60149        Stack Overflow (public Q&A for anyone who codes)
#
#                                                      NEWStuck        OpSys  \
# Respondent
# 44          Call a coworker or friend;Visit Stack Overflow...      Windows
# 59          Call a coworker or friend;Visit Stack Overflow...      Windows
# 241            Call a coworker or friend;Visit Stack Overflow      Windows
# 310         Meditate;Call a coworker or friend;Visit Stack...      Windows
# 328            Call a coworker or friend;Visit Stack Overflow  Linux-based
# ...                                                       ...          ...
# 65621                                                     NaN          NaN
# 4995                                                      NaN      Windows
# 17229       Visit Stack Overflow;Go for a walk or other ph...  Linux-based
# 57188                                                     NaN          NaN
# 60149       Call a coworker or friend;Visit Stack Overflow...        MacOS
#
#                                                       OrgSize  \
# Respondent
# 44                                         10 to 19 employees
# 59                                       500 to 999 employees
# 241                                        10 to 19 employees
# 310         Just me - I am a freelancer, sole proprietor, ...
# 328                                  1,000 to 4,999 employees
# ...                                                       ...
# 65621                                    500 to 999 employees
# 4995                                                      NaN
# 17229                                                     NaN
# 57188                                                     NaN
# 60149                                                     NaN
#
#                                        PlatformDesireNextYear  \
# Respondent
# 44                                              Linux;Windows
# 59                                    Microsoft Azure;Windows
# 241                                           Android;Windows
# 310         Android;Docker;Heroku;IBM Cloud or Watson;iOS;...
# 328                                   Docker;Kubernetes;Linux
# ...                                                       ...
# 65621                                                     NaN
# 4995                                                  Android
# 17229                                Android;Heroku;iOS;Linux
# 57188                                                     NaN
# 60149                    AWS;Google Cloud Platform;Kubernetes
#
#                                            PlatformWorkedWith  \
# Respondent
# 44                                                    Windows
# 59                                               Docker;MacOS
# 241                                           Android;Windows
# 310         Android;Linux;Microsoft Azure;Raspberry Pi;Win...
# 328                                       Docker;Heroku;Linux
# ...                                                       ...
# 65621                                                     NaN
# 4995                                                  Android
# 17229                                    Heroku;Linux;Windows
# 57188                                                     NaN
# 60149                                                     AWS
#
#                                 PurchaseWhat                Sexuality  \
# Respondent
# 44                     I have some influence  Straight / Heterosexual
# 59             I have little or no influence  Straight / Heterosexual
# 241            I have little or no influence  Straight / Heterosexual
# 310         I have a great deal of influence  Straight / Heterosexual
# 328            I have little or no influence  Straight / Heterosexual
# ...                                      ...                      ...
# 65621                                    NaN                      NaN
# 4995                                     NaN                      NaN
# 17229                                    NaN  Straight / Heterosexual
# 57188                                    NaN                      NaN
# 60149                                    NaN  Straight / Heterosexual
#
#                           SOAccount           SOComm  \
# Respondent
# 44                              Yes    Yes, somewhat
# 59                              Yes    Yes, somewhat
# 241                             Yes  Yes, definitely
# 310                             Yes          Neutral
# 328                             Yes    Yes, somewhat
# ...                             ...              ...
# 65621                           NaN              NaN
# 4995                            NaN              NaN
# 17229                           Yes   No, not at all
# 57188                           NaN              NaN
# 60149       Not sure/can't remember   No, not really
#
#                                                    SOPartFreq  \
# Respondent
# 44                            A few times per month or weekly
# 59                                       A few times per week
# 241                                    Multiple times per day
# 310                       Less than once per month or monthly
# 328                                      A few times per week
# ...                                                       ...
# 65621                                                     NaN
# 4995                                                      NaN
# 17229       I have never participated in Q&A on Stack Over...
# 57188                                                     NaN
# 60149                                                     NaN
#
#                                 SOVisitFreq                  SurveyEase  \
# Respondent
# 44                   Multiple times per day  Neither easy nor difficult
# 59                     A few times per week                        Easy
# 241                   Daily or almost daily                        Easy
# 310         A few times per month or weekly                        Easy
# 328                   Daily or almost daily                        Easy
# ...                                     ...                         ...
# 65621                                   NaN                         NaN
# 4995                                    NaN                        Easy
# 17229                  A few times per week                        Easy
# 57188                                   NaN                         NaN
# 60149       A few times per month or weekly                        Easy
#
#                      SurveyLength Trans  \
# Respondent
# 44          Appropriate in length    No
# 59          Appropriate in length    No
# 241                     Too short    No
# 310         Appropriate in length    No
# 328         Appropriate in length    No
# ...                           ...   ...
# 65621                         NaN   NaN
# 4995                          NaN    No
# 17229       Appropriate in length    No
# 57188                         NaN   NaN
# 60149       Appropriate in length    No
#
#                                                UndergradMajor  \
# Respondent
# 44          Another engineering discipline (such as civil,...
# 59          Computer science, computer engineering, or sof...
# 241         Information systems, information technology, o...
# 310         Computer science, computer engineering, or sof...
# 328         Computer science, computer engineering, or sof...
# ...                                                       ...
# 65621                                                     NaN
# 4995                                                      NaN
# 17229       Computer science, computer engineering, or sof...
# 57188                                                     NaN
# 60149       Computer science, computer engineering, or sof...
#
#                                 WebframeDesireNextYear  \
# Respondent
# 44                                                 NaN
# 59                              Angular;ASP.NET;jQuery
# 241                                             jQuery
# 310         Angular;ASP.NET Core;Django;Express;Vue.js
# 328                                     Express;Vue.js
# ...                                                ...
# 65621                                              NaN
# 4995                                           ASP.NET
# 17229                   Django;Express;React.js;Vue.js
# 57188                                              NaN
# 60149                                     Django;Flask
#
#                               WebframeWorkedWith  \
# Respondent
# 44                                           NaN
# 59          ASP.NET;jQuery;Laravel;Ruby on Rails
# 241                                       jQuery
# 310                         ASP.NET Core;Express
# 328                Angular;Express;jQuery;Vue.js
# ...                                          ...
# 65621                                        NaN
# 4995                                     ASP.NET
# 17229                    Express;jQuery;React.js
# 57188                                        NaN
# 60149                                     Django
#
#                                                 WelcomeChange  WorkWeekHrs  \
# Respondent
# 44                    Just as welcome now as I felt last year         45.0
# 59                    Just as welcome now as I felt last year         40.0
# 241                   Just as welcome now as I felt last year         44.0
# 310                   Just as welcome now as I felt last year         40.0
# 328                   Just as welcome now as I felt last year         40.0
# ...                                                       ...          ...
# 65621                                                     NaN          NaN
# 4995                                                      NaN          NaN
# 17229       Not applicable - I did not use Stack Overflow ...          NaN
# 57188                                                     NaN          NaN
# 60149                 Just as welcome now as I felt last year          NaN
#
#            YearsCode YearsCodePro
# Respondent
# 44                10            6
# 59                24           15
# 241                5            3
# 310               10           10
# 328               13            9
# ...              ...          ...
# 65621              4          NaN
# 4995             NaN          NaN
# 17229              4          NaN
# 57188            NaN          NaN
# 60149             16           14
#
# [1818 rows x 60 columns]

# %%
filter_sp_br = ((df['Country'] == 'Brazil') & (df['Age1stCode'] == '11'))

# %%
df.loc[filter_sp_br]
# Out:
# ily  Neither easy nor difficult
# 22314                     Daily or almost daily                        Easy
# 24812                    Multiple times per day  Neither easy nor difficult
# 25136                     Daily or almost daily                        Easy
# 25612                     Daily or almost daily  Neither easy nor difficult
# 32392                    Multiple times per day                        Easy
# 35206                     Daily or almost daily  Neither easy nor difficult
# 35239                    Multiple times per day  Neither easy nor difficult
# 35884                    Multiple times per day                        Easy
# 39669       Less than once per month or monthly                         NaN
# 40442                                       NaN                         NaN
# 40487                    Multiple times per day  Neither easy nor difficult
# 42328                    Multiple times per day                        Easy
# 44393                     Daily or almost daily                         NaN
# 46458                    Multiple times per day  Neither easy nor difficult
# 46589           A few times per month or weekly                        Easy
# 47445                     Daily or almost daily                        Easy
# 49218                    Multiple times per day                        Easy
# 49948                      A few times per week                        Easy
# 50020                      A few times per week                        Easy
# 50891       Less than once per month or monthly                        Easy
# 53064                      A few times per week  Neither easy nor difficult
# 57434                     Daily or almost daily  Neither easy nor difficult
# 57497                      A few times per week                        Easy
# 60042       Less than once per month or monthly  Neither easy nor difficult
# 61246           A few times per month or weekly  Neither easy nor difficult
# 61644                    Multiple times per day                        Easy
# 62351           A few times per month or weekly                        Easy
# 65621                                       NaN                         NaN
#
#                      SurveyLength Trans  \
# Respondent
# 2373        Appropriate in length    No
# 2976        Appropriate in length    No
# 3040        Appropriate in length    No
# 3172        Appropriate in length    No
# 3959                    Too short    No
# 4868        Appropriate in length    No
# 5322        Appropriate in length    No
# 14122       Appropriate in length    No
# 14666       Appropriate in length    No
# 14992       Appropriate in length    No
# 15108                    Too long    No
# 15140                    Too long    No
# 15195       Appropriate in length    No
# 15257       Appropriate in length    No
# 15764       Appropriate in length    No
# 15867       Appropriate in length    No
# 15903       Appropriate in length    No
# 16120                    Too long    No
# 17652       Appropriate in length    No
# 17822       Appropriate in length    No
# 19635       Appropriate in length    No
# 22314       Appropriate in length    No
# 24812       Appropriate in length    No
# 25136                    Too long    No
# 25612       Appropriate in length    No
# 32392                    Too long    No
# 35206       Appropriate in length    No
# 35239       Appropriate in length    No
# 35884                    Too long    No
# 39669                         NaN   NaN
# 40442                         NaN   NaN
# 40487       Appropriate in length    No
# 42328       Appropriate in length    No
# 44393                         NaN   NaN
# 46458                    Too long   NaN
# 46589       Appropriate in length    No
# 47445       Appropriate in length    No
# 49218       Appropriate in length    No
# 49948                   Too short    No
# 50020       Appropriate in length    No
# 50891                    Too long    No
# 53064       Appropriate in length    No
# 57434       Appropriate in length    No
# 57497                    Too long    No
# 60042       Appropriate in length    No
# 61246       Appropriate in length    No
# 61644       Appropriate in length    No
# 62351       Appropriate in length    No
# 65621                         NaN   NaN
#
#                                                UndergradMajor  \
# Respondent
# 2373        Computer science, computer engineering, or sof...
# 2976                                                      NaN
# 3040        Computer science, computer engineering, or sof...
# 3172                            Web development or web design
# 3959        Another engineering discipline (such as civil,...
# 4868        Computer science, computer engineering, or sof...
# 5322        Another engineering discipline (such as civil,...
# 14122       Computer science, computer engineering, or sof...
# 14666       Computer science, computer engineering, or sof...
# 14992                                                     NaN
# 15108       Computer science, computer engineering, or sof...
# 15140       Computer science, computer engineering, or sof...
# 15195                                                     NaN
# 15257                                                     NaN
# 15764       Computer science, computer engineering, or sof...
# 15867       Information systems, information technology, o...
# 15903                                                     NaN
# 16120       Computer science, computer engineering, or sof...
# 17652       Computer science, computer engineering, or sof...
# 17822       A business discipline (such as accounting, fin...
# 19635       Computer science, computer engineering, or sof...
# 22314       Computer science, computer engineering, or sof...
# 24812       Information systems, information technology, o...
# 25136       Computer science, computer engineering, or sof...
# 25612       Another engineering discipline (such as civil,...
# 32392       Another engineering discipline (such as civil,...
# 35206       Computer science, computer engineering, or sof...
# 35239                                                     NaN
# 35884                                                     NaN
# 39669       Computer science, computer engineering, or sof...
# 40442       Another engineering discipline (such as civil,...
# 40487       Information systems, information technology, o...
# 42328       Computer science, computer engineering, or sof...
# 44393                                                     NaN
# 46458       Computer science, computer engineering, or sof...
# 46589       Another engineering discipline (such as civil,...
# 47445                                                     NaN
# 49218                                                     NaN
# 49948       Information systems, information technology, o...
# 50020       Computer science, computer engineering, or sof...
# 50891       Computer science, computer engineering, or sof...
# 53064                                                     NaN
# 57434       Computer science, computer engineering, or sof...
# 57497       Another engineering discipline (such as civil,...
# 60042       Another engineering discipline (such as civil,...
# 61246       Computer science, computer engineering, or sof...
# 61644       Information systems, information technology, o...
# 62351       Another engineering discipline (such as civil,...
# 65621                                                     NaN
#
#                                        WebframeDesireNextYear  \
# Respondent
# 2373             Angular;ASP.NET;ASP.NET Core;jQuery;React.js
# 2976                             Angular;ASP.NET Core;Express
# 3040        Angular;Django;Express;jQuery;React.js;Ruby on...
# 3172                                           Flask;React.js
# 3959                                     Angular;Flask;Vue.js
# 4868                             Flask;Gatsby;React.js;Vue.js
# 5322                                                      NaN
# 14122                                                     NaN
# 14666            Express;jQuery;React.js;Ruby on Rails;Vue.js
# 14992                                                  jQuery
# 15108                             Django;Ruby on Rails;Vue.js
# 15140                                                  Django
# 15195                                 Express;React.js;Vue.js
# 15257               Angular;Angular.js;Django;jQuery;React.js
# 15764                                 Express;Gatsby;React.js
# 15867                          Express;jQuery;React.js;Vue.js
# 15903                            Angular;Django;Spring;Vue.js
# 16120             ASP.NET Core;Express;Gatsby;React.js;Vue.js
# 17652                                  Express;Laravel;Vue.js
# 17822                                  Django;React.js;Vue.js
# 19635       Angular.js;ASP.NET;ASP.NET Core;jQuery;React.j...
# 22314                        ASP.NET Core;Django;Flask;Spring
# 24812                                        Express;React.js
# 25136            Express;Gatsby;React.js;Ruby on Rails;Vue.js
# 25612       Angular;Angular.js;jQuery;Laravel;React.js;Vue.js
# 32392                      Angular;Angular.js;React.js;Vue.js
# 35206                                                     NaN
# 35239                             Angular;ASP.NET Core;Vue.js
# 35884                  Angular;Django;Express;React.js;Vue.js
# 39669                    ASP.NET;ASP.NET Core;React.js;Vue.js
# 40442                                                     NaN
# 40487       Angular;Django;jQuery;React.js;Ruby on Rails;S...
# 42328                   Angular;ASP.NET;ASP.NET Core;React.js
# 44393                   Express;Gatsby;Laravel;Symfony;Vue.js
# 46458                                 Angular;Laravel;Symfony
# 46589                                                     NaN
# 47445                                   Flask;Gatsby;React.js
# 49218                                           Ruby on Rails
# 49948                                          Express;Vue.js
# 50020                                                     NaN
# 50891             ASP.NET;ASP.NET Core;React.js;Spring;Vue.js
# 53064                                            Flask;Spring
# 57434                                   Django;Flask;React.js
# 57497                                                     NaN
# 60042                                                     NaN
# 61246                                     Angular.js;React.js
# 61644                    ASP.NET;ASP.NET Core;React.js;Spring
# 62351                                                     NaN
# 65621                                                     NaN
#
#                                            WebframeWorkedWith  \
# Respondent
# 2373        Angular;Angular.js;ASP.NET;ASP.NET Core;jQuery...
# 2976           Angular;Angular.js;ASP.NET Core;Express;jQuery
# 3040                   Angular.js;Django;Express;Flask;jQuery
# 3172                                                 React.js
# 3959                                                      NaN
# 4868        Django;Express;Flask;Gatsby;jQuery;React.js;Ru...
# 5322                                                      NaN
# 14122                                   Angular;jQuery;Spring
# 14666                     Express;jQuery;Ruby on Rails;Spring
# 14992                                                  jQuery
# 15108       Angular;Angular.js;ASP.NET;ASP.NET Core;jQuery...
# 15140                                                  Spring
# 15195                                      Angular;Angular.js
# 15257                ASP.NET;ASP.NET Core;Flask;Ruby on Rails
# 15764                                 Express;Gatsby;React.js
# 15867                                 Express;jQuery;React.js
# 15903                                           Django;Vue.js
# 16120                                          Express;Vue.js
# 17652                 Express;Laravel;React.js;Symfony;Vue.js
# 17822                                         jQuery;React.js
# 19635                                          ASP.NET;jQuery
# 22314                                         React.js;Spring
# 24812                                        Express;React.js
# 25136                   Express;Gatsby;React.js;Ruby on Rails
# 25612                                 jQuery;Laravel;React.js
# 32392                                            Flask;jQuery
# 35206                                                  Vue.js
# 35239                         Angular;Angular.js;ASP.NET Core
# 35884       Angular;Angular.js;Django;Express;jQuery;React...
# 39669            Angular;ASP.NET;ASP.NET Core;jQuery;React.js
# 40442                                                     NaN
# 40487               Angular;Angular.js;jQuery;React.js;Spring
# 42328                                 ASP.NET;jQuery;React.js
# 44393                                                 Express
# 46458                                           jQuery;Spring
# 46589                                                     NaN
# 47445                                 Express;jQuery;React.js
# 49218                  Angular.js;ASP.NET;ASP.NET Core;jQuery
# 49948                                           Django;Vue.js
# 50020                                           Ruby on Rails
# 50891                                         React.js;Spring
# 53064                                    Express;Flask;Spring
# 57434                            Django;Flask;React.js;Vue.js
# 57497                                                     NaN
# 60042                                                  Django
# 61246                      Angular;ASP.NET Core;jQuery;Vue.js
# 61644                                                  Spring
# 62351                                                  Vue.js
# 65621                                                     NaN
#
#                                        WelcomeChange  WorkWeekHrs YearsCode  \
# Respondent
# 2373         Just as welcome now as I felt last year         45.0         9
# 2976        Somewhat more welcome now than last year         50.0        16
# 3040         Just as welcome now as I felt last year          NaN        13
# 3172         Just as welcome now as I felt last year          NaN         4
# 3959         Just as welcome now as I felt last year         30.0        15
# 4868         Just as welcome now as I felt last year         50.0        23
# 5322           A lot more welcome now than last year         42.0         5
# 14122        Just as welcome now as I felt last year         40.0        22
# 14666        Just as welcome now as I felt last year         40.0        15
# 14992        Just as welcome now as I felt last year          NaN         4
# 15108        Just as welcome now as I felt last year          8.0        11
# 15140       Somewhat less welcome now than last year         44.0        31
# 15195        Just as welcome now as I felt last year         60.0        19
# 15257        Just as welcome now as I felt last year         35.0        13
# 15764        Just as welcome now as I felt last year         25.0         6
# 15867        Just as welcome now as I felt last year         40.0        15
# 15903        Just as welcome now as I felt last year         45.0        15
# 16120        Just as welcome now as I felt last year         33.0         9
# 17652        Just as welcome now as I felt last year         40.0        22
# 17822        Just as welcome now as I felt last year         36.0         2
# 19635        Just as welcome now as I felt last year         40.0        12
# 22314        Just as welcome now as I felt last year          NaN        18
# 24812        Just as welcome now as I felt last year          NaN         7
# 25136        Just as welcome now as I felt last year         40.0        14
# 25612        Just as welcome now as I felt last year         35.0        15
# 32392        Just as welcome now as I felt last year         40.0        14
# 35206        Just as welcome now as I felt last year         50.0        35
# 35239        Just as welcome now as I felt last year         40.0        12
# 35884          A lot less welcome now than last year         50.0        11
# 39669       Somewhat more welcome now than last year          NaN         9
# 40442                                            NaN         40.0        16
# 40487       Somewhat more welcome now than last year         40.0        20
# 42328       Somewhat more welcome now than last year         40.0        25
# 44393        Just as welcome now as I felt last year          NaN         4
# 46458        Just as welcome now as I felt last year         30.0         5
# 46589        Just as welcome now as I felt last year          NaN        10
# 47445        Just as welcome now as I felt last year         40.0         9
# 49218        Just as welcome now as I felt last year         40.0         3
# 49948        Just as welcome now as I felt last year         50.0         9
# 50020        Just as welcome now as I felt last year         40.0        20
# 50891        Just as welcome now as I felt last year         40.0         5
# 53064        Just as welcome now as I felt last year         40.0        17
# 57434        Just as welcome now as I felt last year         40.0        15
# 57497        Just as welcome now as I felt last year         45.0         8
# 60042        Just as welcome now as I felt last year         40.0         4
# 61246        Just as welcome now as I felt last year         44.0        27
# 61644       Somewhat more welcome now than last year         40.0        11
# 62351        Just as welcome now as I felt last year         20.0        12
# 65621                                            NaN          NaN         4
#
#                 YearsCodePro
# Respondent
# 2373                       5
# 2976                       7
# 3040                     NaN
# 3172                     NaN
# 3959                       1
# 4868                      10
# 5322                       2
# 14122                     18
# 14666                      4
# 14992                    NaN
# 15108                      4
# 15140                     31
# 15195                     14
# 15257                      8
# 15764                      1
# 15867                     12
# 15903                      9
# 16120                      7
# 17652                     18
# 17822                      1
# 19635                      6
# 22314                     10
# 24812                      1
# 25136                     12
# 25612       Less than 1 year
# 32392                      4
# 35206                     24
# 35239                      4
# 35884                     11
# 39669                      2
# 40442                     10
# 40487                     12
# 42328                     19
# 44393                    NaN
# 46458                      1
# 46589                    NaN
# 47445                      7
# 49218                      1
# 49948                      1
# 50020                     17
# 50891                      4
# 53064                     12
# 57434                     13
# 57497                      3
# 60042                      3
# 61246                     30
# 61644                     10
# 62351                      5
# 65621                    NaN

# %%
filter_ConvertedComp_br = ((df['Country'] == 'Brazil') & (df['ConvertedComp'] >= 130000))

# %%
df.loc[filter_ConvertedComp_br, ['LanguageWorkedWith', 'ConvertedComp']]
# Out:
#                                            LanguageWorkedWith  ConvertedComp
# Respondent
# 2931                        C#;HTML/CSS;JavaScript;Python;SQL       329856.0
# 10949                   C#;HTML/CSS;JavaScript;SQL;TypeScript       188016.0
# 17681                                     Java;JavaScript;VBA      1000000.0
# 24307       Bash/Shell/PowerShell;HTML/CSS;Java;Kotlin;Obj...       629484.0
# 42056       Bash/Shell/PowerShell;C#;HTML/CSS;Java;JavaScr...       164928.0
# 49623                                   Assembly;C;C#;C++;SQL       412324.0
# 51207                                     C#;HTML/CSS;SQL;VBA       250140.0
# 58698                                     HTML/CSS;JavaScript       131940.0
# 60111                                                Java;SQL       549768.0

# %%
countries = ['Brazil', 'India', 'Canada']
filter_countries = (df['Country'].isin(countries)) & (df['ConvertedComp'] >= 130000)

# %%
df.loc[filter_countries, ['Country', 'LanguageWorkedWith', 'ConvertedComp']]
# Out:
#            Country                                 LanguageWorkedWith  \
# Respondent
# 149          India                     Bash/Shell/PowerShell;C++;Perl
# 279          India  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# 304         Canada        HTML/CSS;Java;JavaScript;Perl;PHP;Scala;SQL
# 313         Canada  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# 374         Canada  Bash/Shell/PowerShell;C#;Go;HTML/CSS;Java;Java...
# ...            ...                                                ...
# 62919       Canada                                                NaN
# 63350       Canada   Bash/Shell/PowerShell;Go;HTML/CSS;JavaScript;SQL
# 63837        India                                                NaN
# 64875       Canada  Bash/Shell/PowerShell;Haskell;HTML/CSS;JavaScr...
# 65528       Canada                                             Python
#
#             ConvertedComp
# Respondent
# 149              293196.0
# 279              150792.0
# 304              136136.0
# 313             1000000.0
# 374              136136.0
# ...                   ...
# 62919            136140.0
# 63350           1000000.0
# 63837            163345.0
# 64875            151263.0
# 65528            151263.0
#
# [245 rows x 3 columns]

# %%
filter_language = df['LanguageWorkedWith'].str.contains('C#', na=False)#na==NaN

# %%
df.loc[filter_language, 'LanguageWorkedWith']
# Out:
# Respondent
# 1                                   C#;HTML/CSS;JavaScript
# 7                                          C#;HTML/CSS;PHP
# 11                                     C#;JavaScript;Swift
# 17                   C#;HTML/CSS;JavaScript;Python;SQL;VBA
# 19       Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;S...
#                                ...
# 63452    Bash/Shell/PowerShell;C#;C++;HTML/CSS;JavaScri...
# 63640    Bash/Shell/PowerShell;C;C#;C++;HTML/CSS;Java;J...
# 63796                    C#;HTML/CSS;Java;JavaScript;Swift
# 64867    Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 65112                      C#;HTML/CSS;Java;JavaScript;SQL
# Name: LanguageWorkedWith, Length: 18041, dtype: object

# %%
df.columns = [uc.upper() for uc in df.columns]
df
# Out:
#                                                      NaN
# 5                                             Java;Ruby;Scala
# ...                                                       ...
# 64858                                                     NaN
# 64867       Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64898                                                     NaN
# 64925                                HTML/CSS;Java;JavaScript
# 65112                         C#;HTML/CSS;Java;JavaScript;SQL
#
#                                            LANGUAGEWORKEDWITH  \
# Respondent
# 1                                      C#;HTML/CSS;JavaScript
# 2                                            JavaScript;Swift
# 3                                    Objective-C;Python;Swift
# 4                                                         NaN
# 5                                           HTML/CSS;Ruby;SQL
# ...                                                       ...
# 64858                                                     NaN
# 64867       Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64898                                                     NaN
# 64925                                                HTML/CSS
# 65112                         C#;HTML/CSS;Java;JavaScript;SQL
#
#                       MISCTECHDESIRENEXTYEAR MISCTECHWORKEDWITH  \
# Respondent
# 1                          .NET Core;Xamarin     .NET;.NET Core
# 2           React Native;TensorFlow;Unity 3D       React Native
# 3                                        NaN                NaN
# 4                                        NaN                NaN
# 5                               Ansible;Chef            Ansible
# ...                                      ...                ...
# 64858                                    NaN                NaN
# 64867                                    NaN                NaN
# 64898                                    NaN                NaN
# 64925                                Node.js                NaN
# 65112                      .NET Core;Xamarin     .NET;.NET Core
#
#                       NEWCOLLABTOOLSDESIRENEXTYEAR  \
# Respondent
# 1           Microsoft Teams;Microsoft Azure;Trello
# 2                                     Github;Slack
# 3                                              NaN
# 4                                              NaN
# 5            Github;Google Suite (Docs, Meet, etc)
# ...                                            ...
# 64858                                          NaN
# 64867                                          NaN
# 64898                                          NaN
# 64925                                Github;Gitlab
# 65112                       Github;Microsoft Teams
#
#                                      NEWCOLLABTOOLSWORKEDWITH NEWDEVOPS  \
# Respondent
# 1                Confluence;Jira;Slack;Microsoft Azure;Trello        No
# 2                         Confluence;Jira;Github;Gitlab;Slack       NaN
# 3                                                         NaN       NaN
# 4                                                         NaN        No
# 5           Confluence;Jira;Github;Slack;Google Suite (Doc...       NaN
# ...                                                       ...       ...
# 64858                                                     NaN       NaN
# 64867                                                     NaN       NaN
# 64898                                                     NaN       NaN
# 64925                   Confluence;Jira;Slack;Microsoft Teams       NaN
# 65112                                                  Github       NaN
#
#                  NEWDEVOPSIMPT                           NEWEDIMPT  \
# Respondent
# 1           Somewhat important                    Fairly important
# 2                          NaN                    Fairly important
# 3                          NaN                                 NaN
# 4                          NaN  Not at all important/not necessary
# 5                          NaN                      Very important
# ...                        ...                                 ...
# 64858                      NaN                      Very important
# 64867                      NaN                                 NaN
# 64898                      NaN                                 NaN
# 64925                      NaN                                 NaN
# 65112                      NaN                Critically important
#
#                                                    NEWJOBHUNT  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4           Curious about other opportunities;Wanting to w...
# 5                                                         NaN
# ...                                                       ...
# 64858                                                     NaN
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                                     NaN
# 65112                                                     NaN
#
#            NEWJOBHUNTRESEARCH       NEWLEARN NEWOFFTOPIC NEWONBOARDGOOD  \
# Respondent
# 1                         NaN    Once a year    Not sure            NaN
# 2                         NaN    Once a year    Not sure            NaN
# 3                         NaN  Once a decade         NaN            NaN
# 4                         NaN    Once a year    Not sure            Yes
# 5                         NaN    Once a year          No            NaN
# ...                       ...            ...         ...            ...
# 64858                     NaN  Once a decade         NaN            NaN
# 64867                     NaN            NaN         NaN            NaN
# 64898                     NaN            NaN         NaN            NaN
# 64925                     NaN    Once a year         NaN            NaN
# 65112                     NaN    Once a year         NaN            NaN
#
#            NEWOTHERCOMMS                                        NEWOVERTIME  \
# Respondent
# 1                     No                   Often: 1-2 days per week or more
# 2                     No                                                NaN
# 3                     No                                                NaN
# 4                    Yes  Occasionally: 1-2 days per quarter but less th...
# 5                    Yes                                                NaN
# ...                  ...                                                ...
# 64858                NaN                                                NaN
# 64867                NaN                                                NaN
# 64898                NaN                                                NaN
# 64925                NaN                                                NaN
# 65112                NaN                                                NaN
#
#                                           NEWPURCHASERESEARCH  \
# Respondent
# 1           Start a free trial;Ask developers I know/work ...
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
# 5           Start a free trial;Ask developers I know/work ...
# ...                                                       ...
# 64858                                      Start a free trial
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                      Start a free trial
# 65112       Start a free trial;Ask developers I know/work ...
#
#                 NEWPURPLELINK  \
# Respondent
# 1                      Amused
# 2                      Amused
# 3                         NaN
# 4                         NaN
# 5           Hello, old friend
# ...                       ...
# 64858                  Amused
# 64867                     NaN
# 64898                     NaN
# 64925       Hello, old friend
# 65112             Indifferent
#
#                                                    NEWSOSITES  \
# Respondent
# 1            Stack Overflow (public Q&A for anyone who codes)
# 2           Stack Overflow (public Q&A for anyone who code...
# 3            Stack Overflow (public Q&A for anyone who codes)
# 4           Stack Overflow (public Q&A for anyone who code...
# 5           Stack Overflow (public Q&A for anyone who code...
# ...                                                       ...
# 64858        Stack Overflow (public Q&A for anyone who codes)
# 64867                                                     NaN
# 64898                                                     NaN
# 64925        Stack Overflow (public Q&A for anyone who codes)
# 65112                                                     NaN
#
#                                                      NEWSTUCK        OPSYS  \
# Respondent
# 1           Visit Stack Overflow;Go for a walk or other ph...      Windows
# 2           Visit Stack Overflow;Go for a walk or other ph...        MacOS
# 3                                                         NaN  Linux-based
# 4                                                         NaN  Linux-based
# 5           Call a coworker or friend;Visit Stack Overflow...      Windows
# ...                                                       ...          ...
# 64858                               Call a coworker or friend      Windows
# 64867                                                     NaN          NaN
# 64898                                                     NaN          NaN
# 64925          Call a coworker or friend;Visit Stack Overflow      Windows
# 65112       Meditate;Visit Stack Overflow;Go for a walk or...      Windows
#
#                              ORGSIZE  \
# Respondent
# 1                   2 to 9 employees
# 2           1,000 to 4,999 employees
# 3                                NaN
# 4                 20 to 99 employees
# 5                                NaN
# ...                              ...
# 64858                            NaN
# 64867                            NaN
# 64898                            NaN
# 64925                            NaN
# 65112                            NaN
#
#                                        PLATFORMDESIRENEXTYEAR  \
# Respondent
# 1              Android;iOS;Kubernetes;Microsoft Azure;Windows
# 2                                  iOS;Kubernetes;Linux;MacOS
# 3                                                         NaN
# 4                                                         NaN
# 5           Docker;Google Cloud Platform;Heroku;Linux;Windows
# ...                                                       ...
# 64858                                                     NaN
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                                     NaN
# 65112                      Arduino;Linux;Raspberry Pi;Windows
#
#                                     PLATFORMWORKEDWITH  \
# Respondent
# 1                                              Windows
# 2                                                  iOS
# 3                                                  NaN
# 4                                                  NaN
# 5                       AWS;Docker;Linux;MacOS;Windows
# ...                                                ...
# 64858                                              NaN
# 64867                                              NaN
# 64898                                              NaN
# 64925                                    Linux;Windows
# 65112       Android;Arduino;Linux;Raspberry Pi;Windows
#
#                                 PURCHASEWHAT                SEXUALITY  \
# Respondent
# 1                                        NaN  Straight / Heterosexual
# 2              I have little or no influence                      NaN
# 3                                        NaN                      NaN
# 4           I have a great deal of influence  Straight / Heterosexual
# 5                                        NaN  Straight / Heterosexual
# ...                                      ...                      ...
# 64858                                    NaN                      NaN
# 64867                                    NaN                      NaN
# 64898                                    NaN                      NaN
# 64925                                    NaN                      NaN
# 65112                                    NaN                      NaN
#
#            SOACCOUNT           SOCOMM                           SOPARTFREQ  \
# Respondent
# 1                 No   No, not at all                                  NaN
# 2                Yes  Yes, definitely  Less than once per month or monthly
# 3                Yes    Yes, somewhat      A few times per month or weekly
# 4                Yes  Yes, definitely      A few times per month or weekly
# 5                Yes    Yes, somewhat  Less than once per month or monthly
# ...              ...              ...                                  ...
# 64858            NaN              NaN                                  NaN
# 64867            NaN              NaN                                  NaN
# 64898            NaN              NaN                                  NaN
# 64925            NaN              NaN                                  NaN
# 65112            NaN              NaN                                  NaN
#
#                                 SOVISITFREQ                  SURVEYEASE  \
# Respondent
# 1                    Multiple times per day  Neither easy nor difficult
# 2                    Multiple times per day                         NaN
# 3                     Daily or almost daily  Neither easy nor difficult
# 4                    Multiple times per day                         NaN
# 5           A few times per month or weekly                        Easy
# ...                                     ...                         ...
# 64858                                   NaN                         NaN
# 64867                                   NaN                         NaN
# 64898                                   NaN                         NaN
# 64925                                   NaN                         NaN
# 65112                                   NaN                         NaN
#
#                      SURVEYLENGTH TRANS  \
# Respondent
# 1           Appropriate in length    No
# 2                             NaN   NaN
# 3           Appropriate in length   NaN
# 4                             NaN    No
# 5                       Too short    No
# ...                           ...   ...
# 64858                         NaN   NaN
# 64867                         NaN   NaN
# 64898                         NaN   NaN
# 64925                         NaN   NaN
# 65112                         NaN   NaN
#
#                                                UNDERGRADMAJOR  \
# Respondent
# 1           Computer science, computer engineering, or sof...
# 2           Computer science, computer engineering, or sof...
# 3                                                         NaN
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
# ...                                                       ...
# 64858       Computer science, computer engineering, or sof...
# 64867                                                     NaN
# 64898                                                     NaN
# 64925                                                     NaN
# 65112       Computer science, computer engineering, or sof...
#
#                  WEBFRAMEDESIRENEXTYEAR  \
# Respondent
# 1                          ASP.NET Core
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                  Django;Ruby on Rails
# ...                                 ...
# 64858                               NaN
# 64867                               NaN
# 64898                               NaN
# 64925       Angular;Angular.js;React.js
# 65112               ASP.NET Core;jQuery
#
#                                 WEBFRAMEWORKEDWITH  \
# Respondent
# 1                             ASP.NET;ASP.NET Core
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# 5                                    Ruby on Rails
# ...                                            ...
# 64858                                          NaN
# 64867                                          NaN
# 64898                                          NaN
# 64925                                          NaN
# 65112       Angular;Angular.js;ASP.NET Core;jQuery
#
#                                        WELCOMECHANGE  WORKWEEKHRS YEARSCODE  \
# Respondent
# 1            Just as welcome now as I felt last year         50.0        36
# 2           Somewhat more welcome now than last year          NaN         7
# 3           Somewhat more welcome now than last year          NaN         4
# 4           Somewhat less welcome now than last year         40.0         7
# 5            Just as welcome now as I felt last year          NaN        15
# ...                                              ...          ...       ...
# 64858                                            NaN          NaN        10
# 64867                                            NaN          NaN       NaN
# 64898                                            NaN          NaN       NaN
# 64925                                            NaN          NaN       NaN
# 65112                                            NaN          NaN       NaN
#
#                 YEARSCODEPRO
# Respondent
# 1                         27
# 2                          4
# 3                        NaN
# 4                          4
# 5                          8
# ...                      ...
# 64858       Less than 1 year
# 64867                    NaN
# 64898                    NaN
# 64925                    NaN
# 65112                    NaN
#
# [64461 rows x 60 columns]

# %%
df['HOBBYIST'].map({'Yes':True, 'No': False})
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4         True
# 5         True
#          ...
# 64858     True
# 64867     True
# 64898     True
# 64925     True
# 65112     True
# Name: HOBBYIST, Length: 64461, dtype: object

# %%
df.columns
# Out:
# Index(['MAINBRANCH', 'HOBBYIST', 'AGE', 'AGE1STCODE', 'COMPFREQ', 'COMPTOTAL',
#        'CONVERTEDCOMP', 'COUNTRY', 'CURRENCYDESC', 'CURRENCYSYMBOL',
#        'DATABASEDESIRENEXTYEAR', 'DATABASEWORKEDWITH', 'DEVTYPE', 'EDLEVEL',
#        'EMPLOYMENT', 'ETHNICITY', 'GENDER', 'JOBFACTORS', 'JOBSAT', 'JOBSEEK',
#        'LANGUAGEDESIRENEXTYEAR', 'LANGUAGEWORKEDWITH',
#        'MISCTECHDESIRENEXTYEAR', 'MISCTECHWORKEDWITH',
#        'NEWCOLLABTOOLSDESIRENEXTYEAR', 'NEWCOLLABTOOLSWORKEDWITH', 'NEWDEVOPS',
#        'NEWDEVOPSIMPT', 'NEWEDIMPT', 'NEWJOBHUNT', 'NEWJOBHUNTRESEARCH',
#        'NEWLEARN', 'NEWOFFTOPIC', 'NEWONBOARDGOOD', 'NEWOTHERCOMMS',
#        'NEWOVERTIME', 'NEWPURCHASERESEARCH', 'NEWPURPLELINK', 'NEWSOSITES',
#        'NEWSTUCK', 'OPSYS', 'ORGSIZE', 'PLATFORMDESIRENEXTYEAR',
#        'PLATFORMWORKEDWITH', 'PURCHASEWHAT', 'SEXUALITY', 'SOACCOUNT',
#        'SOCOMM', 'SOPARTFREQ', 'SOVISITFREQ', 'SURVEYEASE', 'SURVEYLENGTH',
#        'TRANS', 'UNDERGRADMAJOR', 'WEBFRAMEDESIRENEXTYEAR',
#        'WEBFRAMEWORKEDWITH', 'WELCOMECHANGE', 'WORKWEEKHRS', 'YEARSCODE',
#        'YEARSCODEPRO'],
#       dtype='object')

# %%
df.sort_values(by=['COUNTRY', 'CONVERTEDCOMP'], ascending=[True, False], inplace=True)
df[['COUNTRY', 'CONVERTEDCOMP']].head(100)
# Out:
#                 COUNTRY  CONVERTEDCOMP
# Respondent
# 62788       Afghanistan      1000000.0
# 65381       Afghanistan      1000000.0
# 65456       Afghanistan      1000000.0
# 38672       Afghanistan       231192.0
# 28374       Afghanistan       130000.0
# 9839        Afghanistan        23328.0
# 63848       Afghanistan        23328.0
# 51862       Afghanistan        20950.0
# 51509       Afghanistan        20220.0
# 44484       Afghanistan        18660.0
# 15422       Afghanistan        18000.0
# 2932        Afghanistan        16335.0
# 26540       Afghanistan        13992.0
# 57269       Afghanistan        10884.0
# 26775       Afghanistan         8016.0
# 30568       Afghanistan         5448.0
# 30522       Afghanistan         4668.0
# 28811       Afghanistan         4509.0
# 34969       Afghanistan         4356.0
# 26857       Afghanistan         2328.0
# 33878       Afghanistan         1860.0
# 35753       Afghanistan          780.0
# 18049       Afghanistan          109.0
# 35295       Afghanistan            0.0
# 898         Afghanistan            NaN
# 5972        Afghanistan            NaN
# 7616        Afghanistan            NaN
# 7710        Afghanistan            NaN
# 8631        Afghanistan            NaN
# 8856        Afghanistan            NaN
# 9486        Afghanistan            NaN
# 9617        Afghanistan            NaN
# 10350       Afghanistan            NaN
# 23798       Afghanistan            NaN
# 24215       Afghanistan            NaN
# 25001       Afghanistan            NaN
# 26575       Afghanistan            NaN
# 26594       Afghanistan            NaN
# 26623       Afghanistan            NaN
# 29893       Afghanistan            NaN
# 30608       Afghanistan            NaN
# 31317       Afghanistan            NaN
# 35179       Afghanistan            NaN
# 35656       Afghanistan            NaN
# 35687       Afghanistan            NaN
# 36574       Afghanistan            NaN
# 37159       Afghanistan            NaN
# 37601       Afghanistan            NaN
# 37698       Afghanistan            NaN
# 37951       Afghanistan            NaN
# 39217       Afghanistan            NaN
# 39582       Afghanistan            NaN
# 40349       Afghanistan            NaN
# 42188       Afghanistan            NaN
# 42668       Afghanistan            NaN
# 43183       Afghanistan            NaN
# 43808       Afghanistan            NaN
# 43946       Afghanistan            NaN
# 43966       Afghanistan            NaN
# 44555       Afghanistan            NaN
# 44556       Afghanistan            NaN
# 44697       Afghanistan            NaN
# 45409       Afghanistan            NaN
# 45481       Afghanistan            NaN
# 45973       Afghanistan            NaN
# 46844       Afghanistan            NaN
# 51532       Afghanistan            NaN
# 51683       Afghanistan            NaN
# 51900       Afghanistan            NaN
# 52876       Afghanistan            NaN
# 55019       Afghanistan            NaN
# 55232       Afghanistan            NaN
# 57632       Afghanistan            NaN
# 58171       Afghanistan            NaN
# 60507       Afghanistan            NaN
# 62698       Afghanistan            NaN
# 62950       Afghanistan            NaN
# 63499       Afghanistan            NaN
# 63514       Afghanistan            NaN
# 63532       Afghanistan            NaN
# 11353       Afghanistan            NaN
# 36423       Afghanistan            NaN
# 37605       Afghanistan            NaN
# 43476       Afghanistan            NaN
# 23342           Albania       194580.0
# 19666           Albania        32652.0
# 13065           Albania        31788.0
# 45079           Albania        31788.0
# 10647           Albania        25944.0
# 26843           Albania        25944.0
# 17228           Albania        23316.0
# 58427           Albania        21192.0
# 61050           Albania        16860.0
# 21952           Albania        15900.0
# 28900           Albania        15900.0
# 51520           Albania        15900.0
# 23498           Albania        13776.0
# 37526           Albania        12972.0
# 564             Albania        10812.0
# 27714           Albania        10596.0

# %%
df['CONVERTEDCOMP'].nlargest(10)
# Out:
# Respondent
# 5725     2000000.0
# 54263    2000000.0
# 43430    2000000.0
# 59279    2000000.0
# 46711    2000000.0
# 123      2000000.0
# 125      2000000.0
# 193      2000000.0
# 665      2000000.0
# 699      2000000.0
# Name: CONVERTEDCOMP, dtype: float64

# %%
df.nlargest(10, 'CONVERTEDCOMP')
# Out:
#                                                Teraform
# 54263                   React Native;TensorFlow;Torch/PyTorch
# 43430                                                     NaN
# 59279       Ansible;Apache Spark;Flutter;Hadoop;Keras;Pand...
# 46711       .NET;.NET Core;Ansible;Apache Spark;Chef;Cordo...
# 123                   Flutter;Hadoop;TensorFlow;Unreal Engine
# 125                     Keras;Pandas;TensorFlow;Torch/PyTorch
# 193                                                       NaN
# 665                                                   Node.js
# 699                .NET;.NET Core;Pandas;Puppet;Unreal Engine
#
#                                            MISCTECHWORKEDWITH  \
# Respondent
# 5725                                                      NaN
# 54263                                         Flutter;Node.js
# 43430                                                     NaN
# 59279       .NET;.NET Core;Chef;Cordova;Node.js;React Nati...
# 46711       .NET;.NET Core;Ansible;Apache Spark;Chef;Cordo...
# 123                                                 .NET Core
# 125                                   Keras;Pandas;TensorFlow
# 193                                                       NaN
# 665                                                   Node.js
# 699                                                       NaN
#
#                                  NEWCOLLABTOOLSDESIRENEXTYEAR  \
# Respondent
# 5725             Github;Gitlab;Google Suite (Docs, Meet, etc)
# 54263                                      Facebook Workplace
# 43430       Confluence;Jira;Github;Gitlab;Slack;Google Sui...
# 59279                                           Gitlab;Trello
# 46711       Confluence;Jira;Github;Gitlab;Facebook Workpla...
# 123                              Confluence;Jira;Github;Slack
# 125                                                      Jira
# 193         Github;Slack;Trello;Google Suite (Docs, Meet, ...
# 665          Jira;Github;Slack;Google Suite (Docs, Meet, etc)
# 699         Microsoft Teams;Microsoft Azure;Trello;Google ...
#
#                                      NEWCOLLABTOOLSWORKEDWITH NEWDEVOPS  \
# Respondent
# 5725                    Github;Google Suite (Docs, Meet, etc)       Yes
# 54263       Confluence;Jira;Github;Gitlab;Slack;Microsoft ...       Yes
# 43430       Confluence;Jira;Github;Gitlab;Slack;Google Sui...       Yes
# 59279       Confluence;Jira;Github;Facebook Workplace;Slac...       Yes
# 46711       Confluence;Jira;Github;Gitlab;Facebook Workpla...       Yes
# 123         Confluence;Jira;Github;Gitlab;Slack;Microsoft ...       Yes
# 125                                                      Jira  Not sure
# 193         Github;Gitlab;Slack;Microsoft Teams;Trello;Goo...        No
# 665          Jira;Github;Slack;Google Suite (Docs, Meet, etc)       Yes
# 699         Jira;Microsoft Teams;Microsoft Azure;Trello;Go...        No
#
#                   NEWDEVOPSIMPT                           NEWEDIMPT  \
# Respondent
# 5725        Extremely important                      Very important
# 54263       Extremely important                  Somewhat important
# 43430        Somewhat important                    Fairly important
# 59279       Extremely important                                 NaN
# 46711       Extremely important  Not at all important/not necessary
# 123          Somewhat important                      Very important
# 125                     Neutral                Critically important
# 193                     Neutral                    Fairly important
# 665         Extremely important                  Somewhat important
# 699          Somewhat important                Critically important
#
#                                                    NEWJOBHUNT  \
# Respondent
# 5725        Trouble with my teammates;Better work/life bal...
# 54263       Just because;Curious about other opportunities...
# 43430       Curious about other opportunities;Better compe...
# 59279       Having a bad day (or week or month) at work;Tr...
# 46711       Just because;Having a bad day (or week or mont...
# 123         Trouble with my direct manager;Trouble with le...
# 125                                  Better work/life balance
# 193         Curious about other opportunities;Better compe...
# 665         Better compensation;Trouble with leadership at...
# 699                        Growth or leadership opportunities
#
#                                            NEWJOBHUNTRESEARCH  \
# Respondent
# 5725        Read company media, such as employee blogs or ...
# 54263       Read company media, such as employee blogs or ...
# 43430       Read company media, such as employee blogs or ...
# 59279       Read company media, such as employee blogs or ...
# 46711       Read company media, such as employee blogs or ...
# 123         Read company media, such as employee blogs or ...
# 125         Personal network - friends or family;Directly ...
# 193         Read company media, such as employee blogs or ...
# 665         Read company media, such as employee blogs or ...
# 699         Read company media, such as employee blogs or ...
#
#                         NEWLEARN NEWOFFTOPIC                NEWONBOARDGOOD  \
# Respondent
# 5725                 Once a year          No                           Yes
# 54263           Every few months    Not sure                           Yes
# 43430       Once every few years    Not sure                           Yes
# 59279                        NaN         Yes                           Yes
# 46711           Every few months         NaN                           Yes
# 123                  Once a year         Yes                            No
# 125         Once every few years          No                           Yes
# 193             Every few months          No  Onboarding? What onboarding?
# 665                  Once a year    Not sure                           Yes
# 699                  Once a year         NaN                            No
#
#            NEWOTHERCOMMS                                        NEWOVERTIME  \
# Respondent
# 5725                  No                   Often: 1-2 days per week or more
# 54263                Yes                  Rarely: 1-2 days per year or less
# 43430                 No                   Often: 1-2 days per week or more
# 59279                 No  Sometimes: 1-2 days per month but less than we...
# 46711                NaN                   Often: 1-2 days per week or more
# 123                   No                  Rarely: 1-2 days per year or less
# 125                   No  Occasionally: 1-2 days per quarter but less th...
# 193                   No                                              Never
# 665                  Yes  Occasionally: 1-2 days per quarter but less th...
# 699                   No                   Often: 1-2 days per week or more
#
#                                           NEWPURCHASERESEARCH  \
# Respondent
# 5725                                                      NaN
# 54263       Start a free trial;Ask developers I know/work ...
# 43430                                      Start a free trial
# 59279       Start a free trial;Ask developers I know/work ...
# 46711                                                     NaN
# 123         Start a free trial;Ask developers I know/work ...
# 125                                                       NaN
# 193                                                       NaN
# 665                                                       NaN
# 699         Start a free trial;Visit developer communities...
#
#                 NEWPURPLELINK  \
# Respondent
# 5725        Hello, old friend
# 54263       Hello, old friend
# 43430             Indifferent
# 59279                  Amused
# 46711       Hello, old friend
# 123               Indifferent
# 125                    Amused
# 193         Hello, old friend
# 665               Indifferent
# 699         Hello, old friend
#
#                                                    NEWSOSITES  \
# Respondent
# 5725        Stack Overflow (public Q&A for anyone who code...
# 54263       Stack Overflow (public Q&A for anyone who code...
# 43430        Stack Overflow (public Q&A for anyone who codes)
# 59279       Stack Overflow (public Q&A for anyone who code...
# 46711       Stack Overflow (public Q&A for anyone who code...
# 123         Stack Overflow (public Q&A for anyone who code...
# 125         Stack Overflow (public Q&A for anyone who code...
# 193         Stack Overflow (public Q&A for anyone who code...
# 665         Stack Overflow (public Q&A for anyone who code...
# 699                   I have never visited any of these sites
#
#                                                      NEWSTUCK        OPSYS  \
# Respondent
# 5725        Call a coworker or friend;Go for a walk or oth...  Linux-based
# 54263       Meditate;Visit Stack Overflow;Go for a walk or...        MacOS
# 43430       Call a coworker or friend;Go for a walk or oth...  Linux-based
# 59279       Call a coworker or friend;Visit Stack Overflow...      Windows
# 46711       Meditate;Play games;Call a coworker or friend;...          NaN
# 123         Visit Stack Overflow;Go for a walk or other ph...  Linux-based
# 125         Visit Stack Overflow;Go for a walk or other ph...      Windows
# 193         Play games;Visit Stack Overflow;Do other work ...        MacOS
# 665         Call a coworker or friend;Visit Stack Overflow...        MacOS
# 699         Call a coworker or friend;Visit Stack Overflow...      Windows
#
#                              ORGSIZE  \
# Respondent
# 5725        10,000 or more employees
# 54263                            NaN
# 43430       10,000 or more employees
# 59279       1,000 to 4,999 employees
# 46711       10,000 or more employees
# 123         10,000 or more employees
# 125         5,000 to 9,999 employees
# 193               10 to 19 employees
# 665         1,000 to 4,999 employees
# 699             100 to 499 employees
#
#                                        PLATFORMDESIRENEXTYEAR  \
# Respondent
# 5725                             Docker;Google Cloud Platform
# 54263                            Docker;Heroku;iOS;Kubernetes
# 43430                             Android;Linux;MacOS;Windows
# 59279       Arduino;Heroku;IBM Cloud or Watson;Kubernetes;...
# 46711       Android;Arduino;AWS;Docker;Google Cloud Platfo...
# 123         Android;Arduino;AWS;Docker;Google Cloud Platfo...
# 125                                         Docker;Kubernetes
# 193                                               Android;iOS
# 665         AWS;Google Cloud Platform;Kubernetes;Linux;Mac...
# 699         Android;Arduino;AWS;Google Cloud Platform;Kube...
#
#                                            PLATFORMWORKEDWITH  \
# Respondent
# 5725                             Docker;Google Cloud Platform
# 54263                                       Android;AWS;Linux
# 43430                             Android;Linux;MacOS;Windows
# 59279       Android;AWS;Docker;Google Cloud Platform;iOS;L...
# 46711       Android;Arduino;AWS;Docker;Google Cloud Platfo...
# 123                             AWS;Docker;Linux;Raspberry Pi
# 125                                                    Docker
# 193                                               Android;iOS
# 665              Google Cloud Platform;Heroku;MacOS;WordPress
# 699                                                 WordPress
#
#                                 PURCHASEWHAT                SEXUALITY  \
# Respondent
# 5725           I have little or no influence  Straight / Heterosexual
# 54263                  I have some influence  Straight / Heterosexual
# 43430                  I have some influence  Straight / Heterosexual
# 59279       I have a great deal of influence                      NaN
# 46711          I have little or no influence                      NaN
# 123                    I have some influence  Straight / Heterosexual
# 125            I have little or no influence  Straight / Heterosexual
# 193            I have little or no influence  Straight / Heterosexual
# 665            I have little or no influence           Bisexual;Queer
# 699                                      NaN  Straight / Heterosexual
#
#                           SOACCOUNT          SOCOMM  \
# Respondent
# 5725                            Yes  No, not at all
# 54263       Not sure/can't remember   Yes, somewhat
# 43430                           Yes  No, not at all
# 59279                           Yes   Yes, somewhat
# 46711                           NaN             NaN
# 123                             Yes   Yes, somewhat
# 125         Not sure/can't remember  No, not really
# 193                             Yes  No, not really
# 665                             Yes  No, not really
# 699                             NaN             NaN
#
#                                                    SOPARTFREQ  \
# Respondent
# 5725        I have never participated in Q&A on Stack Over...
# 54263                                                     NaN
# 43430       I have never participated in Q&A on Stack Over...
# 59279       I have never participated in Q&A on Stack Over...
# 46711                                                     NaN
# 123                       Less than once per month or monthly
# 125                                                       NaN
# 193                       Less than once per month or monthly
# 665         I have never participated in Q&A on Stack Over...
# 699                                                       NaN
#
#                                 SOVISITFREQ                  SURVEYEASE  \
# Respondent
# 5725        A few times per month or weekly                        Easy
# 54263                 Daily or almost daily  Neither easy nor difficult
# 43430       A few times per month or weekly                        Easy
# 59279                Multiple times per day  Neither easy nor difficult
# 46711                Multiple times per day                         NaN
# 123                   Daily or almost daily                        Easy
# 125                  Multiple times per day                        Easy
# 193                    A few times per week  Neither easy nor difficult
# 665         A few times per month or weekly  Neither easy nor difficult
# 699                                     NaN  Neither easy nor difficult
#
#                      SURVEYLENGTH TRANS  \
# Respondent
# 5725                    Too short    No
# 54263                    Too long    No
# 43430       Appropriate in length    No
# 59279                    Too long   NaN
# 46711                         NaN   NaN
# 123         Appropriate in length    No
# 125         Appropriate in length    No
# 193         Appropriate in length    No
# 665         Appropriate in length    No
# 699         Appropriate in length    No
#
#                                                UNDERGRADMAJOR  \
# Respondent
# 5725        Computer science, computer engineering, or sof...
# 54263       Computer science, computer engineering, or sof...
# 43430       Computer science, computer engineering, or sof...
# 59279       Computer science, computer engineering, or sof...
# 46711                                                     NaN
# 123         Computer science, computer engineering, or sof...
# 125                                                       NaN
# 193         Computer science, computer engineering, or sof...
# 665         A humanities discipline (such as literature, h...
# 699         Information systems, information technology, o...
#
#                                        WEBFRAMEDESIRENEXTYEAR  \
# Respondent
# 5725                                                   Gatsby
# 54263                                         React.js;Vue.js
# 43430                                                     NaN
# 59279                      Django;Drupal;Flask;Gatsby;Laravel
# 46711       Angular;Angular.js;ASP.NET;ASP.NET Core;Django...
# 123                                     Flask;jQuery;React.js
# 125                                                       NaN
# 193                                                       NaN
# 665                                                  React.js
# 699                Angular;ASP.NET;ASP.NET Core;Express;Flask
#
#                                            WEBFRAMEWORKEDWITH  \
# Respondent
# 5725                                                   Spring
# 54263                                    Express;Flask;jQuery
# 43430                                                     NaN
# 59279       Angular;Angular.js;ASP.NET;ASP.NET Core;Expres...
# 46711       Angular;Angular.js;ASP.NET;ASP.NET Core;Django...
# 123                                                    Spring
# 125                                                       NaN
# 193                                                       NaN
# 665                            Express;React.js;Ruby on Rails
# 699                                                       NaN
#
#                                                 WELCOMECHANGE  WORKWEEKHRS  \
# Respondent
# 5725        Not applicable - I did not use Stack Overflow ...         40.0
# 54263                 Just as welcome now as I felt last year         36.0
# 43430                 Just as welcome now as I felt last year         40.0
# 59279                   A lot more welcome now than last year         40.0
# 46711                                                     NaN        168.0
# 123                   Just as welcome now as I felt last year         36.0
# 125                   Just as welcome now as I felt last year         40.0
# 193                   Just as welcome now as I felt last year         40.0
# 665                   Just as welcome now as I felt last year         40.0
# 699                                                       NaN         40.0
#
#                      YEARSCODE        YEARSCODEPRO
# Respondent
# 5725                        10                   4
# 54263                       14                   5
# 43430                       13                   2
# 59279                       20                  14
# 46711       More than 50 years  More than 50 years
# 123                          8                   3
# 125                         11                  11
# 193                         13                   7
# 665                          4    Less than 1 year
# 699                          5                   2

# %%
#df.dropna()

# %%
#df['YEARSCODE'] = df['YEARSCODE'].astype(float)

# %%
df['YEARSCODE'].unique()
# Out:
# array([nan, '30', 51, '40', '17', '10', '14', '5', '8', '9', '4', '6',
#        '3', '2', '35', '1', 0, '7', '12', '50', '19', '20', '11', '15',
#        '24', '27', '28', '16', '22', '13', '18', '25', '38', '34', '23',
#        '32', '21', '42', '33', '26', '29', '39', '48', '36', '47', '41',
#        '37', '31', '43', '44', '45', '46', '49'], dtype=object)

# %%
df['YEARSCODE'].replace('More than 50 years', 51, inplace=True)
df['YEARSCODE'].replace('Less than 1 year', 0, inplace=True)

# %%
df['YEARSCODE'] = df['YEARSCODE'].astype(float)

# %%
df['YEARSCODE'].mean()
# Out:
# 12.709052770265584

# %%
df['YEARSCODE'].median()
# Out:
# 10.0
